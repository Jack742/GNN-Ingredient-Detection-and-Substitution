# %%
"""USAGE:
If Training GNN -> set the following to true
|MAKE_TEST_SET
|STEM
|DECOMPOSE_HIERARCHY

NOTE: Cannot Test GNN unless model has already been trained
If Testing GNN -> set the following to true
|LOAD_TEST_SET
|STEM
|DECOMPOSE_HIERARCHY

If Training MLP/XGBOOST -> set the following to true
|USE_BRANDS_AND_INGR
|LOAD_BALANCED_DATA
|STEM
|DECOMPOSE_HIERARCHY

If Testing MLP/XGBOOST -> set the following to true
|USE_BRANDS_AND_INGR
|LOAD_TEST_SET
|STEM
|DECOMPOSE_HIERARCHY

||ORDER OF RUNNING||
| RUN TRAIN-GNN FIRST, THEN TEST-GNN, THEN TRAIN MLP/XG, THEN TEST-MLP/XG
| ENSURE FRAC IS ALWAYS

"""

# %%
import ast
import random
import math
import string
import pickle
import json
from copy import deepcopy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import sys
from torch_geometric.data import Data
from torch.nn import Dropout
from tqdm import tqdm
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import torch_geometric.transforms as transforms
from torch_geometric.loader import DataLoader
from torch_geometric.data import InMemoryDataset
import pandas as pd
#www.python-graph-gallery.com


USE_FULL_FEATURES = False
USE_BRANDS_AND_INGR = False
USE_FREQUENCY = False
MASK = False



LOAD_TEST_SET = True
LOAD_BALANCED_DATA = True
MAKE_TEST_SET = False

SAMPLE_FRAC = 0.75
TEST_SAMPLE_FRAC = 0.25
STEM = True
DECOMPOSE_HIERARCHY = True
REMOVE_REPLACE = False

INGREDIENT_TO_CLASSIFY = 'palm oil'#
# Out:
# 'USAGE:\nIf Training GNN -> set the following to true\n|MAKE_TEST_SET\n|STEM\n|DECOMPOSE_HIERARCHY\n\nIf Testing GNN -> set the following to true\n|LOAD_TEST_SET\n|STEM\n|DECOMPOSE_HIERARCHY\n\nIf Training MLP/XGBOOST -> set the following to true\n|USE_BRANDS_AND_INGR\n|LOAD_BALANCED_DATA\n|STEM\n|DECOMPOSE_HIERARCHY\n\nIf Testing MLP/XGBOOST -> set the following to true\n|USE_BRANDS_AND_INGR\n|LOAD_TEST_SET\n|STEM\n|DECOMPOSE_HIERARCHY\n\n||ORDER OF RUNNING||\n| RUN TRAIN-GNN FIRST, THEN TEST-GNN, THEN TRAIN MLP/XG, THEN TEST-MLP/XG\n| ENSURE FRAC IS ALWAYS\n\n'

# %% [markdown]
# ### Load Data From File

# %%
def get_data()->pd.DataFrame:
    """
    Load data from file, depending on global config parameters set
    """
    if LOAD_BALANCED_DATA:
        df = pd.read_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv')
    elif LOAD_TEST_SET:
        df = pd.read_csv(f'test_set.csv')
    else:
        files = [
            "outputs/food_1_Y.csv",
            "outputs/food_2_Y.csv",
            "outputs/food_3_Y.csv"
        ]

        df = pd.DataFrame()
        for file in files:
            df = pd.concat([df, pd.read_csv(file)])

        #df = df[df.index < int(len(df.index)/50)]
        if MAKE_TEST_SET:
            df1 = df.sample(frac=TEST_SAMPLE_FRAC, random_state=123456789)
            df = df.drop(df1.index)
            df = df.sample(frac=SAMPLE_FRAC, random_state=123456789)
            df1.reset_index()
            df = df.reset_index()
            df1.to_csv('test_set.csv')
        else:
            df = df.sample(frac=SAMPLE_FRAC, random_state=123456789)
            df.reset_index()
    return df


def get_stopwords():
    with open('stopwords.txt', 'r') as f:
        stopwords = []
        for l in f:
            if l not in stopwords:
                stopwords.append(l.replace('\n',''))
    return stopwords

def get_hierarchy_ingreds():
    with open('replace_words.json') as f:
        replacements = json.load(f)
        for each in replacements.keys():
            replacements[each] = ast.literal_eval(replacements[each])  
    return replacements

# %% [markdown]
# ### Preprocess Data

# %%
"""
Utility Functions
"""

def stem_ingreds(row: pd.Series, ingred_idx: int)->None:
    ps = PorterStemmer()
    words = [ps.stem(word) for word in INGREDIENT_TO_CLASSIFY.split(' ')]
    s = ''
    for word in words:
        s += word
    sentence = row['ingredients_list'][ingred_idx]
    words = [ps.stem(word) for word in sentence.split(' ')]
    s = ''
    for word in words:
        s += word    
    row['ingredients_list'][ingred_idx] = s
    row['ingredients_list'][ingred_idx] = row['ingredients_list'][ingred_idx].replace(' ', '')


def decompose_hierarchy(row: pd.Series, replacements: dict) -> None: 
    idx = 0
    idx_to_remove = []
    while idx<len(row['ingredients_list']):
        if row['ingredients_list'][idx] in replacements.keys():
            #NEED TO DO THIS. SIMPLE GET THE VALUES IN replacements. CAN'T APPEND IN LOOP, BUT YOU COULD DO A WHILE LOOP
            idx_to_remove.append(idx)
            if LOAD_TEST_SET:                
                if all(item.lower() in replacements[row['ingredients_list'][idx]] \
                    for item in INGREDIENT_TO_CLASSIFY.lower().split()):
                    row['ingredients_list'].append(INGREDIENT_TO_CLASSIFY)
            else:
                row['ingredients_list'].extend(replacements[row['ingredients_list'][idx]])             
        idx+=1
    if REMOVE_REPLACE:
        for i in reversed(idx_to_remove):
            row['ingredients_list'].pop(i)

def remove_stopwords(row:pd.Series,ingred_idx:int, stopwords: list):
    stop_row_li = np.array(row['ingredients_list'][ingred_idx].split(' '))
    for stopword in stopwords:
            stop_loc = np.where(stop_row_li ==stopword)
            if len(stop_loc[0])>0:
                stop_row_li= np.delete(stop_row_li,stop_loc)
                str_ = ''
                for stringify_ in stop_row_li:
                    str_ += ' ' + stringify_
                row['ingredients_list'][ingred_idx] = str_

def is_sparse(row: pd.Series) -> bool:
    if row['brand'] == math.nan:
        return True

    len_ing = len(row['ingredients_list'])
    if len_ing==0:
        return True
    elif len_ing == 1 and row['ingredients_list'][0].lower() in ['nan', 'none', 'na']:
        return True

def combine_all_labels(row: pd.Series, ingred_idx: int)->None:
    each = row['ingredients_list'][ingred_idx]
    if all(item in each.lower() for item in INGREDIENT_TO_CLASSIFY.lower().split()):       
        row['ingredients_list'][ingred_idx] = INGREDIENT_TO_CLASSIFY.lower()

# %%
stopwords = get_stopwords()
if DECOMPOSE_HIERARCHY:
    replacements = get_hierarchy_ingreds()
    
df = get_data()
#Add a list of the ingredients, and concatenate palm oil products to be just palm oil
ingredients = [[x.lower() for x in ast.literal_eval(product['ingredients'])] for _,product in df.iterrows()]
df['ingredients_list'] = ingredients


drop_sparse_idx = []


trans = str.maketrans(string.punctuation, ' '*len(string.punctuation))
for row_idx, row in tqdm(df.iterrows()):
    if is_sparse(row):
        drop_sparse_idx.append(row_idx)
    else:
        for idx in range(len(row['ingredients_list'])):
            row['ingredients_list'][idx] = row['ingredients_list'][idx].translate(trans) 
        if DECOMPOSE_HIERARCHY:
            decompose_hierarchy(row, replacements)

df = df.drop(drop_sparse_idx)
drop_sparse_idx = []

for row_idx, row in tqdm(df.iterrows()):
    pop_li = []
    for idx, each in enumerate(row['ingredients_list']):        
        remove_stopwords(row,idx, stopwords)
        if STEM:
            stem_ingreds(row, idx)
        if row['ingredients_list'][idx] == '':
            pop_li.append(idx)
        else:
            combine_all_labels(row, idx)
    if pop_li:
        for each in reversed(pop_li):
            row['ingredients_list'].pop(each)
        if len(row['ingredients_list']) == 0:
            drop_sparse_idx.append(row_idx)

df = df.drop(drop_sparse_idx)
df = df.drop_duplicates(subset="name")


df = df[['name','brand','categories','price_max','price_min','ingredients','ingredients_list']]
df = df.dropna().reset_index()
df
# Out:
# 2963it [00:00, 3164.82it/s]
# 2963it [00:43, 67.64it/s]
#       index                                               name
# 0         0               OREO Fudge Covered Chocolate Cookies  \
# 1         1               OREO Mini Chocolate Sandwich Cookies
# 2         2   Sunbelt Bakery Chewy Chocolate Chip Granola Bars
# 3         3  Russell Stover Cherry Cordials Box 9.25 Ounce ...
# 4         4                                Whoppers Robin Eggs
# ...     ...                                                ...
# 2958   2958               Beanfields Jalapeno Nacho Bean Chips
# 2959   2959                   De La Rosa Marzipan Peanut Candy
# 2960   2960     Caramel Macchiato for K-Cup Keurig 2.0 Brewers
# 2961   2961                      Truroots Sprouted Quinoa Trio
# 2962   2962         Nature's Path Heritage Cereal (3x13.25 Oz)
#
#                brand                                         categories
# 0               Oreo  ['Grocery & Gourmet Food', 'Cookies', 'Chocola...  \
# 1               Oreo  ['Sandwich', 'Grocery & Gourmet Food', 'Cookie...
# 2     Sunbelt Bakery  ['Cookies', ' Chips & Snacks', 'Grocery', 'Gra...
# 3     Russell Stover  ['Grocery', 'Chocolate', ' Candy Gum', 'Grocer...
# 4           Whoppers  ['Household & Grocery', 'Candy', 'Product', 'C...
# ...              ...                                                ...
# 2958      BEANFIELDS  ['Grocery & Gourmet Food', 'Deli & Prepared Fo...
# 2959      de la Rosa  ['Grocery & Gourmet Food', 'Candy & Chocolate ...
# 2960    Victor Allen  ['Single-Serve Cups & Pods', 'Grocery & Gourme...
# 2961        truRoots  ['Grocery', 'Quinoa', 'Grocery & Gourmet Food'...
# 2962   Nature's Path  ['Grocery', 'Breakfast Foods', 'Grocery & Gour...
#
#       price_max  price_min                                        ingredients
# 0         12.72      12.72  ['sugar', 'unbleached enriched flour wheat flo...  \
# 1         45.89      44.71  ['enriched flour wheat flour', 'niacin', 'redu...
# 2          3.99       2.39  ['carrageenan', 'chocolate chips sugar', 'choc...
# 3         17.95       8.99  ['consist of chocolate sugar', 'chocolate', 'c...
# 4          2.99       2.99  ['contains or less of soy lecithin', 'contains...
# ...         ...        ...                                                ...
# 2958      39.85      38.85  ['black beans', 'navy beans', 'brown rice', 's...
# 2959      17.98      16.81                   ['peanuts', 'sugar and flavors']
# 2960      29.85      13.99         ['arabica coffee', 'artificial flavoring']
# 2961      36.15       4.19  ['sprouted white quinoa', 'sprouted red quinoa...
# 2962      72.32      16.55  ['quinoa', 'sea salt', 'spelt flour', 'kamut k...
#
#                                        ingredients_list
# 0     [sugar, flourwheatflour, niacin, iron, thiamin...
# 1     [flourwheatflour, niacin, iron, thiaminmononit...
# 2     [carrageenan, chocolchipsugar, chocol, cocoabu...
# 3     [consistchocolsugar, chocol, chocolprocessalka...
# 4     [soylecithin, tapiocadextrin, calciumcarbon, c...
# ...                                                 ...
# 2958  [blackbean, navibean, brownrice, safflowsunflo...
# 2959                              [peanut, sugarflavor]
# 2960                           [arabicacoffe, artifici]
# 2961  [sproutwhitequinoa, sproutredquinoa, sproutbla...
# 2962  [quinoa, seasalt, speltflour, kamutkhorasanwhe...
#
# [2963 rows x 8 columns]

# %%
unique_names = df['name'].unique()
unique_brands = df['brand'].unique()

unique_cats = np.unique(sum(df["categories"].apply(ast.literal_eval).values.tolist(), []))
unique_names = sorted(unique_names)

unique_ingred = []
for x in df['ingredients_list']:
    for y in x:
        if y not in unique_ingred:
            unique_ingred.append(y)

# %%
def get_feature_matrix():
    feature_mat = np.zeros((len(unique_names),len(unique_ingred)),dtype=int)
    for idx, row in df.iterrows():
        ingr = row['ingredients_list']
        for ing_idx,each in enumerate(unique_ingred):
            feature_mat[idx,ing_idx] = 1 if each in ingr else 0
    return feature_mat

def get_feature_coocurrance():    
    feature_mat = dict()
    for each in range(len(unique_ingred)):
        feature_mat[each] = np.zeros((len(unique_ingred)),dtype=int)

    for idx, row in df.iterrows():
        ingr = row['ingredients_list']#ast.literal_eval(row['ingredients'])
        for ing_idx,each in enumerate(unique_ingred):
            if each in ingr:
                for ing_idx2,each2 in enumerate(unique_ingred):
                    if each2 in ingr:
                        #Minus the value along the diagonal. Prevents inteference with the coocurrance but also allows us to retrieve magnitude later
                        feature_mat[ing_idx][ing_idx2] += 1 if ing_idx!=ing_idx2 else -1
    return feature_mat

def get_cooccurance_tf_idf(palm_oil_cooccurance_vector):
    # Adapted from TF-IDF.
    # IDF = log(n/j) where n = total number of documents and j = number of documents containing a given term. This is kept the same, but squared
    # TF is the frquency of a term in a *given* document. This doesn't really apply here, but instead we..
    # || consider the frequency of a term (i.e. ingredient) in products that also contain palm oil (i.e. co-occurance)

    n = len(unique_names)

    #IMPORTANT We initialise the array to 1 rather than 0 at present, this is to avoid 0 divides in the math.log without having to iterate over idf to check and then skip the log step due to time complexity
    idf = np.ones(len(unique_ingred))
    for idx,row in df.iterrows():
        ingr_list = row['ingredients_list']#ast.literal_eval(row['ingredients'])
        for i,ingredient in enumerate(unique_ingred):
            idf[i] += 1 if ingredient in ingr_list else 0
        
        
        idf = np.array([math.log(n/j) for j in idf])
    #assert len(palm_oil_cooccurance_vector) == len(idf)

    tf_idf_vector = palm_oil_cooccurance_vector * np.square(idf)
    return tf_idf_vector

def get_information_entropy(cooccurance_matrix, palm_oil_idx, num_palm_oil, num_total_products):
    #Intuition: use information entropy to calculate how much information each other ingredient can give us on the presence of palm oil
    # - (P(palm_oil_presence|x) log(P(palm_oil_presence|x))) + (P(¬palm_oil_presence|x) log(P(¬palm_oil_presence|x)))
    def calculate_entropy(palm_presence, n):
        if n != 0:
            p1 = palm_presence/n
        else:
            p1 = 0
        p2 = 1-p1
        sum1 = 0 if p1==0 else (p1*math.log2(p1))
        sum2 = 0 if p2==0 else (p2*math.log2(p2))
        return - sum1 + sum2
    
    def calcalate_conditional_entropy(palm_presence, n, p_n):
        if p_n < 0:
            print(p_n)
            exit()
        if n!= 0:
            p1 = (palm_presence/n)*p_n
        else:
            p1 = 0
        assert p1 >=0
        assert p_n >=0
        sum1 = 1 if (p1<=0 or p_n<=0) else (1 + (p1*math.log2(1+(p1/p_n))))
        if sum1 <= 0:
            print(p1, p_n, palm_presence, n)
        return sum1

    n = len(unique_ingred)
    entropies = np.empty(n) 
    for idx,each in enumerate(cooccurance_matrix[palm_oil_idx]):
        if idx == palm_oil_idx:
            entropies[idx] == 100
        else:
            n_occ = -cooccurance_matrix[idx][idx]
            assert n_occ >= each, (unique_ingred[idx])
            entropies[idx] = (calcalate_conditional_entropy(each, n_occ, n_occ/num_total_products) + 
                                calcalate_conditional_entropy(each, num_total_products-n_occ, (num_total_products-n_occ)/num_total_products) + 
                                calcalate_conditional_entropy(n_occ-each, n_occ, n_occ/num_total_products) + 
                                calcalate_conditional_entropy(n_occ-each, num_total_products-n_occ, (num_total_products-n_occ)/num_total_products)
                                )
    return entropies        
    # for idx, row in df.iterrows():
    #     ingr_list = ast.literal_eval(row['ingredients'])
    #     for i, ingredient in enumerate(ingr_list):


        
def show_frequency():
  cooccurance_matrix = get_feature_coocurrance()
  freqs = []
  total_products = len(df.index)
  for idx in range(len(cooccurance_matrix[0])):
    freqs.append((-cooccurance_matrix[idx][idx])/total_products)
  plt.bar(range(len(freqs)), sorted(freqs))
  plt.show()

def piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies, threshold_perc = 0.01):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00

  def calculate_threshold():
      freqs = []
      total_products = len(df.index)
      for idx in range(len(cooccurance_matrix[0])):
        freqs.append((-cooccurance_matrix[idx][idx])/total_products)
        
      perc_idx = int(len(freqs)*threshold_perc)
      top_n_threshold = sorted(freqs, reverse=True)[perc_idx]
      zero_thresh = sorted(freqs, reverse=True)[0]
      print(perc_idx, top_n_threshold, zero_thresh)
      return top_n_threshold

  thresh = calculate_threshold()
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          #n/f = 1/(f/n), f/n == frequency.
          fx = -cooccurance_matrix[idx][idx]
          frequency = (fx)/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency) if frequency <= thresh else np.log(total_products/(total_products-fx))
              if occurance < 0:
                  print(f'less than zero, occ: {np.log(1/(total_products-fx))} with fx as {fx}')
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          frequency = (-cooccurance_matrix[idx][idx])/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency)
              if occurance < 0:
                  print("yes")
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def apply_entropy_mask(top_n=2000, frequency_weighted=True):
  cooccurance_matrix = get_feature_coocurrance()
  #Print the highest co-occuring ingredients
  for idx,each in enumerate(unique_ingred):
      if (INGREDIENT_TO_CLASSIFY in each.lower()):
          palm_idx = idx
          palm_vector = cooccurance_matrix[idx]
          sorted_indicies = sorted(range(len(palm_vector)), key=lambda x: palm_vector[x], reverse=True)
          print("MOST CO-OCCURANCES: ",[(unique_ingred[x],palm_vector[x]) for x in sorted_indicies[:10]])
          break
  entropies = get_information_entropy(cooccurance_matrix, palm_idx, num_palm,len(df.index))
  ordered_entropy = sorted(range(len(entropies)), key=lambda x: entropies[x], reverse=False)
  
  if frequency_weighted:
    fwce = piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies)
    fwce_ordered_entropy = sorted(range(len(entropies)), key=lambda x: fwce[x], reverse=False)
    unique_ingred_ = [unique_ingred[i_] for i_ in fwce_ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, fwce_ordered_entropy, unique_ingred_
  else:
    unique_ingred_ = [unique_ingred[i_] for i_ in ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, ordered_entropy, unique_ingred_


def show_frequency():
  cooccurance_matrix = get_feature_coocurrance()
  freqs = []
  total_products = len(df.index)
  for idx in range(len(cooccurance_matrix[0])):
    freqs.append((-cooccurance_matrix[idx][idx])/total_products)
  plt.bar(range(len(freqs)), sorted(freqs))
  plt.show()

def piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies, threshold_perc = 0.01):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00

  def calculate_threshold():
      freqs = []
      total_products = len(df.index)
      for idx in range(len(cooccurance_matrix[0])):
        freqs.append((-cooccurance_matrix[idx][idx])/total_products)
        
      perc_idx = int(len(freqs)*threshold_perc)
      top_n_threshold = sorted(freqs, reverse=True)[perc_idx]
      zero_thresh = sorted(freqs, reverse=True)[0]
      print(perc_idx, top_n_threshold, zero_thresh)
      return top_n_threshold

  thresh = calculate_threshold()
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          #n/f = 1/(f/n), f/n == frequency.
          fx = -cooccurance_matrix[idx][idx]
          frequency = (fx)/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency) if frequency <= thresh else np.log(total_products/(total_products-fx))
              if occurance < 0:
                  print(f'less than zero, occ: {np.log(1/(total_products-fx))} with fx as {fx}')
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          frequency = (-cooccurance_matrix[idx][idx])/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency)
              if occurance < 0:
                  print("yes")
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def apply_entropy_mask(feature_matrix,top_n=2000, frequency_weighted=True):
  cooccurance_matrix = get_feature_coocurrance()
  #Print the highest co-occuring ingredients
  for idx,each in enumerate(unique_ingred):
      if (INGREDIENT_TO_CLASSIFY in each.lower()):
          palm_idx = idx
          palm_vector = cooccurance_matrix[idx]
          sorted_indicies = sorted(range(len(palm_vector)), key=lambda x: palm_vector[x], reverse=True)
          print("MOST CO-OCCURANCES: ",[(unique_ingred[x],palm_vector[x]) for x in sorted_indicies[:10]])
          break
  entropies = get_information_entropy(cooccurance_matrix, palm_idx, num_palm,len(df.index))
  ordered_entropy = sorted(range(len(entropies)), key=lambda x: entropies[x], reverse=False)
  
  if frequency_weighted:
    fwce = piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies)
    fwce_ordered_entropy = sorted(range(len(entropies)), key=lambda x: fwce[x], reverse=False)
    unique_ingred_ = [unique_ingred[i_] for i_ in fwce_ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, fwce_ordered_entropy, unique_ingred_
  else:
    unique_ingred_ = [unique_ingred[i_] for i_ in ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, ordered_entropy, unique_ingred_

# %%
def get_adj_matrix_from_features(feature_mat):
    adj_mat = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        for i in elements:
            for j in elements:
                adj_mat[i,j] += 1 if i!=j else 0 
    return adj_mat

def get_adj_matrix_from_extra_features(feature_mat):
    adj_mat = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    shared_features = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        for i in elements:
            for j in elements:
                adj_mat[i,j] += 1 if i!=j else 0
                shared_features[i,j] = idx
    return (adj_mat, shared_features)

def get_adj_list_from_features(graph,feature_mat):
    adj_list = dict()

    # for node in range(len(list(graph.vs))):
    #     node_idx = node
    #     adj_list[node_idx] = {}
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        if len(elements) > 0:
            for i in elements:
                assert len([_ for _ in elements]) > 0
                adj_list[i] = [_ for _ in elements]
                adj_list[i].remove(i)
    for each in adj_list.keys():
        adj_list[each] = list(set(adj_list[each]))
    return adj_list

# %%
def get_feature_vector_and_label(product, decision_ingredients):
  #Build feature vector of high entropy ingredients. 
  feature_vector = np.zeros(len(decision_ingredients))
  ingredients = product['ingredients_list']#ast.literal_eval(product['ingredients'])
  for dec_idx,decision_ingr in enumerate(decision_ingredients):
    #Check if ingredients is in feature list, and also make sure to mask the palm oil ingredient
    if unique_ingred[dec_idx] in ingredients and unique_ingred[dec_idx] != INGREDIENT_TO_CLASSIFY:      
      feature_vector[dec_idx] = 1
  #1 = palmy, 0 = non_palmy
  label = 1 if INGREDIENT_TO_CLASSIFY in ingredients else 0

  return (feature_vector, label)

def get_one_feature_vector(product, feature_key,unique_features, is_list=False):
  product_data = ast.literal_eval(product[feature_key]) if is_list else product[feature_key]
  feature_vector = np.zeros(len(unique_features))
  for feat_idx,feat in enumerate(unique_features):
    if (is_list and (feat in product_data)) or (feat==product_data):
      feature_vector[feat_idx] += 1
  return feature_vector

def get_balanced_dataset(df, test_perc, val_perc):
  if 'level_0' in df.columns:
    df = df.drop('level_0', axis=1).reset_index()
  palmy_prods = []
  for idx,row in df.iterrows():
    for each in row['ingredients_list']:    
      if (INGREDIENT_TO_CLASSIFY in each):
        palmy_prods.append(row)

  palmy_df = pd.DataFrame(palmy_prods)
  #What % of the dataset is a positive class?
  proportion = len(palmy_df.index)/len(df.index)

  #Sample the same amount of non-palmy products
  df = df.drop(list(palmy_df.index))
  palmy_df = palmy_df.drop_duplicates(subset='index')


  palmy_test_sample_num = int(len(palmy_df)*test_perc)
  nonpalmy_test_sample_num = int(len(df.index)*test_perc)
  palmy_val_sample_num = int(len(palmy_df)*val_perc)
  nonpalmy_val_sample_num = int(len(df.index)*val_perc)

  sample_len = int(len(palmy_df.index)*(1-(test_perc+val_perc)))
  non_palmy_df = df.sample(sample_len+nonpalmy_test_sample_num+nonpalmy_val_sample_num)
  #assert len(palmy_df.index) == len(non_palmy_df.index)
  #Shuffle each df
  palmy_df = palmy_df.sample(frac=1)
  non_palmy_df = non_palmy_df.sample(frac=1)
  if 'level_0' in palmy_df.columns:
    palmy_df = palmy_df.drop('level_0', axis=1).reset_index()
  else:
    palmy_df = palmy_df.reset_index()
  if 'level_0' in non_palmy_df.columns:
    non_palmy_df = non_palmy_df.drop('level_0', axis=1).reset_index()
  else:
      non_palmy_df = non_palmy_df.reset_index()
  df=pd.concat([palmy_df, non_palmy_df]).drop('level_0', axis=1).reset_index()
  #print(len(palmy_df.index), len(df.index),proportion, nonpalmy_test_sample_num, palmy_test_sample_num, nonpalmy_val_sample_num,palmy_val_sample_num)


  train_mask,val_mask,test_mask = np.zeros(len(df.index)),np.zeros(len(df.index)),np.zeros(len(df.index))
  dflen, pdflen, npdflen = len(df.index),len(palmy_df.index),len(non_palmy_df.index)

  train_boundaries = (int((1-(test_perc+val_perc))*pdflen), (pdflen+npdflen-(nonpalmy_test_sample_num+nonpalmy_val_sample_num)))
  val_boundaries = (train_boundaries[0]+int(pdflen*val_perc), train_boundaries[1]+nonpalmy_val_sample_num)

  train_mask[:train_boundaries[0]] = 1
  train_mask[pdflen:train_boundaries[1]] = 1

  val_mask[train_boundaries[0]:val_boundaries[0]] = 1
  val_mask[train_boundaries[1]:val_boundaries[1]] = 1

  test_mask[val_boundaries[0]:pdflen]=1
  test_mask[val_boundaries[1]:]=1

  assert dflen == (pdflen+npdflen)
  assert dflen == sum([sum(x) for x in [test_mask, train_mask, val_mask]])

  print(sum(train_mask), sum(val_mask),sum(test_mask), len(df.index), pdflen, npdflen,palmy_test_sample_num,nonpalmy_test_sample_num)
  return (df, torch.tensor(train_mask, dtype=bool), torch.tensor(val_mask, dtype=bool), torch.tensor(test_mask, dtype=bool))


if LOAD_BALANCED_DATA:
  df = pd.read_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv', converters={'ingredients_list': pd.eval})
  with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_test_mask.pickle', 'rb') as f:
    test_mask = pickle.load(f)
  with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_train_mask.pickle', 'rb') as f:
    train_mask = pickle.load(f)
  with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_val_mask.pickle', 'rb') as f:
    val_mask = pickle.load(f)
else:  
  if LOAD_TEST_SET:
    df,train_mask,val_mask,test_mask = get_balanced_dataset(df,0.98,0.01)
  else:
    df,train_mask,val_mask,test_mask = get_balanced_dataset(df,0.1,0.1)
    df.to_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv')
    with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_test_mask.pickle', 'wb') as f:
      pickle.dump(test_mask,f)
    with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_train_mask.pickle', 'wb') as f:
      pickle.dump(train_mask,f)
    with open(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_val_mask.pickle', 'wb') as f:
      pickle.dump(val_mask,f)

#df.to_csv('final_saved_balanced_dataset.csv')

# feature_matrix = []
# for idx, product in df.iterrows():
#   feature_vector, label = get_feature_vector_and_label(product, unique_ingred)#get_feature_vector_and_label_with_brands(product, unique_ingred)
#   feature_matrix.append(feature_vector)





show_frequency()
unique_ingred = []

if LOAD_TEST_SET:
  with open(f'{INGREDIENT_TO_CLASSIFY}test_set_unique_ingreds', 'rb') as f:
    unique_ingred = pickle.load(f)
  if USE_BRANDS_AND_INGR:
    with open(f'{INGREDIENT_TO_CLASSIFY}test_set_unique_brands', 'rb') as f:
      unique_brands = pickle.load(f)
else:
  if USE_BRANDS_AND_INGR:
    with open(f'{INGREDIENT_TO_CLASSIFY}test_set_unique_brands', 'wb') as f:
      pickle.dump(unique_brands,f)
  if MASK:  
    feature_matrix,ordered_entropy,unique_ingred=apply_entropy_mask(int(len(unique_ingred)/2), frequency_weighted=USE_FREQUENCY)
  else:
    for x in df['ingredients_list']:
        for y in x:
            if y not in unique_ingred:
                unique_ingred.append(y)                
  with open(f'{INGREDIENT_TO_CLASSIFY}test_set_unique_ingreds', 'wb') as f:
    pickle.dump(unique_ingred, f)
    
#Get Matrix of Features -- Products x Features
feature_matrix = []
label_vector = []
edge_matrix = []
brand_vector = []
cat_matrix = []
for idx, product in df.iterrows():
  feature_vector, label = get_feature_vector_and_label(product, unique_ingred)#get_feature_vector_and_label_with_brands(product, unique_ingred)
  feature_matrix.append(feature_vector)
  label_vector.append(label)
  edge_matrix.append(get_one_feature_vector(product, 'brand',unique_brands))
  brand_vector.append(np.where(edge_matrix[idx] == 1)[0])
  cat_matrix.append(get_one_feature_vector(product,'categories',unique_cats, is_list=True))

#(adj_matrix,feature_matrix) = drop_sparse(get_adj_matrix_from_features(np.array(feature_matrix)), feature_matrix)



ingred_adj_matrix = get_adj_matrix_from_features(np.array(feature_matrix))
#adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))

if USE_FULL_FEATURES:
  #Concatenate ingredients with brands and categories
  feature_matrix = np.concatenate((feature_matrix, edge_matrix, cat_matrix), axis=1)
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))
elif USE_BRANDS_AND_INGR:
  feature_matrix = np.concatenate((feature_matrix, edge_matrix), axis=1)
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))
else:
  #Get adjacency from just brands
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(edge_matrix))
  #adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(cat_matrix))
  #adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))


# adj_matrix = get_adj_matrix_from_extra_features(np.array(feature_matrix), len(unique_ingred))
# for col in adj_matrix:
#   print(len(np.where(col==1)[0]))


# if MASK:
#   feature_matrix, ordered_entropies = apply_entropy_mask(feature_matrix, top_n=int(len(feature_matrix[:][0])/7.5))

edge_index = []
edge_attr = []
edge_weights_ = []
for idx,_ in enumerate(adj_matrix):
  for target,val in enumerate(adj_matrix[idx]):
    if val >0:
      edge_index.append([idx,target])
      edge_weights_.append(ingred_adj_matrix[idx, target])
      edge_attr.append(shared_features[idx, target])

#To Tensor
feature_matrix = torch.tensor(feature_matrix, dtype=torch.float)
label_vector = torch.tensor(label_vector)
edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
print(edge_index.shape)
edge_weights = torch.tensor([1 for _ in range(len(edge_weights_))], dtype=torch.float)#.t().contiguous()
edge_attr = torch.tensor(edge_attr, dtype=torch.float)#.t().contiguous()
edge_attr = torch.randn(edge_index.size(1))
transform = transforms.Compose([
    #transforms.RandomNodeSplit('train_rest', num_val=int(feature_matrix.shape[0]/10), num_test=int(feature_matrix.shape[0]/10)),
    transforms.TargetIndegree()
])
# print(feature_matrix.shape, label_vector.shape)
# print(len(np.where(label_vector==1)[0]),len(np.where(label_vector==0)[0]))

# class ProductDataset(InMemoryDataset):
#   def __init__(self, data, transform=None, pre_transform=None):
#     super().__init__(None, transform, pre_transform)
#     self.data = data
#     self.transform = transform
#     self.pre_transform = pre_transform 
  
#   def len(self):
#     return 1
  
#   def get(self,idx):
#     if self.pre_transform:
#       data = self.pre_transform(self.data)
#     if self.transform:
#       data = self.transform(self.data)
#     return data

# print(Data(x=feature_matrix, y=label_vector,edge_index=edge_index, edge_weight=edge_weights, edge_attr=edge_attr))
data = transform(Data(x=feature_matrix, edge_index=edge_index))
data.y=label_vector
data.edge_weight=edge_weights
data.edge_attr=edge_attr
data.train_mask=train_mask
data.val_mask=val_mask
data.test_mask=test_mask
#dataset = ProductDataset(data, transform=transform)
#dataloader = DataLoader(dataset, 
print(data)

# if MASK:
#   masked_data = deepcopy(data)
#   masked_data.x, ordered_entropies = apply_entropy_mask(masked_data.x, top_n=int(len(masked_data.x[:][0])/10))
# Out:
# torch.Size([2, 14394])
# Data(x=[2963, 6786], edge_index=[2, 14394], edge_attr=[14394], y=[2963], edge_weight=[14394], train_mask=[2963], val_mask=[2963], test_mask=[2963])
# C:\Users\Jwfos\AppData\Local\Temp\ipykernel_22752\301668392.py:194: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   feature_matrix = torch.tensor(feature_matrix, dtype=torch.float)

# %%
from torch_geometric.utils import to_networkx
import networkx as nx


print(data.y[data.test_mask])
new_graph = to_networkx(data)
k=100

sampled_nodes = random.sample(new_graph.nodes,k)

sampled_graph = new_graph.subgraph(sampled_nodes)


#pos=nx.kamada_kawai_layout(sampled_graph)
cm = []
for node in sampled_graph:
    if data.y[node] ==1:
        cm.append('orange')
    else:
        cm.append('blue')

nx.draw(sampled_graph, node_color=cm)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 from torch_geometric.utils import to_networkx
# ----> 2 import networkx as nx
#       5 print(data.y[data.test_mask])
#       6 new_graph = to_networkx(data)
#
# ModuleNotFoundError: No module named 'networkx'

# %%
if MASK and USE_FREQUENCY:
    cooccurance_matrix = get_feature_coocurrance()
    #Print the highest co-occuring ingredients
    for idx,each in enumerate(unique_ingred):
        if (INGREDIENT_TO_CLASSIFY in each.lower()):
            palm_idx = idx
            palm_vector = cooccurance_matrix[idx]
            sorted_indicies = sorted(range(len(palm_vector)), key=lambda x: palm_vector[x], reverse=True)
            print("MOST CO-OCCURANCES: ",[(unique_ingred[x],palm_vector[x]) for x in sorted_indicies[:10]])
            break
    entropies = get_information_entropy(cooccurance_matrix, palm_idx, num_palm,len(df.index))
    ordered_entropy = sorted(range(len(entropies)), key=lambda x: entropies[x], reverse=False)

    print(f"Lowest Entropy Ingredients: {np.array(unique_ingred)[ordered_entropy[:11]]}")
    print(f"Highest Entropy Ingredients: {np.array(unique_ingred)[ordered_entropy[-10:]]}")

    print(sorted(entropies)[:10])

# for idx,each in enumerate(entropies):
#     if each <=0:
#         print(unique_ingred[idx])

# %%
# sns.color_palette('Set2')
# sns.set_theme()
if MASK and USE_FREQUENCY:
    print(min(entropies), entropies[ordered_entropy[0]],entropies[ordered_entropy[-1]])

    '''
    Frequency-weighted conditional entropy = log(N/f) * H(Y|X)
    Where N is total number of products and f is the number of products that contain this ingredient

    '''
    frequency_weighted_conditional_entropies = []
    total_products = len(df.index)
    fs = []
    min_frequency = 0.00 #1%
    for idx in ordered_entropy:
        #Minus as you've made the diagonal minus for other reasons
        
        if cooccurance_matrix[idx][idx]!=0:
            frequency = (-cooccurance_matrix[idx][idx])/total_products
            fs.append(frequency)
            if frequency >= min_frequency:
                occurance = np.log(1/frequency)
                if occurance < 0:
                    print("yes")
                
                frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
            else:
                frequency_weighted_conditional_entropies.append(1.0)
        else:
            print('Entropy', unique_ingred[idx])
    print(sorted(frequency_weighted_conditional_entropies)[:20])
    print(min(frequency_weighted_conditional_entropies),max(frequency_weighted_conditional_entropies))
    print(min(fs), max(fs), np.median(fs), np.mean(fs))


    fig,ax = plt.subplots()
    ax.set_title('IDF-Conditional Entropy of Ingredients For Palm Oil Prediction')
    ax.set_ylabel('IDF Conditional Entropy')
    ax.set_xlabel('Ingredients')
    ax.bar(np.arange(len(frequency_weighted_conditional_entropies)), sorted(frequency_weighted_conditional_entropies))
    plt.show()

# %%
if MASK and USE_FREQUENCY:
    fig,ax = plt.subplots(1,2)
    ax[0].bar(np.arange(len(entropies)),sorted(entropies))
    #ax[0].set_xticklabels(np.array(unique_ingred)[ordered_entropy], rotation=45, ha='right')
    ax[0].set_xticks(np.arange(len(entropies)))

    ax[1].bar(np.arange(len(entropies[:20])),sorted(entropies[:20]))
    #ax[1].set_xticklabels(np.array(unique_ingred)[ordered_entropy[:20]], rotation=45, ha='right')
    ax[1].set_xticks(np.arange(len(entropies[:20])))
    ax[0].set_title('Conditional Entropy of Ingredients With Respect to Palm Oil')
    ax[1].set_title('Ingredients With Lowest Conditional Entropy With Respect to Palm Oil')

    plt.show()

# %%
from torch_geometric.nn import GCNConv, GATv2Conv, NNConv,SAGEConv
from torch_geometric.nn.models import AttentiveFP 
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.transforms import NormalizeFeatures
from sklearn.manifold import TSNE
def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(out.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
class MLP(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(MLP, self).__init__()
        #torch.manual_seed(12345)
        self.lin1 = Linear(len(data.x[0]), hidden_channels)
        self.lin2 = Linear(hidden_channels,2)

    def forward(self, x):
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x

model = MLP(hidden_channels=16)
print(model)
print(sum(p.numel() for p in model.parameters() if p.requires_grad))

# criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.

# def train():
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss

# def test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(data.x)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[data.test_mask]
#       d = data.y[data.test_mask]      
#       for idx,each in enumerate(test_correct):
#           class_samples[d[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# def masked_test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(masked_data.x)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[masked_data.test_mask] == masked_data.y[masked_data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[masked_data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(masked_data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[masked_data.test_mask]
#       d = data.y[masked_data.test_mask]      
#       for idx,each in enumerate(test_correct):
#           class_samples[d[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# for epoch in range(1, 101):
#     loss = train()
#     print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# test_acc = test()
# print(f'Test Accuracy: {test_acc:.4f}')

# # if MASK:
# #     masked_test_acc = masked_test()
# #     print(f'Masked Test Accuracy: {masked_test_acc:.4f}')
# Out:
# MLP(
#   (lin1): Linear(in_features=6786, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=2, bias=True)
# )
# 108626

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = GCNConv(len(data.x[0]), hidden_channels)
        self.conv2 = GCNConv(hidden_channels, 2)

    def forward(self, x, edge_index, edge_weight):
        x = self.conv1(x, edge_index, edge_weight=edge_weight)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index, edge_weight)
        return x

class GatV2ConvClass(torch.nn.Module):
    def __init__(self, hidden_channels, heads=4, edge_dim=1):
        super().__init__()
        self.edge_dim=edge_dim
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = GATv2Conv(len(data.x[0]), hidden_channels, heads=heads)
        self.conv2 = GATv2Conv(hidden_channels*heads, 2)

    def forward(self, x, edge_index, edge_attr=None, size=None):
        x = self.conv1(x, edge_index, edge_attr, size)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index,edge_attr, size)
        return x


class SAGEConvClass(torch.nn.Module):
    def __init__(self, hidden_channels,dropout=0.5,edge_dim=1):
        super().__init__()
        self.edge_dim=edge_dim
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = SAGEConv(len(data.x[0]), hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, 2)
        self.dropout_prob = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=self.dropout_prob, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score
if LOAD_TEST_SET and not USE_BRANDS_AND_INGR:
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = data.to(device)
  # WEIGHTS = torch.tensor([1-proportion, proportion])
  # WEIGHTS = WEIGHTS.to(device)
  def gridsearch(model_path, hidden_channels, lrs,weight_decays, save_path, dropouts):
      def test():
          predictions = pd.DataFrame(columns=['Product', 'Ingredients', 'Prediction', 'Label'])
          class_correct = [0,0]
          class_samples = [0,0]
          model.eval()
          out = model(data.x, data.edge_index)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
          
          assert len(test_correct)==len(pred[data.test_mask])
          #print(test_correct)
          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]
          test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
          p = pred[data.test_mask]
          d = data.y[data.test_mask]
          
          d_ = d.cpu().numpy()
          p_ = p.cpu().numpy()
          _data_test_mask = data.test_mask.detach().cpu().numpy()
          for df_idx,pred,label in zip(np.where(_data_test_mask==True)[0],p_,d_):
            prod_row = df.iloc[[df_idx]]
            row = {'Product': prod_row.iloc[0]['name'], 'Ingredients': prod_row.iloc[0]['ingredients_list'],'Prediction': pred, 'Label': label}
            print(row)
            predictions = pd.concat([predictions, pd.Series(row)])
          greater_class_probs_ = greater_class_probs[data.test_mask].cpu().detach().numpy()

          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(y_true = d_, y_pred=p_)
          predictions.to_csv("palmoil_classification_predictions.csv")
          return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

      num_features = len(data.x[0])
      stop_at = 0
      data_dict = {}
      end_str = INGREDIENT_TO_CLASSIFY
      data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
      gridsearch_ = {}
      for hidden_chans in hidden_channels:
          for lr in lrs:
            for wd in weight_decays:
              for do in dropouts:
                for i in range(1):
                  model = SAGEConvClass(hidden_chans, dropout=do).to(device)
                  model.load_state_dict(torch.load(f'{model_path}_{i}'))
                  model.eval()
                  optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
                  criterion = torch.nn.CrossEntropyLoss()
                  max_acc = 0.0
                  max_auc = 0.0
                  max_test_auc = 0.0
                  max_test_acc = 0.0
                  test_acc_li = []
                  test_auc_li = []
                  test_prec_li = []
                  test_rec_li = []
                  test_f1_li = []
                  test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                  test_auc_li.append(round(test_auc,3))
                  test_acc_li.append(round(test_acc,3))
                  test_prec_li.append(test_precision)
                  test_rec_li.append(test_recall)
                  test_f1_li.append(test_f1)
                  max_test_auc = test_auc
                  max_test_acc = test_acc
                  print(f'HC: {hidden_channels} | LR: {lr} | WD: {wd} | DrpOut: {do} | Run: {i} | \
                    Accuracy: {test_acc} | AUC: {test_auc} | Precision: {test_precision} | Recall: {test_recall} | F1: {test_f1_li}')
    
                  data_dict[end_str]['Test Accuracy'][i]= test_acc_li
                  data_dict[end_str]['Test AUC'][i] = test_auc_li
                  data_dict[end_str]['Test Precision'][i] = test_prec_li
                  data_dict[end_str]['Test Recall'][i] = test_rec_li
                  data_dict[end_str]['Test F1'][i] = test_f1_li
            with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_graphsage_data_dict_TESTING', 'wb') as f:
              pickle.dump(data_dict, f)
    
  # 'Hids: 128 lr: 0.01 wd: 0.005 dropout: 0.5'
  hidden_chans = [128]#64 lr: 0.01 wd: 0.005
  lrs = [0.01]
  wds = [0.005]
  dropouts = [0.5]
  save_path = ''
  model_path = f'{INGREDIENT_TO_CLASSIFY}_DEMO_TEST_GNN'
  gridsearch(model_path,hidden_chans,lrs,wds, save_path,dropouts)
# Out:
# {'Product': "Hershey's Mr. Goodbar", 'Ingredients': ['vanillin', 'vegetoil', 'peanut', 'chocol', 'salt', 'flavor', 'palm oil', 'sugar', 'milk', 'milk', 'vegetoil', 'whey', 'soylecithin', 'cocoabutter', 'peanut', 'sugar', 'palm oil', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'COFFEEMATE CARB VANILLA CARAMEL', 'Ingredients': ['yeasttrivialsugarsourclactos', 'vegetoil', 'cornsyrupsolid', 'flavor', 'sodiumcasein', 'dipotassiumphosphat', 'monodiglycerid', 'salt', 'sodiumaluminosil', 'sucralos', 'acesulfampotassium', 'yeast', 'flavor', 'vegetoil', 'acesulfampotassium', 'palm oil', 'palm', 'soybean', 'cottonse', 'safflow', 'cornsyrupsolid', 'flavor', 'sodiumcasein', 'dipotassiumphosphat', 'monodiglycerid', 'salt', 'sodiumaluminosil', 'sucralos', 'acesulfampotassium', 'yeast', 'sodiumaluminosil', 'cornsyrupsolid', 'salt', 'sucralos', 'dipotassiumphosphat', 'sodiumcasein', 'monodiglycerid'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Gatorade Whey Protein Bars', 'Ingredients': ['chocolflavorcoatcanesyrup', 'palm oil', 'wheyprotein', 'cocoaprocessalkali', 'soylecithin', 'flavor', 'wheyproteincrispwheyprotein', 'cornstarch', 'cornsyrup', 'chocolcookipiecwheatflour', 'sugar', 'canolaoil', 'cocoa', 'salt', 'sodiumbicarbon', 'vanillaflavorcremelayersugar', 'palm oil', 'soybeanoil', 'drimilk', 'driwholemilk', 'milk', 'flavor', 'soylecithin', 'brownsugar', 'caramelglucos', 'sugar', 'palm oil', 'milk', 'glycerin', 'buttercream', 'salt', 'cornstarch', 'whey', 'salt', 'monodiglycerid', 'flavor', 'soylecithin', 'chocolchipsugar', 'chocolliquor', 'cocoabutter', 'soylecithin', 'vanillaextract', 'glycerin', 'invertsugar', 'milkprotein', 'water', 'salt', 'flavor', 'bht', 'citricacid'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Assortit Yolele Premium Prewashed Fonio Ancient African Grain Alkaline Diet Super Food Vegan High Protein Gluten Free Fast Cooking 22 Servings 2.25 Lb (36 Oz)', 'Ingredients': ['oneozpackagyollfonio', 'coollemonnelichopgarlicnelichopgingersaltpepperpeppertastcupolivoilcupnelidicemangocupdicepeelcucumbcuphalvgrapetomatocupnelichopmintcupnelichopparsleypoundyuca', 'peelcutintolargchunkcupyollfoniocupnelichopspinachshallot', 'nelichoptablespoonthyme', 'nelichoptablespoonparsley', 'palm oil', 'plugreasozpitmedjooldate', 'roughlichopcuproughlichoproastpeanutcashew', 'pumpkinseedpinenutcayennmediumcarrot', 'cutintoinchdicecupyollfoniocupchickenvegetstockkoshersaltfreshligroundblackpepperfinechopflatleafparsleylargmango', 'peeldicetablespoonfinegroundalmondflourtablespoonlemonpeanutvegetoil', 'pluifneedlambshanksaltfreshligroundblackpeppercupchopyellowoniongarlicclove', 'minctablespoontomatopast', 'mixfewtablespoonwaterquartchickenstockwaterbayleavfinechopthymecupsmoothpeanutbutterscotchbonnetpeppervietnamesthaifishsaucolivoil', 'cookcupbutternutsquash', 'peeldiceripetomato', 'chopgarlicclove', 'crushcupfoniopackcupbabispinachleav', 'tornintopieclargeggcupmilkcupgratecheddargoatcheessaltpeppertastfonio'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Masterfoods Variety Minis Mix', 'Ingredients': ['flavortwixbrandminimilkchocolsugar', 'thiaminmononitr', 'wheatflourwheatflour', 'riboflavin', 'folicacid', 'milkiwaymidnightminichocolsugar', 'flavor', 'cocoaprocessalkali', 'flavor', 'palm oil', 'salt', 'palm oil', 'cornsyrup', 'palm oil', 'chocolprocessalkali', 'soybeanoil', 'maltbarley', 'soylecithin', 'cocoaprocessalkali', 'cocoa', 'milk', 'flavormilkiwaybrandminimilkchocolsugar', 'pgpr', 'flavorsnickerbrandminimilkchocolsugar', 'sugar', 'flavormusketbrandminimilkchocolsugar', 'flavor', 'peanut', 'iron', 'chocol', 'milkiwaymidnightminichocolsugar', 'chocolprocessalkali', 'chocol', 'cocoabutter', 'milkfat', 'soylecithin', 'flavor', 'cornsyrup', 'sugar', 'palm oil', 'milkfat', 'chocolmilk', 'cocoabutter', 'flavor', 'niacin', 'starchmodifi', 'milkfat', 'dextros', 'eggwhite', 'lactos', 'milkiwaymidnightminichocolsugar', 'chocolprocessalkali', 'chocol', 'cocoabutter', 'milkfat', 'soylecithin', 'flavor', 'soylecithin', 'bakesoda', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Gold Emblem Sweet And Salty Almond Chewy Granola Bars, 6 CT', 'Ingredients': ['cashewbutter', 'peanutbutter', 'almond', 'yogurtflavorcoat', 'crisprice', 'almondbutter', 'flavor', 'flavor', 'canolaoil', 'fructos', 'glycerin', 'wheatflake', 'honey', 'salt', 'cornsyrup', 'granola', 'peanut', 'palm oil', 'salt', 'almond', 'coconut', 'ricestarch', 'oat', 'water', 'vanillaextract', 'treenut', 'sunflowoil', 'soy', 'cashewnut', 'milk', 'sugar', 'palm oil'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Madelaine Premium Solid Milk Chocolate Race Cars Wrapped In Italian Foil (Race Cars', 'Ingredients': ['milkchocolsugar', 'milkcocoabutter', 'chocol', 'soylecithinemulsifi', 'vanillinflavor', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'UnTapped Organic Raspberry Waffle', 'Ingredients': ['wheatflour', 'maplsyrupsugar', 'palm oil', 'invertmaplsyrup', 'soyflour', 'raspberri', 'riceextract', 'seasalt', 'soylecithin', 'bakesoda'], 'Prediction': 1, 'Label': 1}
# {'Product': 'ZonePerfect High Protein Nutrition Bars', 'Ingredients': ['chocolalmondsoyproteinnuggetisolsoyprotein', 'cocoaprocessalkali', 'tapiocastarch', 'salt', 'chocolflavorcoatsugar', 'palm oil', 'cocoaprocessalkali', 'soylecithin', 'vanilla', 'cornsyrup', 'roastalmondalmond', 'safflowoil', 'soyprotein', 'fructossyrup', 'chocolcocoa', 'sugar', 'chocolliquor', 'cocoabutter', 'soylecithin', 'vanilla', 'chocolcookipiecbleachwheatflour', 'sugar', 'cocoaprocessalkali', 'sunflowoil', 'salt', 'bakesoda', 'chocolliquor', 'cocoafructosfructos', 'water', 'cornmaltodextrin', 'cocoaprocessalkali', 'cocoa', 'salt', 'carrageenan', 'flavor', 'tocopherol', 'ascorbacid', 'cocoa', 'oleicsafflowoleicsunflowoildoublchocolsoyproteinnuggetisolsoyprotein', 'cocoaprocessalkali', 'tapiocastarch', 'salt', 'chocollayercornsyrup', 'sugar', 'palm oil', 'chocol', 'invertsugar', 'cocoaprocessalkali', 'milkprotein', 'soylecithin', 'salt', 'xanthangum', 'carobseedgum', 'gumarab', 'vanillaextractotherflavor', 'chocolflavorcoatsugar', 'palm oil', 'cocoaprocessalkali', 'soylecithin', 'vanilla', 'cornsyrup', 'soyprotein', 'chocoldropsugar', 'chocolliquor', 'cocoabutter', 'soylecithin', 'vanilla', 'fructossyrup', 'chocolliquor', 'cocoa'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Wickedly Prime Nut Bar', 'Ingredients': ['driroastpeanut', 'driroastalmond', 'chocolflavorcoatsugar', 'palm oil', 'cocoa', 'cocoa', 'drimilk', 'whey', 'lactos', 'soylecithin', 'vanillaextract', 'walnut', 'chicorirootextract', 'peaproteincrisppeaprotein', 'ricestarch', 'honey', 'invertsugar', 'sunflowoil', 'seasalt', 'chocol', 'flavor', 'agar', 'mixtocopherolrosemariextractpeanut', 'milk', 'soy', 'almond', 'walnutpackonshareothertreenutbrazilnut', 'cashew', 'pecan', 'coconut'], 'Prediction': 0, 'Label': 1}
# {'Product': "Entenmann's Variety Pack Donuts", 'Ingredients': ['water', 'caramelcolorcrumbdonutsugar', 'eggyolk', 'betacaroten', 'color', 'cocoa', 'sodiumaluminumphosphat', 'cottonse', 'cellulosgum', 'caramel', 'maltbarleyflour', 'egg', 'soyflour', 'riboflavin', 'palm oil', 'cornsyrup', 'potassiumsorbat', 'sodiumaluminumsulfat', 'palm oil', 'sodiumaluminumphosphat', 'cornstarch', 'richfrostdonutsugar', 'cinnamon', 'monodiglycerid', 'palmitglazedonutsugar', 'molass', 'pregelatinwheatstarch', 'iron', 'calciumsulfat', 'caramelcolor', 'xanthangum', 'calciumcarbon', 'niacin', 'dextros', 'tapiocadextrin', 'cocoa', 'starch', 'eggwhiteglazedonutsugar', 'cornstarch', 'milk', 'calciumpropion', 'caramelcolorplainoldfashiondonutwheatflourflour', 'thiaminmononitr', 'whey', 'guargum', 'soyfloorvegetshortensoybean', 'leavenbakesoda', 'soylecithin', 'karayagum', 'folicacid', 'richfrostdonutsugar', 'soybeanoil', 'betacarotenplainoldfashiondonutwheatflourflour', 'sorbitanmonostear', 'sodiumphosphat', 'dextrin', 'vegetoil', 'wheatflourflour', 'preservpotassiumsorbat', 'calciumpropion', 'sodiumbenzoat', 'glycerin', 'caramelcolorglazedonutsugar', 'salt', 'polysorb', 'potassiumsorbat', 'richfrostdonutsugar', 'wheatflourflour', 'maltbarleyflour', 'iron', 'niacin', 'thiaminmononitr', 'riboflavin', 'folicacid', 'palm oil', 'water', 'palm oil', 'cocoa', 'soybeanoil', 'milk', 'soyflour', 'artifici', 'eggyolk', 'leavenbakesoda', 'sodiumacidpyrophosph', 'sodiumaluminumphosphat', 'fructoscornsyrup', 'dextros', 'salt', 'pregelatinwh', 'riboflavin', 'caramelcolorplainoldfashiondonutwheatflour', 'sugar', 'betacarotencrumbdonutsugar', 'buttermilk', 'carobbeangum', 'fructoscornsyrup', 'sodiumacidpyrophosph', 'crumbdonutsugar', 'cornsyrupsolid', 'agar', 'preservpotassiumsorbat', 'betacaroten', 'thiaminmononitr', 'preservpotassiumsorbat', 'leavenbakesoda', 'sodiumacidpyrophosph', 'sodiumaluminumphosphat', 'sodiumaluminumsulfat', 'artifici', 'monodiglycerid', 'glazesugar', 'wheatflourflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'water', 'vegetshorten', 'soybeanoil', 'soyflour', 'leavenbakesoda', 'sodiumacidpyrophosph', 'sodiumaluminumphosphat', 'sodiumaluminumsulfat', 'glycerin', 'starchmodifi', 'artifici', 'milk', 'cornstarch', 'cornsyrupsolid', 'salt', 'eggyolk', 'whey', 'dextros', 'buttermilk', 'tapiocastarch', 'polyglycerolesterfattiacid', 'potassiumsorbat', 'cellulosgum', 'xanthangum', 'milkprotein', 'wheyprotein', 'wheatprotein', 'calciumcarbon', 'soylecithin', 'guargum', 'monodiglycerid', 'locustbeangum', 'agar', 'betacaroten', 'sorbitanmonostearrichfrostsugar', 'wheatflourflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'water', 'vegetshorten', 'vegetshorten', 'cocoa', 'soybeanoil', 'palm oil', 'maltodextrin', 'invertsugar', 'soyflour', 'leavenbakesoda', 'sodiumacidpyrophosph', 'sodiumaluminumphosphat', 'sodiumaluminumsulfat', 'glycerin', 'starchmodifi', 'milk', 'cornsyrupsolid', 'salt', 'artifici', 'eggyolk', 'whey', 'dextros', 'buttermilk', 'tapiocastarch', 'soylecithin', 'polyglycerolesterfattiacid', 'potassiumsorbat', 'cellulosgum', 'xanthangum', 'milkprotein', 'wheyprotein', 'wheatprotein', 'guargum', 'sorbitantristear', 'monodiglycerid', 'locustbeangum', 'betacarotencrumbdonutsugar', 'wheatflourflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'water', 'vegetshorten', 'vegetoil', 'dextros', 'soyflour', 'starchmodifi', 'leavenbakesoda', 'sodiumacidpyrophosph', 'sodiumaluminumphosphat', 'sodiumaluminumsulfat', 'cornstarch', 'glycerin', 'artifici', 'salt', 'milk', 'cornsyrupsolid', 'eggyolk', 'whey', 'buttermilk', 'tapiocastarch', 'interesterifisoybeanoil', 'molass', 'monodiglycerid', 'color', 'cinnamon', 'preservpotassiumsorbat', 'calciumpropion', 'sodiumbenzoat', 'polyglycerolesterfattiacid', 'cellulosgum', 'xanthangum', 'milkprotein', 'wheyprotein', 'soylecithin', 'wheatprotein', 'calciumcarbon', 'guargum', 'locustbeangum', 'wheatstarch', 'agar', 'betacaroten', 'sorbitanmonostear ...
# {'Product': 'Russell Stover Pecan Delight', 'Ingredients': ['consistmilkchocolsugar', 'wholemilk', 'cocoabutter', 'chocol', 'soylecithin', 'vanillin', 'pecan', 'cornsyrup', 'dairicream', 'sugar', 'condensmilk', 'palm oil', 'invertsugar', 'brownsugar', 'salt', 'flavor', 'soylecithin', 'wholemilk', 'condensmilk', 'dairicream', 'chocol', 'cocoabutter', 'invertsugar', 'flavor', 'vanillin', 'palm oil', 'salt', 'soylecithin', 'cornsyrup', 'consistmilkchocolsugar', 'wholemilk', 'cocoabutter', 'chocol', 'soylecithinanemulsifi', 'vanillinanflavor', 'pecan', 'cornsyrupdairicream', 'sugar', 'palm oil', 'invertsugar', 'brownsugar', 'salt', 'flavor', 'soylecithinanemulsifi', 'pecan', 'consistmilkchocolsugar', 'soylecithin', 'sugar', 'brownsugar', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Pop Tarts Gone Nutty! Peanut Butter Flavor Toaster Pastries', 'Ingredients': ['palmit', 'sodiumstearoyllactyl', 'wheat', 'folicacid', 'palm oil', 'redlake', 'glycerin', 'twofructos', 'peanutbutterpeanut', 'salt', 'cornsyrup', 'almondbutter', 'yellowlake', 'sodiumaluminumphosphat', 'sugar', 'leavenbakesoda', 'sodiumaluminumphosphat', 'flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'cornsyrup', 'fructoscornsyrup', 'peanutbutter', 'sugar', 'palm oil', 'glycerin', 'twofructos', 'cornstarch', 'molass', 'salt', 'flavor', 'leavenbakesoda', 'sodiumaluminumphosphat', 'milk', 'sodiumstearoyllactyl', 'dextros', 'soylecithin', 'datem', 'monoanddiglycerid', 'yellowlake', 'carrageenan', 'redlake', 'niacinamid', 'bluelake', 'iron', 'palmit', 'tbhq', 'almondbutter', 'milk', 'fructoscornsyrup', 'flavor', 'niacinamid', 'peanut', 'molass', 'tbhq', 'iron', 'cornstarch', 'flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'flourwheatflour', 'niacin', 'dextros', 'riboflavin', 'milk', 'datem', 'monodiglycerid', 'thiaminmononitr', 'leavenbakesoda', 'soylecithin', 'wheat', 'soyalmond', 'carrageenan', 'peanutbutterpeanut', 'peanutoil', 'tbhq', 'peanutoil', 'bluelake', 'peanut', 'palm oil', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': '100 Grand Fun Size Stand Up Bag', 'Ingredients': ['salt', 'cocoabutter', 'chocol', 'lactos', 'coconutoil', 'flavor', 'monoanddiglycerid', 'milkchocolsugar', 'cocoabutter', 'chocol', 'milk', 'lactos', 'milkfat', 'soylecithin', 'flavor', 'milkchocolsugar', 'sugar', 'salt', 'soylecithin', 'butter', 'flavor', 'milk', 'milkchocolsugar', 'cocoabutter', 'chocol', 'milk', 'lactos', 'milkfat', 'soylecithin', 'flavor', 'sugar', 'cornsyrup', 'milk', 'crispricericeflour', 'sugar', 'barleymalt', 'salt', 'coconutoil', 'butter', 'monoanddiglycerid', 'salt', 'soylecithin', 'flavor', 'barleymalt', 'flavor', 'cornsyrup', 'milkfat', 'crispricericeflour', 'crispricericeflour', 'sugar', 'barleymalt', 'salt', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Schar Gluten Free Breadsticks 3 x 50g', 'Ingredients': ['potatostarch', 'riceflour', 'maizstarch', 'yeast', 'buckwheatflour', 'palm oil', 'glucosefructossyrup', 'sugar', 'salt', 'thickenhydroxypropylmethylcellulos', 'emulsifimonodiacetyltartaracidestermonodiglyceridfattiacid', 'raisammoniumhydrogencarbon', 'flavour'], 'Prediction': 0, 'Label': 1}
# {'Product': "HERSHEY'S Chocolate Candy Bars", 'Ingredients': ['palm oil', 'emulsifisaltdisodiumphosphatpotassiumsorbatcarrageenan', 'palm oil', 'maintaincarrageenannegligsugar'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Bear Naked Peanut Butter Granola - Non-GMO', 'Ingredients': ['wholegrainoat', 'honey', 'peanutbutter', 'peanut', 'expelpresssunflowoil', 'brownrice', 'canesugar', 'oatbran', 'peanutflour', 'seasalt', 'peanut', 'palm oil', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Oreo Brownie', 'Ingredients': ['oreochocolcookiflourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'oleiccanolacanolaoil', 'cocoa', 'fructoscornsyrup', 'leaven', 'salt', 'soylecithin', 'vanillinanflavor', 'sugar', 'flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'palm oil', 'soybeanoil', 'cornsyrup', 'fructos', 'calciumcarbon', 'glycerin', 'eggwhite', 'milk', 'cocoa', 'palm oil', 'chocol', 'soylecithin', 'cornstarch', 'milk', 'bakesoda', 'salt', 'flavor', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Millville Chewy Dipped Chocolate Cover Granola Bar (Chocolate Chip)', 'Ingredients': ['milkchocolflavorcoatsugar', 'palm oil', 'whey', 'lactos', 'cocoa', 'cocoa', 'soylecithinanemulsifi', 'flavor', 'cornsyrup', 'granolawholerolloat', 'wheatflake', 'cornsyrup', 'sugar', 'canolasoybeanoil', 'honey', 'molass', 'salt', 'soylecithinanemulsifi', 'crispricericeflour', 'sugar', 'calciumcarbon', 'salt', 'chocolchipsugar', 'chocolliquor', 'anhydrdextros', 'cocoabutter', 'wholemilk', 'soylecithinanemulsifi', 'salt', 'flavor', 'canolasoybeanoil', 'sugar', 'glycerin', 'coconut', 'fructos', 'honey', 'salt', 'ascorbacid', 'citricacid', 'rosemariextract', 'peanut', 'almond', 'cashew', 'flavor'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Bulletproof Bars Collagen Protein', 'Ingredients': ['cashewbutter', 'grassfcollagenprotein', 'chicorirootfiber', 'palm oil', 'tapiocadextrin', 'tapioca', 'cashew', 'bulletproofbrainoctanoil', 'coconutoil', 'labtestvanillabean', 'seasalt', 'steviacashew', 'coconut'], 'Prediction': 1, 'Label': 1}
# {'Product': "Whitman's Sampler Assorted Chocolates", 'Ingredients': ['water', 'sorbitol', 'cashew', 'sulfurdioxidpreserv', 'cherricherri', 'dairicream', 'fdcred', 'flavor', 'flavor', 'palm oil', 'fdcred', 'soylecithinanemulsifi', 'cornsyrup', 'citricacid', 'preservsodiumbenzoatpotassiumsorbat', 'molass', 'peanut', 'spice', 'cocoabutter', 'nutalmond', 'invertsugar', 'honey', 'walnut', 'tocopherol', 'whitechocolsugar', 'carnaubawax', 'confectionglaze', 'sulfurdioxidpreserv', 'condensmilk', 'gumarab', 'eggalbumen', 'flavorsalt', 'coconutsodiummetabisulfit', 'chocolsugar', 'chocol', 'chocolprocessalkali', 'cocoabutter', 'wholemilk', 'milk', 'soylecithin', 'salt', 'chocolsugar', 'chocolprocessalkali', 'sugar', 'brownsugar', 'fdcred', 'wholemilk', 'fdcred', 'butter', 'chocol', 'invertas', 'tapiocaflour', 'monodiglyceridcitricacidhelp', 'milk', 'vanillavanillinanflavor', 'pecan', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Toblerone Chocolate Bar, 1.76 oz. Bars, 20 Bars/Box', 'Ingredients': ['eggwhitemilk', 'almond', 'chocol', 'egg', 'cocoabutter', 'milkfat', 'vanillin', 'honey', 'almond', 'milkchocolsugar', 'soylecithin', 'soy', 'sugar', 'milk', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Spam Chorizo', 'Ingredients': ['porkmechanseparchicken', 'water', 'salt', 'potatostarch', 'sugar', 'chilichilipepper', 'spice', 'paprika', 'sodiumphosphat', 'potassiumchlorid', 'sodiumdiacet', 'palm oil', 'oleoresinpaprika', 'sodiumnitrit'], 'Prediction': 0, 'Label': 1}
# {'Product': 'ProtiDIET Delicious Protein Bar Nutritious Low Fat and Carb Snack With High Vitamins and Minerals Healthy and Energizing Small Meal Assists In Weight Loss (Old Fashion Strawberry and Peanut)', 'Ingredients': ['soynuggetisolsoyprotein', 'tapiocastarch', 'peanutcoatsugar', 'palm oil', 'defatpeanutflour', 'wheyprotein', 'minerwheyprotein', 'soylecithin', 'salt', 'flavor', 'strawberrijammaltitolsyrup', 'water', 'glycerin', 'strawberri', 'strawberri', 'canolaoil', 'appl', 'cornstarch', 'palm oil', 'pectin', 'citricacid', 'monodigiycerid', 'salt', 'sodiumcitrat', 'soylecithin', 'flavor', 'polydextros', 'maltitolsyrup', 'hydrolyzgelatin', 'soyprotein', 'glycerin', 'peanutbutterdriroastpeanut', 'salt', 'cornsyrup', 'wheyprotein', 'fructoscornsyrup', 'peanutflour', 'soylecithin', 'peanutoil', 'natur', 'palm oil', 'peanutextract', 'salt', 'sucralos', 'mixtocopherolmilk', 'soybean', 'peanutthimanufacturafacil', 'usetreenut', 'wheategg'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Keebler Cookies', 'Ingredients': ['flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'vegetoilsoybean', 'palmpalmkernel', 'palm oil', 'coconut', 'dextros', 'wholegrainoat', 'cornstarchinvertsugar', 'cocoa', 'salt', 'whey', 'cocoaprocessalkali', 'leavenbakesoda', 'monocalciumphosphat', 'soylecithin', 'flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'vegetoilsoybean', 'palm oil', 'palm oil', 'coconut', 'dextros', 'wholegrainoat', 'cornstarch', 'twoinvertsugar', 'cocoa', 'salt', 'whey', 'leavensoda', 'monocalciumphosphat', 'cocoaprocessalkalisoylecithin', 'flavor'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Martha White Muffin Baking Mix', 'Ingredients': ['bleachflourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'blueberribitdextros', 'palm oil', 'pregelatinyellowcornflour', 'citricacid', 'flavor', 'bluelake', 'redlake', 'strawberribitdextros', 'palm oil', 'pregelatinyellowcornflour', 'citricacid', 'flavor', 'redlake', 'yellowlake', 'bluelake', 'dextros', 'canolaoil', 'leavenbakesoda', 'sodiumaluminumphosphat', 'cornstarch', 'calciumcarbon', 'propylenglycolesterfattiacid', 'monodiglycerid', 'salt', 'cornstarch', 'sodiumstearoyllactyl', 'calciumsulfat', 'niacin', 'iron', 'hydrochlorid', 'bhtcitricacid', 'riboflavin', 'thiaminmononitr'], 'Prediction': 1, 'Label': 1}
# {'Product': 'purely elizabeth Ancient Grain Granola', 'Ingredients': ['seasalt', 'na', 'sail', 'palm oil', 'glutenfreoat', 'chiaseed', 'glutenfreoat', 'coconutpalmsugar', 'rawvirgincoconutoil', 'sunflowseed', 'pufamaranth', 'milletflake', 'quinoaflake', 'chiaseed', 'cinnamon', 'salt', 'pufamaranth', 'glutenfreoat', 'sunflowseed', 'oat', 'quinoaflake', 'cinnamon', 'milletflake', 'chiaseed', 'cinnamon', 'pufamaranth', 'coconutsugar', 'pufamaranth', 'sunflowseed', 'coconutpalmsugar', 'coconutoil', 'rawvirgincoconutoil', 'sunflowseed', 'quinoaflake', 'cinnamon', 'quinoaflake', 'seasalt', 'chiaseed'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Ferrero Rocher Fine Hazelnut Milk Chocolate', 'Ingredients': ['milkchocolsugar', 'cocoabutter', 'cocoa', 'milk', 'butteroil', 'lecithinasemulsifi', 'vanillinanflavor', 'hazelnut', 'sugar', 'palm oil', 'wheatflour', 'whey', 'cocoa', 'lecithinasemulsifi', 'sodiumbicarbonasleaven', 'salt', 'vanillinanflavor', 'milkchocolsugar', 'cocoabutter', 'cocoa', 'milk', 'butteroil', 'lecithinasemulsifi', 'vanillinanflavor', 'hazelnut', 'surgar', 'palm oil', 'wheatflour', 'whey', 'cocoa', 'lecithinasemulsifisoy', 'sodiumbicarbonasleaven', 'salt', 'vanillinanflavor'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Protein One 90 Calorie', 'Ingredients': ['chicorirootextract', 'soyprotein', 'wheyprotein', 'maltitol', 'vegetglycerin', 'maltitolsyrup', 'milkprotein', 'palm oil', 'hydrolyzmilkprotein', 'peanutflour', 'calciumcasein', 'dutchcocoa', 'water', 'soylecithin', 'milksolid', 'peanutbutter', 'salt', 'peanutoil', 'flavor', 'steviaextractmilk', 'soy', 'peanutwheat', 'treenut', 'sesamegg', 'peanut', 'palm oil', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': "Hershey's Kisses with Candy Cane Flavored White Chocolate Candy", 'Ingredients': ['sugarvegetoilcocoabutter', 'palm', 'shea', 'sunflowsafflowoilmilkcornsyrupsolidmilkcornstarchsoylecithinoilpeppermintcolorresinglazevanillin', 'flavortocopherol', 'maintainpgpr', 'emulsificarnaubawax', 'palm oil', 'flavorcolorredlakeredpgprcarnaubawax', 'sugar', 'vegetoilcocoabutter', 'palm', 'shea', 'sunflowsafflowoil', 'milk', 'cornsyrupsolid', 'milkcornstarch', 'soylecithin', 'oilpeppermint', 'color', 'resinglaze', 'vanillin', 'flavor', 'tocopherolmaintain', 'pgpremulsifi', 'carnaubawax'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Tom and Luke Snackaballs: Whole Food Fruit and Nut Protein Balls Variety Pack – 3x Salted Caramel and 3x Peanut Butter and Cacao Bliss Balls - Refined Sugar Free', 'Ingredients': ['date', 'peanut', 'cashewnut', 'peaprotein', 'peanutbutter', 'cacao', 'coconut', 'raisin', 'caramelflavour', 'seasalt', 'peanut', 'palm oil', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': "LENNY and LARRY'S Triple Chocolate Muscle Brownie", 'Ingredients': ['water', 'vegetglycerin', 'vanillaalmond', 'chocolchunksugar', 'soybeanlecithin', 'proteinwheyprotein', 'whey', 'palm oil', 'palm oil', 'salt', 'monodiglycerid', 'wheatstarch', 'wheyprotein', 'cornsyrupdud', 'palm oil', 'wheatflour', 'butterbetacaroten', 'solublcornfiber', 'cocoasugar', 'peanut', 'drimilk', 'cocoaprocessalkali', 'soyprotein', 'vanilla', 'palmit', 'soylecithin', 'bakesoda', 'soybeanoil'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Faith Cookies, 1 OZ, 85CT', 'Ingredients': ['palm oil', 'vegetshorten', 'flavor', 'soylecithin', 'wholeeggsolid', 'canolaoil', 'fructoscorisyrup', 'bleachwheatflour', 'soybeanoil', 'sugar'], 'Prediction': 0, 'Label': 1}
# {'Product': "Annie's Homegrown Cookie Bites", 'Ingredients': ['wheatflour', 'chocolchipcanesugar', 'chocol', 'cocoabutter', 'vanillaextract', 'canesugar', 'wholegrainoatflour', 'palm oil', 'expellerpresssunflowoil', 'invertcanesyrup', 'seasalt', 'molass', 'leavenbakesoda', 'ammoniumbicarbon', 'mixtocopherol', 'flavor', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Mauna Loa Hawaiian Roasted Macadamia Nuts (Honey Siracha', 'Ingredients': ['palm oil', 'gumarab', 'spice', 'driroastmacadamianut', 'honeysirachasugar', 'maltodextrin', 'salt', 'spice', 'tomato', 'garlic', 'vinegar', 'torulayeast', 'honey', 'citricacid', 'tomato', 'flavor', 'maltodextrin', 'yeastextract', 'onion', 'soybeanoil', 'tricalciumphosphat', 'paprikaoleoresin', 'gumarab', 'palm oil', 'sunflowoil', 'cornoil', 'driroastmacadamianut', 'yeastextract', 'vinegar', 'flavor', 'tomato', 'salt', 'honey', 'onion', 'tomato', 'torulayeast', 'garlic', 'maltodextrin', 'paprikaoleoresin', 'cornoil', 'honeysrirachasugar', 'sunflowoil', 'citricacid', 'soybeanoil', 'tricalciumphosphat'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Starburst Minis Fruit Chews Candy Bag, 8 OZ', 'Ingredients': ['starburstfaverminifruitchewcandibag', 'sorbitol', 'gumbase', 'glycerolflavor', 'starchhydrolys', 'aspartameacesulfam', 'soylecithin', 'mannitol', 'aspartam', 'malicacid', 'citricacid', 'sucralos', 'fumaracid', 'bht', 'colorred', 'redlakephenylketonurphenylalanin', 'aspartameacesulfam', 'blue', 'dextrin', 'redlakephenylketonurphenylalanin', 'starchhydrolys', 'flavor', 'aspartam', 'sucralos', 'colorred', 'cornsyrup', 'gelatin', 'bht', 'mannitol', 'sorbitol', 'glycerolflavor', 'appl', 'gumbase', 'citricacid', 'sugar', 'palm oil', 'starburstfaverminifruitchewcandibag', 'ascorbacid', 'fumaracid', 'starchmodifi', 'colorred', 'malicacid', 'citricacid', 'soylecithin'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Haribo Starmix Gummi Candy', 'Ingredients': ['flavor', 'red', 'tartaracid', 'yellow', 'blue', 'glucossyrup', 'cornstarch', 'caramel', 'malicacid', 'palm oil', 'dextros', 'gelatin', 'carnaubawax', 'whitebeewax', 'sugar', 'citricacid'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Cadbury Chocolate Eclairs 1lb/454g', 'Ingredients': ['glucossyrup', 'sugar', 'wholemilk', 'palm oil', 'cocoabutter', 'cocoa', 'milk', 'whey', 'milk', 'emulsifi', 'salt', 'acidregul', 'flavournut'], 'Prediction': 1, 'Label': 1}
# {'Product': "M and M'S Ice Cream Sandwich", 'Ingredients': ['carrageenan', 'soybeanoil', 'betacaroten', 'flavor', 'cocoaprocessalkali', 'soylecithin', 'palmit', 'palm oil', 'icecreammilk', 'molass', 'colorincludbluelake', 'red', 'yellow', 'yellow', 'blue', 'redlake', 'yellowlake', 'yellowlake', 'bluelake', 'blue', 'palm oil', 'monodiglycerid', 'carnaubawax', 'water', 'flavor', 'cornstarch', 'sodiumacidpyrophosph', 'monocalciumphosphat', 'palmitcookiwheatflourbleachwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folat', 'whey', 'mmbrandminimilkchocolcandimilkchocolsugar', 'chocol', 'milk', 'cocoabutter', 'lactos', 'milkfat', 'soylecithin', 'salt', 'flavor', 'sugar', 'salt', 'cream', 'bakesoda', 'cornsyrup', 'cellulosgum', 'guargum', 'ammoniumbicarbon', 'dextrin', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Quaker Chewy Chocolate Chip Granola Bars', 'Ingredients': ['sodiumbicarbon', 'water', 'granola', 'granolawholegrainrolloat', 'chocolchipsugar', 'caramel', 'salt', 'vanillaextract', 'maltbarleyflour', 'glycerin', 'salt', 'cornsyrup', 'wholegrainrollwheat', 'soybeanoilsorbitol', 'sugar', 'bht', 'brownsugar', 'flavor', 'chocolliquor', 'citricacid', 'granolawholegrainrolloat', 'brownsugar', 'crisprice', 'molass', 'drimilk', 'cornsyrupsolid', 'calciumcarbon', 'coconut', 'cocoabutter', 'invertsugar', 'crispricericeflour', 'brownricecrispwholegrainbrownrice', 'wholewheatflour', 'soylecithin', 'soybeanoil', 'maltbarleyextract', 'almond', 'coconut', 'ricestarch', 'oat', 'water', 'vanillaextract', 'treenut', 'sunflowoil', 'soy', 'cashewnut', 'milk', 'sugar', 'palm oil'], 'Prediction': 0, 'Label': 1}
# {'Product': 'El Monterey Beef and Bean Burritos – Family Pack of 8 Frozen Burritos', 'Ingredients': ['water', 'soybean', 'calciumlactat', 'riboflavin', 'folicacid', 'chilipepper', 'spice', 'salt', 'wheatflourniacin', 'canolacornoil', 'water', 'chilipepper', 'iron', 'doughconditionyeast', 'canola', 'palm oil', 'wheatflourniacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'salt', 'guargum', 'spice', 'beef', 'waterwheatflourniacin', 'soysaucwheat', 'starch', 'vegetoilsoybean', 'canola', 'palm oil', 'salt', 'isolpea', 'salt', 'wheatgluten', 'soysaucwheat', 'soybean', 'salt', 'maltodextrin', 'lacticacid', 'calciumlactat', 'salt', 'vegetproteinsoyflour', 'caramel', 'beef', 'caramel', 'sugar', 'isolpea', 'bean', 'savoriyeastextract', 'lacticacid', 'vegetoilsoybean', 'vegetproteinsoyflour', 'soysaucwheat', 'water', 'wheatflourniacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'beef', 'bean', 'vegetoilsoybean', 'sunflow', 'canolacornoil', 'vegetproteinsoyflour', 'caramel', 'isolpea', 'salt', 'riceflour', 'yeast', 'cellulosgum', 'guargum', 'wheat', 'sodiumbicarbon', 'wheatstarch', 'starch', 'doughconditionsodiummetabisulfit', 'sodiumstearoyllactyl', 'lcystein', 'monodiglycerid', 'dicalciumphosphat', 'microcrystallincellulos', 'silicondioxid', 'chilipepper', 'yeastextract', 'maltodextrin', 'spice', 'soysauc', 'autolyzyeastextract', 'lacticacid', 'flavor', 'calciumlactat', 'salt', 'bean', 'maltodextrin', 'sodiummetabisulfit', 'savoriyeastextract', 'folicacidbeefbeanvegetoilsoybean', 'thiaminmononitr', 'doughconditionyeast', 'wheatgluten', 'sugar', 'guargum', 'starch', 'sodiummetabisulfit'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Pinwheels Fudge and Marshmallow Chocolate Covered Cookies', 'Ingredients': ['sweetchocolcoatsugar', 'cocoabutter', 'chocol', 'soylecithin', 'flavor', 'salt', 'milk', 'cornsyrup', 'flourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'fructoscornsyrup', 'sugar', 'water', 'canolaoil', 'cocoa', 'palm oil', 'gelatin', 'bakesoda', 'salt', 'caramel', 'flavor', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': "REESE'S Peanut Butter Cup Miniatures", 'Ingredients': ['vegetoilpeanut', 'sodiumcasein', 'chocol', 'emulsififlavorsucralostbhq', 'tbhq', 'pgpr', 'milkcream', 'saltsoylecithinsodiumcasein', 'palm oil', 'polydextros', 'salt', 'sucralos', 'maltitol', 'palm oil', 'maltitolpeanutchocolcocoabutterlactitol', 'cellulosgel', 'pgpr', 'maltitolpeanutchocolcocoabutterlactitolcellulosgelpolydextrosvegetoilpeanut', 'palm oil', 'maintainnegligsugar', 'flavor', 'negligsugar', 'peanut', 'emulsififlavorsucralostbhqnegligsugar', 'cocoabutter', 'cream', 'milk', 'maltitolpeanutchocolcocoabutterlactitolcellulosgelpolydextrosvegetoilpeanut', 'palm oil', 'lactitol', 'soylecithin', 'emulsififlavorsucralostbhq', 'cellulosgelpolydextrosvegetoilpeanut', 'palm oil', 'maltitolpeanutchocolcocoabutterlactitolcellulosgelpolydextrosevegetoilmilkfatcontaincreamsaltsoylecithinsodiumcaseinpgprflavorsucralosetbhq', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'NOOMA Organic Electrolyte Sports Drink Naturally Effective Workout Hydration Certified Keto', 'Ingredients': ['filterwater', 'coconutwater', 'chocol', 'seasalt', 'stevialeafextract', 'mint', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Skittles Love Valentines Mix 11 Ounce Bag - Pack of Two', 'Ingredients': ['tapiocadextrin', 'flavor', 'colorinclud', 'redlake', 'titaniumdioxid', 'bluelake', 'bluelake', 'red', 'yellow', 'blue', 'sodiumcitrat', 'palm oil', 'carnaubawax', 'cornstarch', 'cornsyrup', 'sugar'], 'Prediction': 1, 'Label': 1}
# {'Product': "HERSHEY'S Chocolate Candy Snack Bites", 'Ingredients': ['lecithin', 'milkchocolcanesugar', 'milk', 'almond', 'chocol', 'flavor', 'cocoabutter', 'flavor', 'milkchocolcanesugar', 'sunflowoil', 'milk', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Limited Edition! Kelloggs Special K Pumpkin Spice Crunch Value Size 17.7oz - Two (2) Pack', 'Ingredients': ['rice', 'wholegrainwheat', 'sugar', 'wheatbran', 'palm oil', 'palmcanola', 'coconut', 'soybeancottonse', 'wholegrainoat', 'salt', 'solublwheatfiber', 'brownsugarsyrup', 'dextros', 'calciumcarbon', 'flavor', 'malt', 'wheatflour', 'cinnamon', 'spice', 'soylecithin', 'honey', 'molass', 'ginger', 'nutmeg', 'allspic', 'bakesoda', 'annattoextract', 'mixtocopherol', 'paprikaextractcolorvitaminminer', 'iron', 'niacinamid', 'palmit', 'folicacid'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Bahlsen Leibniz Butter Biscuit Cookies (6 boxes) Our classic original buttery biscuits (7 ounce boxes)', 'Ingredients': ['wheatflour', 'palm oil', 'sunflowoilsugar', 'salt', 'sunflowlecithin', 'milk', 'eggyolkegg', 'milk', 'soywheatalmond', 'coconut', 'hazelnut', 'walnut', 'peanutsoy'], 'Prediction': 0, 'Label': 1}
# {'Product': "Hershey's Candy Cane Mint Candy with Stripes and Candy Bits", 'Ingredients': ['palm oil', 'flavortocopherol', 'maintainpgpr', 'emulsificarnaubawax'], 'Prediction': 0, 'Label': 1}
# {'Product': "Russell Stover's All Milk", 'Ingredients': ['consistmilkchocolsugar', 'water', 'sorbitol', 'condensmilk', 'peanutbutterpeanut', 'vegetoilrapese', 'cottonse', 'soybean', 'raspberri', 'eggalbumen', 'dairicream', 'palm oil', 'soylecithinanemulsifi', 'salt', 'cornsyrup', 'potassiumsorbat', 'vanillinanflavor', 'orangpeel', 'raisin', 'tocopherol', 'cocoa', 'consistmilkchocolsugar', 'wholemilk', 'cocoabutter', 'chocol', 'soylecithin', 'vanillin', 'sugar', 'cornsyrup', 'condensmilk', 'dairicream', 'invertsugar', 'brownsugar', 'coconutsodiummetabisulfit', 'palm oil', 'walnut', 'wholemilk', 'milksolid', 'cherricherri', 'cornsyrup', 'water', 'sugar', 'citricacid', 'sodiumbenzoatpotassiumsorbat', 'sulfurdioxid', 'fdcred', 'pecan', 'peanutbutterdriroastpeanut', 'cottonseedrapeseoil', 'soyoil', 'salt', 'almond', 'molass', 'cocoaprocesspotassiumcarbon', 'confectionglaze', 'butter', 'salt', 'cocoa', 'raspberrisorbitol', 'eggalbumen', 'raisin', 'flavor', 'apricotsulfurdioxid', 'orangpeelhoney', 'strawberri', 'soylecithin', 'spice', 'maplsugar', 'invertas', 'tapiocaflour', 'fdccolorred', 'yellow', 'blue', 'sodiumbenzoatpotassiumsorbat', 'tocopherol', 'carmincolor', 'nutwalnut', 'pecan', 'almond', 'citricacid', 'sugar', 'brownsugar', 'wholemilk', 'saltmolass', 'butter', 'cherricherri', 'spice', 'chocol', 'fdcoloryellow', 'red', 'blue', 'cocoabutter', 'preservsodiumbenzoatpotassiumsorbat', 'tapiocaflour', 'maplsugar', 'invertsugar', 'coconutsodiummetabisulfit', 'honey', 'strawberri', 'invertas', 'sulfurdioxid', 'carmin', 'fdred', 'apricottracesulfurdioxid', 'flavor', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': "Reeses Peanut Butter Pink Hearts Shaped Valentine's Day Candy Gifts Chocolate Multi Pack Snack Candies For School Work Exchange Boys or Girls - Size 10.2 Ounces", 'Ingredients': ['whitechocol', 'milkchocolsugar', 'cocoabutter', 'chocol', 'palm oil', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Bear Naked Premium Dark Chocolate Hazelnut Butter Granola - Gluten Free', 'Ingredients': ['seasalt', 'chocolcanesugar', 'chocol', 'cocoabutter', 'soylecithin', 'vanillaextract', 'pumpkinseed', 'hazelnutbutter', 'honey', 'chocol', 'expelpresssunflowoil', 'wholeoatflour', 'rosemariextract', 'canesugar', 'sunflowseed', 'wholegrainoat', 'hazelnut', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Cadbury Curly Wurly British Chocolate Bar 26g x 10 bar', 'Ingredients': ['glucossyrup', 'sugar', 'palm oil', 'milk', 'cocoabutter', 'cocoa', 'whey', 'milk', 'emulsifi', 'salt', 'sodiumbicarbon', 'flavour', 'milkchocolmilksolidminimum', 'vegetfatadditcocoabutter'], 'Prediction': 1, 'Label': 1}
# {'Product': 'WW Chocolate Marshmallow Puffs - Gluten-free', 'Ingredients': ['crispwhitericeflour', 'tapiocastarch', 'yellowcornflour', 'cornstarch', 'flaxseed', 'quinoa', 'chiaseed', 'canesugar', 'compoundcoatmaltitol', 'palm oil', 'wheyprotein', 'cocoa', 'soylecithin', 'sunflowoil', 'sugar', 'flavormaltodextrin', 'gumarab', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': 'DiBella - Blueberry Lemon Biscotti (2 Pack)', 'Ingredients': ['wheatflour', 'sugar', 'egg', 'palm oil', 'blueberriinfuscranberricranberri', 'sugar', 'blueberri', 'sunflowoil', 'blueberri', 'water', 'blueberri', 'candilemonpeellemonpeel', 'sugar', 'lemonoil', 'bakegluconodeltalacton', 'sodiumbicarbon', 'monopotassiumtartrat', 'cornstarchsoybeanoil', 'flavor', 'salt', 'bakesoda', 'soylecithin'], 'Prediction': 1, 'Label': 1}
# {'Product': 'The Ginger People Gin Gins Super Strength Ginger Caramel Candy', 'Ingredients': ['canesugar', 'glucos', 'ginger', 'cassavastarch', 'palm oil', 'salt', 'soylecithinsoyproducpeanut'], 'Prediction': 0, 'Label': 1}
# {'Product': 'EnviroKidz Organic Panda', 'Ingredients': ['brownriceflour', 'brownricesyrup', 'honey', 'peanutbutter', 'invertcanesyrup', 'evaporcane', 'soyoil', 'acaciagum', 'seasalt', 'molassorgan', 'peanut', 'palm oil', 'salt'], 'Prediction': 1, 'Label': 1}
# {'Product': 'WW Triple Chocolate Baked Protein Bar - High Protein Snack Bar', 'Ingredients': ['proteinsoyprotein', 'wheyprotein', 'wheyprotein', 'palm oil', 'palmkernel', 'sugar', 'cocoa', 'vegetglycerin', 'gelatin', 'chicorirootfiber', 'water', 'drimilk', 'cornsyrup', 'flavor', 'soylecithin', 'salt', 'tapiocastarch', 'sunflowlecithin', 'bakesoda', 'almond', 'peanutmanufacturplantwheat', 'treenut', 'egg'], 'Prediction': 1, 'Label': 1}
# {'Product': "Skittles and Starburst Fun Size Valentine's Day Candy, 20.9 OZ, 50 CT", 'Ingredients': ['flavor', 'gelatinstarburstfaversugar', 'palm oil', 'redlake', 'bluelake', 'sodiumcitrat', 'cornsyrup', 'gelatin', 'yellowlake', 'appl', 'skittlsugar', 'blue', 'red', 'yellowlake', 'blueglutenfrestarburstduosugar', 'carnaubawaxgluten', 'yellow', 'carnaubawaxglutenfre', 'cornstarch', 'yellow', 'colorredlake', 'palm oil', 'gelatinfreskittlberrisugar', 'palm oil', 'tapiocadextrin', 'coloryellowlake', 'titaniumdioxid', 'colorglutenfre', 'colorred', 'blue', 'flavor', 'bluelake'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Milky Way Milk Chocolate ToGo Sharing Size Candy Bar, 3.63 OZ', 'Ingredients': ['cornsyrup', 'cocoaprocessalkali', 'salt', 'chocol', 'milkfat', 'milkchocol', 'palm oil', 'eggwhite', 'sugar', 'maltbarley', 'milk', 'lactos', 'flavor'], 'Prediction': 1, 'Label': 1}
# {'Product': "Annabelle's Rocky Road, Homemade Milk Chocolate Coated Marshmallow With Cashews", 'Ingredients': ['sorbitol', 'cashew', 'soylecithinasanemulsifi', 'flavor', 'milkchocol', 'palm oil', 'whey', 'glycerin', 'salt', 'cornsyrup', 'gelatin', 'cocoa', 'sugar', 'maltmilkcrunch', 'vanillin', 'milk'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Pepperidge Farm Pirouette Crème Filled Wafers Chocolate Fudge Cookies', 'Ingredients': ['sugar', 'wheatflour', 'palm oil', 'cocoaprocessalkali', 'maltodextrin', 'dextros', 'whey', 'milk', 'riceflour', 'caramel', 'soylecithin', 'polyglycerolesterfattiacid', 'salt', 'vanillaextract', 'coconutoil', 'monodiglycerid', 'hazelnut', 'betacarotenenzym'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Satin Ice ChocoPan Bright White Covering Chocolate', 'Ingredients': ['whitechocolsugar', 'palm oil', 'palm oil', 'drimilk', 'milk', 'glyceryllactoesterfattiacid', 'soylecithin', 'salt', 'flavor', 'cornsyrup', 'sugar', 'wateronetitaniumdioxid', 'blue', 'red', 'yellow', 'red', 'yellow'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Blue Bunny', 'Ingredients': ['cream', 'cellulosgum', 'caramel', 'whey', 'flavor', 'monodiglcyerid', 'cornflour', 'palm oil', 'salt', 'monodiglycerid', 'cornsyrup', 'soylecithin', 'icecreammilk', 'cream', 'sugar', 'cornsyrup', 'milk', 'whey', 'buttermilk', 'vanillaextract', 'flavor', 'monodiglycerid', 'carobbeangum', 'cellulosgum', 'carrageenan', 'palmitwaferwheatflour', 'sugar', 'palm oil', 'cocoaprocessalkali', 'dextros', 'caramel', 'cornflour', 'cornsyrup', 'starchmodifi', 'flavor', 'salt', 'bakesoda', 'soylecithin', 'icecreammilk', 'milk', 'sugar', 'vanillaextract', 'buttermilk', 'carobbeangum', 'flavor', 'waferwheatflour', 'flavor', 'starchmodifi', 'dextros', 'soylecithin', 'vanillaextract', 'palmit', 'cocoaprocessalkali', 'cocoaprocessalkali', 'bakesoda', 'carrageenan', 'milk', 'milk'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Pepperidge Farm Chocolate Chunk Crispy Cookies', 'Ingredients': ['wheatflourflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'semisweetchocolsugar', 'chocol', 'cocoabutter', 'dextros', 'milkfat', 'soylecithin', 'palm oil', 'pecan', 'butter', 'brownsugarsugar', 'invertsugar', 'molass', 'egg', 'maltbarleyflour', 'salt', 'bakesoda', 'creamtartar', 'flavor', 'vanillaextract', 'treenutmealalmond', 'cashew', 'macadamianut', 'walnut', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Satin Ice Navy Fondant', 'Ingredients': ['sugar', 'cornsyrup', 'water', 'palm oil', 'gumtragacanth', 'flavor', 'cellulosgum', 'cornstarch', 'potassiumsorbat', 'glycerin', 'acetacid', 'blue', 'blue', 'red', 'red', 'yellow', 'yellow'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Nabisco Oreo Cookies Single Serve', 'Ingredients': ['fructoscornsyrup', 'flour', 'flour', 'soy', 'sugar', 'salt', 'cocoa', 'leaven', 'vanillinanflavor', 'soylecithin', 'chocolwheat', 'cornstarch', 'sugarunbleachflourwheatflourniacinironthiaminmononitr', 'palm oil', 'sugar'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Lindt Excellence 70% Cocoa Dark Chocolate Bars 3.5 OZ, 6CT', 'Ingredients': ['bourbonvanillabeanpiec', 'bourbonvanillabeanpiecvaluecaloriesxafatlipidesgsaturfatgtranfatgxacholesterolmgxasodiummgcarbohydrategfibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxa', 'sugar', 'soyalecithin', 'bourbonvanillabean', 'sugar', 'chocol', 'cocoabutter', 'soyalecithin', 'bourbonvanillabeanpiecvaluecaloriesfat', 'valuecaloriesfat', 'cocoabutter', 'sugar', 'chocol', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'New! OPTIMUM NUTRITION High Protein Wafer Bars', 'Ingredients': ['proteinmilkprotein', 'hydrolyzgelatin', 'wheyprotein', 'peaprotein', 'wheatflour', 'palm oil', 'sugar', 'fructos', 'milkmilk', 'wholemilk', 'buttercocoabutter', 'chocol', 'soylecithin', 'soyflour', 'sunflowoil', 'water', 'flavor', 'salt', 'sodium', 'bicarbon', 'suralos', 'cornflour'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Almond Joy Milk Chocolate Coconut & Almonds King Size', 'Ingredients': ['almond', 'hydrolyzmilkprotein', 'flavor', 'coconut', 'cocoa', 'milkchocol', 'salt', 'palm oil', 'milkchocol', 'cornsyrupmilkchocolcoconutsugaralmondroastcocoabutter', 'caramel', 'flavor', 'vegetoil', 'sugar', 'coconut', 'maintainvanillin', 'cornsyrup', 'soylecithin', 'sodiummetabisulfitsulfurdioxidmaintain', 'almond', 'cornsyrup', 'sugar', 'whey', 'chocol'], 'Prediction': 1, 'Label': 1}
# {'Product': "Tiger's Milk Peanut Butter and Honey Protein Nutrition Bar", 'Ingredients': ['peanutbutterroastpeanut', 'salt', 'fructoscornsyrup', 'honey', 'carobcoatsugar', 'palmkernel', 'palm oil', 'carob', 'whey', 'milk', 'drimilk', 'soylecithinasanemulsifi', 'salt', 'flavor', 'drimilk', 'peanutflour', 'maltodextrin', 'cornsyrup', 'soyprotein', 'riceflour', 'brownsugar', 'calciumcasein', 'calciumphosphat', 'magnesiumphosphat', 'dextros', 'flavor', 'ferroufumar', 'niacinamid', 'calciumdpantothen', 'copperglucon', 'thiaminmononitr', 'riboflavin', 'pyridoxinhydrochlorid', 'biotin', 'salt'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Nips Chocolate Parfait Rich and Creamy Hard Candy', 'Ingredients': ['sugar', 'cornsyrup', 'milkmilk', 'milk', 'coconutoil', 'palm oil', 'whey', 'cocoacocoaprocessalkali', 'salt', 'monodiglycerid', 'flavor', 'soylecithin'], 'Prediction': 1, 'Label': 1}
# {'Product': 'It Works! Keto Coffee Pods - Salted Caramel', 'Ingredients': ['palm oil', 'drimilk', 'coffemgcaffein', 'greencoffebeanextractmgcaffein', 'grassfbutter', 'hydrolyzcollagenpeptid', 'caramel', 'himalayanpinksalt', 'silicondioxid', 'rebaudiosidea'], 'Prediction': 0, 'Label': 1}
# {'Product': 'Necco The Original Candy Wafer, 2.02 OZ', 'Ingredients': ['vegetgum', 'blue', 'sugar', 'cornsyrup', 'gelatin', 'artifici', 'vegetgum', 'chocol', 'citricacid', 'fdccolorwhichincludyellow', 'blue', 'redred', 'fdccolorwhichincludyellow', 'redred', 'artifici', 'sugar', 'chocol', 'cornsyrup', 'gelatin', 'artifici', 'vegetgum', 'citricacid', 'fdccolorwhichincludyellow', 'sugar', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': "Bisquick Shake 'n Pour Buttermilk Pancake Mix (Pack of 3) 10.6 oz Bottles", 'Ingredients': ['flourbleachwheatflour', 'maltbarleyflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'defatsoyflour', 'leavenbakesoda', 'sodiumaluminumphosphat', 'monocalciumphosphat', 'palm oil', 'dextros', 'buttermilk', 'salt', 'eggyolksodiumsilicoalumin', 'eggwhite', 'datem', 'flourbleachwheatflour', 'maltbarleyflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'sugar', 'defatsoyflour', 'leavenbakesoda', 'sodiumaluminumphosphat', 'monocalciumphosphat', 'palm oil', 'dextros', 'buttermilk', 'salt', 'eggyolksodiumsilicoalumin', 'eggwhite', 'datem', 'milk', 'milk'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Lindt Dark Chocolate, Extra Fine', 'Ingredients': ['chocol', 'cocoa', 'cocoabutter', 'bourbonvanillabean', 'sugar', 'chocol', 'cocoa', 'cocoabutter', 'sugar', 'bourbonvanillabean', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# {'Product': 'Lindt Excellence A Touch of Sea Salt Dark Chocolate Bars 3.5 OZ, 12CT', 'Ingredients': ['valuarebaseoncaloridietvaluhigherlowerdependoncalorineedsquarfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxa', 'valuecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumiron', 'valuarebaseon', 'sugar', 'soyalecithin', 'caloridietvaluhigherlowerdependoncalorineed', 'valuarebaseon', 'sugar', 'chocol', 'cocoabutter', 'milk', 'soyalecithin', 'seasalt', 'valuarebaseoncaloridietvaluhigherlowerdependoncalorineedsquarvaluecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumiron', 'caloridietvaluhigherlowerdependoncalorineedsquar', 'milk', 'seasalt', 'cocoabutter', 'sugar', 'chocol', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi', 'palm oil', 'milk', 'sugar', 'cocoa', 'cocoabutter', 'cocoa', 'emulsifi'], 'Prediction': 1, 'Label': 1}
# ...
# {'Product': "KELLOGG'S EGGO Eggo Buttermilk Pancakes Box", 'Ingredients': ['flourwheatflour', 'maltbarleyflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'water', 'fructoscornsyrup', 'vegetoilsoybean', 'palm', 'canola', 'buttermilk', 'egg', 'leavenbakesoda', 'sodiumaluminumphosphat', 'monocalciumphosphat', 'salt', 'soylecithinvitaminminerpalmit', 'iron', 'milk'], 'Prediction': 1, 'Label': 0}
# {'Product': 'La Preferida Extra Virgin Olive Oil, 17 fl oz, (Pack of 12)', 'Ingredients': ['extravirginolivoil'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Valentines Day Chocolate', 'Ingredients': ['giftbasket'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Carnation Breakfast Essentials Powder Drink Mix', 'Ingredients': ['milk', 'maltodextrin', 'sugar', 'vitaminminer', 'lactos', 'cellulosgum', 'flavorvitaminminercalciumphosphat', 'magnesiumhydroxid', 'sodiumascorb', 'ferricorthophosph', 'alphatocopherylacet', 'niacinamid', 'copperglucon', 'zincoxid', 'calciumpantothen', 'manganessulfat', 'palmit', 'pyridoxinhydrochlorid', 'thiaminmononitr', 'biotin', 'folicacid'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Lundberg California Brown Basmati Rice', 'Ingredients': ['californiabrownbasmatirice'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Organic Dried Apple Rings', 'Ingredients': ['applring'], 'Prediction': 0, 'Label': 0}
# {'Product': "Whitley's Home Cooked Salted Redskins Virginia Peanuts 20 Oz. Tin", 'Ingredients': ['peanut', 'vegetoilonecoconutoil', 'cottonseoilcanolaoil', 'salt'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Rhythm Superfoods Kale Chips', 'Ingredients': ['kale', 'sunflowseed', 'tahini', 'carrot', 'applcidervinegar', 'canesugar', 'onion', 'seasalt', 'lemon'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Laird Superfood Hydrate Coconut Water Original 8oz', 'Ingredients': ['freezedricoconutwater', 'aquamintm'], 'Prediction': 0, 'Label': 0}
# {'Product': 'KRAVE Gourmet Pork Cuts, Grilled Teriyaki Flavor, 2.7 OZ', 'Ingredients': ['water', 'soybean', 'alcoholwater', 'canesugar', 'kravegrillteriyakiporkcutpork', 'salt', 'ricewinealcohol', 'salt', 'onion', 'spice', 'granulgarlic', 'glutensoysaucwater', 'soybeanoil'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Roland Dried Mushrooms', 'Ingredients': ['shiitakmushroom'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Kale', 'Ingredients': ['raw', 'kale', 'kale'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Siete Almond Flour and Cassava Flour Mix Pack', 'Ingredients': ['almondflourtortillaalmondflour', 'tapiocaflour', 'water', 'seasalt', 'xanthangumcassavaflourtortillacassavaflour', 'water', 'coconutflour', 'coconutoil', 'applcidervinegar', 'seasalt', 'xanthangum'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Wright Brand', 'Ingredients': ['sodiumphosphat', 'sodiumnitrit', 'curewater', 'sodiumerythorb', 'sodiumphosphat', 'curewater', 'salt', 'sugar', 'sodiumphosphat', 'sodiumerythorb', 'sodiumnitrit', 'sugar', 'salt', 'salt', 'curewater', 'sodiumnitrit', 'curewater', 'sodiumphosphat', 'sugar', 'sodiumerythorb'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Frontier All Purpose Seasoning Salt-Free Blend', 'Ingredients': ['onion', 'parsley', 'basil', 'lemonpeel', 'thyme', 'garlic', 'celeriseed', 'redbellpepper', 'citricacid', 'lemon'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Philippine Brand Dried Mangoes', 'Ingredients': ['mango', 'sugarsulfurdioxidaspreserv'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Nora Seaweed Snacks Crispy Original Flavor, 1.3 OZ', 'Ingredients': ['seawe', 'salt', 'ricebranoil', 'maltodextrin', 'whitepepper', 'canesugar', 'yeastextract'], 'Prediction': 0, 'Label': 0}
# {'Product': "Chi Chi's Fiesta Restaurante Seasoning Mix 0.78 OZ(Pack of 4)", 'Ingredients': ['onion', 'salt', 'greenchile', 'garlic', 'monosodiumglutam', 'spice', 'silicondioxid'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Knorr Leek Recipe Mix', 'Ingredients': ['wheatflour', 'maltodextrin', 'onion', 'potatostarch', 'potato', 'salt', 'hydrolyzcornprotein', 'monosodiumglutam', 'soybeanoil', 'leek', 'whey', 'guargum', 'yeastextract', 'spice', 'flavor', 'turmerdisodiumguanyl', 'disodiuminosindehydratedmadmilk', 'egg', 'soy', 'wheat', 'sesam', 'sulfit', 'wheatflourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'maltodextrin', 'onion', 'potatostarch', 'potato', 'salt', 'hydrolyzcornprotein', 'oleicsunflowoil', 'leek', 'whey', 'potassiumchlorid', 'guargum', 'disodiumguanyl', 'disodiuminosin', 'lacticacid', 'soybeanoil', 'flavor', 'turmer', 'yeastextract', 'spice', 'sulfit', 'wheatflourwheatflour', 'niacin', 'iron', 'thiaminmononitr', 'riboflavin', 'folicacid', 'maltodextrin', 'onion', 'potatostarch', 'potato', 'salt', 'hydrolyzcornprotein', 'oleicsunflowoil', 'leek', 'whey', 'potassiumchlorid', 'guargum', 'disodiumguanyl', 'disodiuminosin', 'lacticacid', 'soybeanoil', 'flavor', 'turmer', 'yeastextract', 'spice', 'sulfit'], 'Prediction': 1, 'Label': 0}
# {'Product': 'Organic Dry Roasted Pumpkin Seeds with Sea Salt, 1 Pound Non-GMO Kernels, Pepitas, Kosher, Vegan, No Shell, Healthy Snack, Bulk by Food to Live', 'Ingredients': ['pumpkinseed', 'seasalt'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Red RoseTea Bags', 'Ingredients': ['orangpekopekocutblacktea', 'orangpekopekocutblacktea'], 'Prediction': 0, 'Label': 0}
# {'Product': "Junior Mints Mini's - 4.5oz", 'Ingredients': ['sugar', 'chocolsugar', 'chocolprocessalkali', 'cocoabutter', 'soylecithinanemulsifi', 'vanillinanflavor', 'cornsyrup', 'confectionglaze', 'starchmodifi', 'peppermintoil', 'invertas'], 'Prediction': 1, 'Label': 0}
# {'Product': 'Reverse Spherification Kit [Molecular Gastronomy] ⊘ Non-GMO ❤ Gluten-Free ☮ Vegan ✡ OU Kosher Certified Ingredients', 'Ingredients': ['calciumlactat', 'sodiumalgin'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Olympiana Jumbo White Greek Dried Figs SINGLE PACK- 11 oz', 'Ingredients': ['fig', 'sulfit'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Wild Bills Hickory Smoked Beef Jerky Strips', 'Ingredients': ['beef', 'soysaucwater', 'salt', 'hydrolyzsoyprotein', 'cornsyrup', 'caramel', 'potassiumsorbat', 'garlic', 'pepper', 'redpepper', 'soy'], 'Prediction': 0, 'Label': 0}
# {'Product': 'SeaBear Sasquatch Approved Smoked Wild Salmon', 'Ingredients': ['smokesalmonpinksalmon', 'salt', 'canesugar', 'woodsmoke'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Springtime Fun Dip ~ 24 pouches', 'Ingredients': ['citricacid', 'dextros', 'maltodextrin', 'citricacid', 'calciumstearat', 'flavor', 'redlake', 'redlake', 'maltodextrin', 'citricacid', 'calciumstearat', 'dextros', 'flavor'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Wild Dried Canadian Chanterelles', 'Ingredients': ['chanterel'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Whole Oats 10 Pounds Groats', 'Ingredients': ['wholeoatnothels'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Spry Xylitol Gems Mints', 'Ingredients': ['calciumglycerophosph', 'stearicacid', 'calciumcarbon', 'xylitol', 'magnesiumstearat', 'calciumcarbon', 'lemon', 'magnesiumstearat', 'xylitol', 'xylitol', 'lemon', 'turmer', 'calciumglycerophosph', 'calciumcarbon', 'magnesiumstearat', 'stearicacid', 'gemmintsugarlemoncrme', 'lemonotherflavor', 'calciumglycerophosph', 'turmer', 'turmer', 'stearicacid'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Mochiko Sweet Rice Flour', 'Ingredients': ['shortgrainsweetrice'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Organic Cashew Pieces', 'Ingredients': ['cashew'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Good Seasons Italian Dry Salad Dressing and Recipe Mix', 'Ingredients': ['sugar', 'salt', 'sodiumcitrat', 'garlic', 'onion', 'spice', 'redbellpepper', 'carrot', 'xanthangum', 'maltodextrin', 'parsley', 'guargum', 'flavor', 'soysaucwheat', 'soybean', 'salt', 'citricacid'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Lifesavers 5 Flavors Sugarfree Hard Candies, 2.75 OZ', 'Ingredients': ['sucralos', 'colorred', 'yellow', 'blue', 'cornsyrup', 'isomalt', 'stearicacid', 'sugar', 'lifesaversugarfrehardcandibag', 'soylecithinexcessconsumptlaxeffect', 'isomalt', 'citricacid', 'flavor', 'sucralos', 'colorred', 'yellow', 'blue', 'soylecithinexcessconsumptlaxeffect', 'flavor', 'citricacid', 'flavor'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Wd 40 Stops Squeaks Cleans Protects Loosens', 'Ingredients': ['propelco', 'propelco'], 'Prediction': 0, 'Label': 0}
# {'Product': 'SUN and SWELL FOODS Plant Based Cookie Bites (Oatmeal Cacao Chip) - 6 count Organic Date and Cashew Snack Cookies Gluten Free', 'Ingredients': ['datecashewoatcinnamoncacao'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Gold Emblem Roasted Garlic & Herb Seasoning Grinder, 2.8 OZ', 'Ingredients': ['seasalt', 'garlicoil', 'spice', 'parsley', 'veget', 'demerarasugar', 'citricacid'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Tamanishiki Super Premium Short Grain Rice', 'Ingredients': ['millrice'], 'Prediction': 0, 'Label': 0}
# {'Product': "Mott's For Tots Apple Juice", 'Ingredients': ['ascorbacid', 'water', 'flavor', 'appl'], 'Prediction': 0, 'Label': 0}
# {'Product': "Kellogg's Smart Start Original Antioxidants Cereal", 'Ingredients': ['acet', 'cornsyrup', 'cinnamon', 'wholegrainwheat', 'salt', 'rice', 'iron', 'barleymaltextract', 'betacaroten', 'niacinamid', 'malt', 'riceflour', 'honey', 'flavor', 'brownsugarsyrup', 'mixtocopherolvitaminminer', 'folicacid', 'sugar', 'wholegrainoat'], 'Prediction': 1, 'Label': 0}
# {'Product': "See's Candies 4 oz. Cafe Latte Little Pops", 'Ingredients': ['cornsyrup', 'cream', 'sugar', 'coffe', 'butter', 'salt'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Community Coffee - Coffee and Chicory Medium-Dark Roast - 72 Count Single Serve Coffee Pods - Compatible with Keurig 2.0 K Cup Brewers', 'Ingredients': ['arabicacoffechicori'], 'Prediction': 0, 'Label': 0}
# {'Product': 'NUTrition Wholesome Mixed Nuts (8.75 oz Can)', 'Ingredients': ['cashew', 'almond', 'macadamia', 'peanutoil', 'seasalt'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Wild Planet Sardines In Marinara Sauce', 'Ingredients': ['sardin', 'water', 'tomatopast', 'garlic', 'sugar', 'salt', 'oregano', 'pepper', 'basil', 'sardin', 'water', 'tomatopast', 'garlic', 'sugar', 'salt', 'oregano', 'pepper', 'basil'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Roasted Garlic and Red Bell Pepper the Gourmet Collection', 'Ingredients': ['garlic', 'blackpepper', 'sugar', 'redbellpepper', 'onion', 'coriand', 'sage', 'thyme', 'marjoram'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Sweet Leaf Sweetleaf Sweetener', 'Ingredients': ['inulinsolublfiber', 'steviaextract', 'silica'], 'Prediction': 0, 'Label': 0}
# {'Product': 'PLANTERS Deluxe Mixed Nuts with Sea Salt', 'Ingredients': ['cashew', 'almond', 'pecan', 'pistachio', 'hazelnut', 'peanutoil', 'seasalt'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Quaker Instant Oatmeal Apples and Cinnamon 1.51-ounce Cups (Pack of 24)', 'Ingredients': ['palmit', 'niacinamid', 'riboflavin', 'wholegrainrolloat', 'thiaminmononitr', 'folicacid', 'flavor', 'salt', 'caramelonevitamin', 'pyridoxinhydrochlorid', 'cinnamon', 'pyridoxinhydrochlorid', 'citricacid', 'sugar', 'appl', 'flavor', 'folicacid', 'iron', 'caramelcolor', 'cinnamon', 'wholegrainoat', 'calciumcarbon', 'riboflavin', 'sugar', 'malicacid', 'salt', 'wholegrainrolloat', 'sugar', 'appl', 'flavor', 'salt', 'cinnamon', 'calciumcarbon', 'citricacid', 'guargum', 'malicacid', 'niacinamid', 'iron', 'palmit', 'pyridoxinhydrochlorid', 'riboflavin', 'thiaminmononitr', 'folicacid', 'caramelcoloronevitamin', 'guargum', 'niacinamid', 'wholegrainrolloat', 'sugar', 'applpiec', 'flavor', 'salt', 'cinnamon', 'calciumcarbon', 'oatflour', 'citricacid', 'guargum', 'malicacid', 'niacinamid', 'iron', 'palmit', 'pyridoxinhydrochlorid', 'riboflavin', 'thiaminmononitr', 'folicacid', 'caramelcolor', 'thiaminmononitr', 'appl'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Effi Foods', 'Ingredients': ['almond', 'sunflowseed', 'chickpeaflour', 'coconutoil', 'coconutsugar', 'maplsyrup', 'pumpkinseed', 'coconut', 'almondbutter', 'bourbonvanillaextractbourbonvanillabean', 'alcohol', 'water', 'pecan', 'sachainchi', 'seasalt', 'nondairiprobiotinulin', 'bacillucoagulangbi'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Instant Coffee Jar - 30 Cups', 'Ingredients': ['colombianarabicacoffe'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Orbit Sweet Mint Sugar Free Gum', 'Ingredients': ['sorbitol', 'gumbase', 'glycerol', 'flavorstarchhydrolys', 'aspartam', 'mannitol', 'acesulfam', 'soylecithin', 'xylitol', 'bht', 'colorbluelake', 'betacaroten'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Kirkland Signature Dried Cherries', 'Ingredients': ['montmorcherri', 'sugar', 'sunflowoilprocessonpackagpeanut', 'treenut', 'wheat', 'soybean', 'milkegg'], 'Prediction': 0, 'Label': 0}
# {'Product': "Perky Jerky Jammin' Jamaican Turkey Jerky", 'Ingredients': ['turkey', 'sodiumglutenfresoysaucwater', 'soybean', 'salt', 'alcohol', 'brownsugar', 'lemon', 'garlic', 'blackpepper', 'sugar', 'onion', 'allspic', 'seasalt', 'cinnamon', 'redpepper', 'jalapenopepper', 'anchopepper', 'thyme'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Pecans', 'Ingredients': ['pecan'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Beanfields Jalapeno Nacho Bean Chips', 'Ingredients': ['blackbean', 'navibean', 'brownrice', 'safflowsunflowoil', 'seasontapiocamaltodextrin', 'salt', 'jalapeopepper', 'tomato', 'sugar', 'onion', 'yeastextract', 'redgreenbellpepper', 'flavor', 'paprika'], 'Prediction': 0, 'Label': 0}
# {'Product': 'De La Rosa Marzipan Peanut Candy', 'Ingredients': ['peanut', 'sugarflavor'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Caramel Macchiato for K-Cup Keurig 2.0 Brewers', 'Ingredients': ['arabicacoffe', 'artifici'], 'Prediction': 0, 'Label': 0}
# {'Product': 'Truroots Sprouted Quinoa Trio', 'Ingredients': ['sproutwhitequinoa', 'sproutredquinoa', 'sproutblackquinoa', 'calori', 'calori', 'total', 'saturfat', 'tran', 'sodium', 'totalcarbohydr', 'dietarifiber', 'sugar', 'protein', 'calcium', 'iron', 'sproutwhitequinoa', 'sproutredquinoa', 'sproutblackquinoa'], 'Prediction': 0, 'Label': 0}
# {'Product': "Nature's Path Heritage Cereal (3x13.25 Oz)", 'Ingredients': ['quinoa', 'seasalt', 'speltflour', 'kamutkhorasanwheatflour', 'wholemillet', 'barleyflour', 'barleymaltextract', 'wholewheatmeal', 'honey', 'kamutkhorasanwheatflour', 'wheatbran', 'wholewheatmeal', 'canesugar', 'wholeoatflour', 'speltflour', 'barleyflour', 'wholemillet', 'barleymaltextract', 'quinoa', 'seasalt', 'honey', 'wheatbran', 'wholeoatflour', 'canesugar'], 'Prediction': 0, 'Label': 0}
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 0 |                     Accuracy: 0.8966565349544073 | AUC: 0.933074146070536 | Precision: 0.6304347826086957 | Recall: 0.8365384615384616 | F1: [0.71900826446281]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 94
#      92 save_path = 'gridsearch/node/'
#      93 model_path = f'{INGREDIENT_TO_CLASSIFY}_DEMO_TEST_GNN'
# ---> 94 gridsearch(model_path,hidden_chans,lrs,wds, save_path,dropouts)
#
# Cell In[42], line 84, in gridsearch(model_path, hidden_channels, lrs, weight_decays, save_path, dropouts)
#      82       data_dict[end_str]['Test Recall'][i] = test_rec_li
#      83       data_dict[end_str]['Test F1'][i] = test_f1_li
# ---> 84 with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_graphsage_data_dict_TESTING', 'wb') as f:
#      85   pickle.dump(data_dict, f)
#
# File c:\Users\Jwfos\miniconda3\envs\phd\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gridsearch/node/palm oil_graphsage_data_dict_TESTING'

# %%
if not USE_BRANDS_AND_INGR and not LOAD_TEST_SET:
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = data.to(device)
  # WEIGHTS = torch.tensor([1-proportion, proportion])
  # WEIGHTS = WEIGHTS.to(device)
  def gridsearch(hidden_channels, lrs,weight_decays, save_path, dropouts):
      def train(optimizer, criterion):
        model.train()
        optimizer.zero_grad()  # Clear gradients.
        out = model(data.x, data.edge_index)  # Perform a single forward pass.
        loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
        # loss = (loss*WEIGHTS).mean()
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        return loss


      def validate():
          model.eval()
          out = model(data.x, data.edge_index)
          pred = out.argmax(dim=1)  # Use the class with highest probability.

          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]

          test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
          test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.

          d_ = data.y[data.val_mask].cpu().numpy()
          p_ = pred[data.val_mask].cpu().numpy()

          #Precision, Recall and F1 Score
          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(y_true = d_, y_pred=p_)

          return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
      
      
      def test():
          class_correct = [0,0]
          class_samples = [0,0]
          model.eval()
          out = model(data.x, data.edge_index)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
          assert len(test_correct)==len(pred[data.test_mask])
          #print(test_correct)
          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]
          test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
          p = pred[data.test_mask]
          d = data.y[data.test_mask]
          
          d_ = d.cpu().numpy()
          p_ = p.cpu().numpy()
          
          greater_class_probs_ = greater_class_probs[data.test_mask].cpu().detach().numpy()           

          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(y_true = d_, y_pred=p_)
          return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

          for idx,each in enumerate(test_correct):          
              class_samples[d[idx]] += 1
              if each == True:
                  class_correct[p[idx]] += 1
          # print(class_correct, class_samples)
          # print([class_correct[idx]/class_samples[idx] for idx in range(2)])
          return roc_auc_score(d.cpu().numpy(),greater_class_probs_),test_acc, precision, recall, f1

      num_features = len(data.x[0])
      stop_at = 0
      data_dict = {}
      end_str = INGREDIENT_TO_CLASSIFY
      data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
      gridsearch_ = {}
      for hidden_chans in hidden_channels:
          for lr in lrs:
            for wd in weight_decays:
              for do in dropouts:
                for i in range(25):
                  model = SAGEConvClass(hidden_chans, dropout=do).to(device)
                  optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
                  criterion = torch.nn.CrossEntropyLoss()
                  max_acc = 0.0
                  max_auc = 0.0
                  max_val = 0.0
                  max_test_auc = 0.0
                  max_test_acc = 0.0
                  acc_li = []
                  auc_li = []
                  test_acc_li = []
                  test_auc_li = []
                  val_prec_li = []
                  val_rec_li = []
                  val_f1_li = []
                  test_prec_li = []
                  test_rec_li = []
                  test_f1_li = []
                  loss_li = []
                  for epoch in range(1,401):
                    loss=train(optimizer,criterion)
                    loss_li.append(loss.cpu().detach().item())
                    if (epoch%10)==0 or epoch==1:
                      val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
                      val_auc = round(val_auc, 3)
                      val_acc = round(val_acc, 3)
                      acc_li.append(val_acc)
                      auc_li.append(val_auc)
                      val_prec_li.append(val_precision)
                      val_rec_li.append(val_recall)
                      val_f1_li.append(val_f1)

                      test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                      test_auc_li.append(round(test_auc,3))
                      test_acc_li.append(round(test_acc,3))
                      test_prec_li.append(test_precision)
                      test_rec_li.append(test_recall)
                      test_f1_li.append(test_f1)
                      if val_acc >= max_val :
                        stop_at = epoch
                        max_auc = val_auc 
                        max_val = val_acc 
                        max_test_auc = test_auc
                        max_test_acc = test_acc
                        torch.save(model.state_dict(), f'{INGREDIENT_TO_CLASSIFY}_DEMO_TEST_GNN_{i}')
                  print(f'HC: {hidden_channels} | LR: {lr} | WD: {wd} | DrpOut: {do} | Run: {i} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')
                      #print(f'Epoch: {epoch} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')

                        # torch.save(model.state_dict(), save_path+f'mlp_state_dict')
                  # if max_test_auc > 0.9:
                  #   print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'dropout: {do}',f'Max Test Accuracy: {max_test_acc:.4f} Max Test AUC: {max_test_auc:.4f}')
                  # string_ = f'Hids: {hidden_chans} lr: {lr} wd: {wd} dropout: {do}'
                  # gridsearch_[string_] = {}
                  # gridsearch_[string_]['ACC'] = max_test_acc
                  # gridsearch_[string_]['AUC'] = max_test_auc
                  # with open(f'{INGREDIENT_TO_CLASSIFY}_gridsearch', 'wb') as f:
                  #   pickle.dump(gridsearch_, f)

                  data_dict[end_str]['train_loss'][i] = loss_li
                  data_dict[end_str]['Validation Accuracy'][i] = acc_li
                  data_dict[end_str]['Validation AUC'][i] = auc_li
                  data_dict[end_str]['Validation Precision'][i] = val_prec_li
                  data_dict[end_str]['Validation Recall'][i] = val_rec_li
                  data_dict[end_str]['Validation F1'][i] = val_f1_li
                  data_dict[end_str]['Test Accuracy'][i]= test_acc_li
                  data_dict[end_str]['Test AUC'][i] = test_auc_li
                  data_dict[end_str]['Test Precision'][i] = test_prec_li
                  data_dict[end_str]['Test Recall'][i] = test_rec_li
                  data_dict[end_str]['Test F1'][i] = test_f1_li
            with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_graphsage_data_dict_{stop_at}', 'wb') as f:
              pickle.dump(data_dict, f)

              
  # 'Hids: 128 lr: 0.01 wd: 0.005 dropout: 0.5'
  hidden_chans = [128]#64 lr: 0.01 wd: 0.005
  lrs = [0.01]
  wds = [0.005]
  dropouts = [0.5]
  save_path = ''

  gridsearch(hidden_chans,lrs,wds, save_path,dropouts)

# %%
if LOAD_TEST_SET and USE_BRANDS_AND_INGR:
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = data.to(device)
  def gridsearch(model_path, hidden_channels, lrs,weight_decays, save_path):  
      def test():
          class_correct = [0,0]
          class_samples = [0,0]
          model.eval()
          out = model(data.x)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
          assert len(test_correct)==len(pred[data.test_mask])
          #print(test_correct)
          test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
          p = pred[data.test_mask]
          d = data.y[data.test_mask]
          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]
          
          for idx,each in enumerate(test_correct):          
              class_samples[d[idx]] += 1
              if each == True:
                  class_correct[p[idx]] += 1
          # print(class_correct, class_samples)
          # print([class_correct[idx]/class_samples[idx] for idx in range(2)])

          d_ = data.y[data.test_mask].cpu().numpy()
          p_ = pred[data.test_mask].cpu().numpy()

          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(d_, p_)

          return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

      num_features = len(data.x[0])
      data_dict = {}
      end_str = INGREDIENT_TO_CLASSIFY
      stop_at = 0
      data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
      for hidden_chans in hidden_channels:
          for lr in lrs:
            for wd in weight_decays:
              for i in range(25):
                model = MLP(hidden_chans)
                model.load_state_dict(torch.load(f'{model_path}_{i}'))
                model = model.to(device)
                optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
                criterion = torch.nn.CrossEntropyLoss()
                max_acc = 0.0
                max_auc = 0.0

                test_acc_li = []
                test_auc_li = []
                test_prec_li = []
                test_rec_li = []
                test_f1_li = []

                test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                test_auc_li.append(round(test_auc,3))
                test_acc_li.append(round(test_acc,3))
                test_prec_li.append(test_precision)
                test_rec_li.append(test_recall)
                test_f1_li.append(test_f1)


 
                # torch.save(model.state_dict(), save_path+f'mlp_state_dict')
                print(f'Run: {i} | Accuracy: {test_acc} | AUC: {test_auc} | Precision: {test_precision} | Recall: {test_recall} | F1: {test_f1}')

                #print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'Max Validate Accuracy: {max_val:.4f} Max Validate AUC: {max_auc:.4f}')
                
                data_dict[end_str]['Test Accuracy'][i]= test_acc_li
                data_dict[end_str]['Test AUC'][i] = test_auc_li
                data_dict[end_str]['Test Precision'][i] = test_prec_li
                data_dict[end_str]['Test Recall'][i] = test_rec_li
                data_dict[end_str]['Test F1'][i] = test_f1_li
            with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_mlp_data_dict_TESTING', 'wb') as f:
              pickle.dump(data_dict, f)

  hidden_chans = [128]#64 lr: 0.01 wd: 0.005
  lrs = [0.01]
  wds = [0.005]
  dropouts = [0.5]
  save_path = ''

  model_path = f'{INGREDIENT_TO_CLASSIFY}_DEMO_TEST_MLP'
  gridsearch(model_path,hidden_chans,lrs,wds, save_path)
# Out:
# Run: 0 | Accuracy: 0.8733435270132518 | AUC: 0.9164118009046024 | Precision: 0.6869070208728653 | Recall: 0.8125701459034792 | F1: 0.7444730077120821
# Run: 1 | Accuracy: 0.867737003058104 | AUC: 0.9162413970085143 | Precision: 0.6684782608695652 | Recall: 0.8282828282828283 | F1: 0.7398496240601504
# Run: 2 | Accuracy: 0.8595820591233435 | AUC: 0.915769964731389 | Precision: 0.6478260869565218 | Recall: 0.8361391694725028 | F1: 0.7300342969132777
# Run: 3 | Accuracy: 0.8634046890927625 | AUC: 0.9168750922789828 | Precision: 0.6569407603890363 | Recall: 0.8338945005611672 | F1: 0.734915924826904
# Run: 4 | Accuracy: 0.8705402650356778 | AUC: 0.916444919577132 | Precision: 0.6788048552754435 | Recall: 0.8159371492704826 | F1: 0.7410805300713558
# Run: 5 | Accuracy: 0.867737003058104 | AUC: 0.9149499538003769 | Precision: 0.6715867158671587 | Recall: 0.8170594837261503 | F1: 0.7372151898734176
# Run: 6 | Accuracy: 0.8651885830784913 | AUC: 0.9162710002912222 | Precision: 0.661319073083779 | Recall: 0.8327721661054994 | F1: 0.7372081470442126
# Run: 7 | Accuracy: 0.872579001019368 | AUC: 0.9163403829850693 | Precision: 0.6853080568720379 | Recall: 0.8114478114478114 | F1: 0.7430626927029805
# Run: 8 | Accuracy: 0.863914373088685 | AUC: 0.9169805539736301 | Precision: 0.6578249336870027 | Recall: 0.835016835016835 | F1: 0.7359050445103857
# Run: 9 | Accuracy: 0.8662079510703364 | AUC: 0.9160521210196998 | Precision: 0.6639784946236559 | Recall: 0.8316498316498316 | F1: 0.7384155455904334
# Run: 10 | Accuracy: 0.8687563710499491 | AUC: 0.9151447804046989 | Precision: 0.6721611721611722 | Recall: 0.8237934904601572 | F1: 0.7402924861321231
# Run: 11 | Accuracy: 0.8641692150866462 | AUC: 0.9175580030069534 | Precision: 0.6570175438596492 | Recall: 0.8406285072951739 | F1: 0.7375677006400788
# Run: 12 | Accuracy: 0.8636595310907238 | AUC: 0.9175065673032482 | Precision: 0.6566901408450704 | Recall: 0.8372615039281706 | F1: 0.7360631475086333
# Run: 13 | Accuracy: 0.8616207951070336 | AUC: 0.9162933877737702 | Precision: 0.6505190311418685 | Recall: 0.8439955106621774 | F1: 0.734733756717147
# Run: 14 | Accuracy: 0.8616207951070336 | AUC: 0.9156102920252827 | Precision: 0.6534391534391535 | Recall: 0.8316498316498316 | F1: 0.7318518518518518
# Run: 15 | Accuracy: 0.8672273190621814 | AUC: 0.9175975973975754 | Precision: 0.667572463768116 | Recall: 0.8271604938271605 | F1: 0.7388471177944863
# Run: 16 | Accuracy: 0.8644240570846076 | AUC: 0.9166121781244322 | Precision: 0.6642268984446478 | Recall: 0.8148148148148148 | F1: 0.7318548387096774
# Run: 17 | Accuracy: 0.8654434250764526 | AUC: 0.9176229452083942 | Precision: 0.6619090098126673 | Recall: 0.8327721661054994 | F1: 0.7375745526838966
# Run: 18 | Accuracy: 0.863914373088685 | AUC: 0.9153588491427813 | Precision: 0.6606660666066607 | Recall: 0.8237934904601572 | F1: 0.7332667332667334
# Run: 19 | Accuracy: 0.8713047910295617 | AUC: 0.9157777355930999 | Precision: 0.6797020484171322 | Recall: 0.819304152637486 | F1: 0.7430025445292621
# Run: 20 | Accuracy: 0.8651885830784913 | AUC: 0.9167844322256895 | Precision: 0.6621863799283154 | Recall: 0.8294051627384961 | F1: 0.7364225211758844
# Run: 21 | Accuracy: 0.8664627930682977 | AUC: 0.9160748785432816 | Precision: 0.6642793196060878 | Recall: 0.8327721661054994 | F1: 0.7390438247011951
# Run: 22 | Accuracy: 0.8618756371049949 | AUC: 0.9186444434823379 | Precision: 0.652668416447944 | Recall: 0.8372615039281706 | F1: 0.7335299901671584
# Run: 23 | Accuracy: 0.8761467889908257 | AUC: 0.9172812123136335 | Precision: 0.6967930029154519 | Recall: 0.8047138047138047 | F1: 0.746875
# Run: 24 | Accuracy: 0.867737003058104 | AUC: 0.9171394865976688 | Precision: 0.6681735985533453 | Recall: 0.8294051627384961 | F1: 0.7401101652478718

# %%
if USE_BRANDS_AND_INGR and not LOAD_TEST_SET:
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = data.to(device)
  def gridsearch(hidden_channels, lrs,weight_decays, save_path):
      def train(optimizer, criterion):
        model.train()
        optimizer.zero_grad()  # Clear gradients.
        out = model(data.x)  # Perform a single forward pass.
        loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        return loss


      def validate():
          model.eval()
          out = model(data.x)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
          test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.]
          
          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]

          d_ = data.y[data.val_mask].cpu().numpy()
          p_ = pred[data.val_mask].cpu().numpy()

          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(d_, p_)

          return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
      
      def test():
          class_correct = [0,0]
          class_samples = [0,0]
          model.eval()
          out = model(data.x)
          pred = out.argmax(dim=1)  # Use the class with highest probability.
          test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
          assert len(test_correct)==len(pred[data.test_mask])
          #print(test_correct)
          test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
          p = pred[data.test_mask]
          d = data.y[data.test_mask]
          sm = torch.nn.Softmax(dim=1)
          probs__ = sm(out)
          greater_class_probs = probs__[:,1]
          
          for idx,each in enumerate(test_correct):          
              class_samples[d[idx]] += 1
              if each == True:
                  class_correct[p[idx]] += 1
          # print(class_correct, class_samples)
          # print([class_correct[idx]/class_samples[idx] for idx in range(2)])

          d_ = data.y[data.test_mask].cpu().numpy()
          p_ = pred[data.test_mask].cpu().numpy()

          precision = precision_score(d_, p_)
          recall = recall_score(d_, p_)
          f1 = f1_score(d_, p_)

          return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

      num_features = len(data.x[0])
      data_dict = {}
      end_str = INGREDIENT_TO_CLASSIFY
      stop_at = 0
      data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
      for hidden_chans in hidden_channels:
          for lr in lrs:
            for wd in weight_decays:
              for i in range(25):
                model = MLP(hidden_chans).to(device)
                optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
                criterion = torch.nn.CrossEntropyLoss()
                max_acc = 0.0
                max_auc = 0.0
                max_val = 0.0
                acc_li = []
                auc_li = []
                test_acc_li = []
                test_auc_li = []
                val_prec_li = []
                val_rec_li = []
                val_f1_li = []
                test_prec_li = []
                test_rec_li = []
                test_f1_li = []
                loss_li = []
                for epoch in range(1,401):
                  loss=train(optimizer,criterion)
                  loss_li.append(loss.cpu().detach().item())
                  if (epoch%10)==0 or epoch==1:
                    val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
                    val_auc = round(val_auc, 3)
                    val_acc = round(val_acc, 3)
                    acc_li.append(val_acc)
                    auc_li.append(val_auc)
                    val_prec_li.append(val_precision)
                    val_rec_li.append(val_recall)
                    val_f1_li.append(val_f1)

                    test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                    test_auc_li.append(round(test_auc,3))
                    test_acc_li.append(round(test_acc,3))
                    test_prec_li.append(test_precision)
                    test_rec_li.append(test_recall)
                    test_f1_li.append(test_f1)

                    if val_auc >= max_auc :
                      stop_at = epoch
                      max_auc = val_auc 
                      max_val = val_acc 
                      torch.save(model.state_dict(), f'{INGREDIENT_TO_CLASSIFY}_DEMO_TEST_MLP_{i}')
                      #print(f'Epoch: {epoch} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')

                print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'Max Validate Accuracy: {max_val:.4f} Max Validate AUC: {max_auc:.4f}')
                
                
                data_dict[end_str]['train_loss'][i] = loss_li
                data_dict[end_str]['Validation Accuracy'][i] = acc_li
                data_dict[end_str]['Validation AUC'][i] = auc_li
                data_dict[end_str]['Validation Precision'][i] = val_prec_li
                data_dict[end_str]['Validation Recall'][i] = val_rec_li
                data_dict[end_str]['Validation F1'][i] = val_f1_li
                data_dict[end_str]['Test Accuracy'][i]= test_acc_li
                data_dict[end_str]['Test AUC'][i] = test_auc_li
                data_dict[end_str]['Test Precision'][i] = test_prec_li
                data_dict[end_str]['Test Recall'][i] = test_rec_li
                data_dict[end_str]['Test F1'][i] = test_f1_li
            with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_mlp_data_dict_stop_epoch_{stop_at}', 'wb') as f:
              pickle.dump(data_dict, f)
  hidden_chans = [128]#64 lr: 0.01 wd: 0.005
  lrs = [0.01]
  wds = [0.005]
  dropouts = [0.5]
  save_path = 'gridsearch/node/'
  gridsearch(hidden_chans,lrs,wds, save_path)

# %%
from sklearn import tree,ensemble
from joblib import dump, load

if not MASK and USE_BRANDS_AND_INGR:
    assert len(data.y) == len(data.test_mask)==len(data.x)
    data.detach().cpu()
    print(data.x.shape)
    if LOAD_TEST_SET:
        clf = load(f'{INGREDIENT_TO_CLASSIFY}_Decision_Tree')
        grad_boost = load(f'{INGREDIENT_TO_CLASSIFY}_Grad_Boost')
    else:
        clf = tree.DecisionTreeClassifier()
        grad_boost = ensemble.GradientBoostingClassifier()

        clf.fit(data.x[data.train_mask], data.y[data.train_mask])
        grad_boost.fit(data.x[data.train_mask], data.y[data.train_mask])


    clf_preds = torch.Tensor(clf.predict(data.x[data.val_mask]))
    clf_val_acc = int((clf_preds==data.y[data.val_mask]).sum()) / int(data.val_mask.sum())
    grad_val_acc = grad_boost.score(data.x[data.val_mask], data.y[data.val_mask])




    clf_val_probas = clf.predict_proba(data.x[data.val_mask])
    grad_val_probas = grad_boost.predict_proba(data.x[data.val_mask])


    clf_val_auc = roc_auc_score(data.y[data.val_mask],clf_val_probas[:,1])
    grad_val_auc = roc_auc_score(data.y[data.val_mask],grad_val_probas[:,1])

    print(f'Decision Tree Validation Acc {clf_val_acc} and Validation AUC {clf_val_auc}')
    print(f'Grad Boost Validation Acc {grad_val_acc} and Validation AUC {grad_val_auc}')


    clf_preds = torch.Tensor(clf.predict(data.x[data.test_mask]))

    clf_test_acc = int((clf_preds==data.y[data.test_mask]).sum()) / int(data.test_mask.sum())
    grad_test_acc = grad_boost.score(data.x[data.test_mask], data.y[data.test_mask])


    clf_test_probas = clf.predict_proba(data.x[data.test_mask])
    grad_test_probas = grad_boost.predict_proba(data.x[data.test_mask])


    clf_test_auc = roc_auc_score(data.y[data.test_mask],clf_test_probas[:,1])
    grad_test_auc = roc_auc_score(data.y[data.test_mask],grad_test_probas[:,1])


    grad_preds = grad_boost.predict(data.x[data.test_mask])

    grad_f1 = f1_score(data.y[data.test_mask], grad_preds)
    clf_f1 = f1_score(data.y[data.test_mask], clf_preds)


    print(f'Decision Tree test Acc {clf_val_acc} and test AUC {clf_val_auc} and Test F1: {clf_f1}')
    print(f'Grad Boost test Acc {grad_test_acc} and test AUC {grad_test_auc} and Test F1: {grad_f1}')


    with open(f'gridsearch/node/{INGREDIENT_TO_CLASSIFY}_clf_grad_boost_dict_test_{LOAD_TEST_SET}', 'wb') as f:
        pickle.dump({'clf': {'test_acc': clf_test_acc, 'test_auc':clf_test_auc, 'test_f1':clf_f1}, 'grad': {'test_acc': grad_test_acc, 'test_auc':grad_test_auc, 'test_f1':grad_f1}}, f) 

    if not LOAD_TEST_SET:
        dump(clf,f'{INGREDIENT_TO_CLASSIFY}_Decision_Tree')
        dump(grad_boost,f'{INGREDIENT_TO_CLASSIFY}_Grad_Boost')
# Out:
# torch.Size([4227, 10605])
# Decision Tree Validation Acc 0.8340943683409436 and Validation AUC 0.8259514170040486
# Grad Boost Validation Acc 0.8462709284627092 and Validation AUC 0.8798785425101215
# Decision Tree test Acc 0.8340943683409436 and test AUC 0.8259514170040486 and Test F1: 0.7009803921568627
# Grad Boost test Acc 0.8358662613981763 and test AUC 0.8886453839516826 and Test F1: 0.7202072538860103
