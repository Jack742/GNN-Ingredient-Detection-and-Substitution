# %%
import ast
import random
import math
import string
import pickle
import json
from copy import deepcopy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import sys
from torch_geometric.data import Data
from torch.nn import Dropout
from tqdm import tqdm
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

import pandas as pd
#www.python-graph-gallery.com

# %%
USE_FULL_FEATURES = False
USE_BRANDS_AND_INGR = True
MASK = False
LOAD_SUB_FROM_FILE = True
USE_FREQUENCY = False
LOAD_BALANCED_DATA = True
INGREDIENT_TO_CLASSIFY = 'egg'#
STEM = True
REPLACE = True
REMOVE_REPLACE = False
if STEM:
    ps = PorterStemmer()
    words = [ps.stem(word) for word in INGREDIENT_TO_CLASSIFY.split(' ')]
    s = ''
    for word in words:
        s += word

if REPLACE:
    with open('replace_words.json') as f:
        replacements = json.load(f)
        for each in replacements.keys():
            replacements[each] = ast.literal_eval(replacements[each])
    
if LOAD_SUB_FROM_FILE:
    df = pd.read_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv')
else:
    files = [
        "outputs/food_1_Y.csv",
        "outputs/food_2_Y.csv",
        "outputs/food_3_Y.csv"
    ]

    df = pd.DataFrame()
    for file in files:
        df = pd.concat([df, pd.read_csv(file)])

    #df = df[df.index < int(len(df.index)/50)]
    df = df.sample(int(len(df.index)/1), random_state=123456789)
    #df = df.dropna()
    df = df.reset_index()

with open('stopwords.txt', 'r') as f:
    stopwords = []
    for l in f:
        if l not in stopwords:
            stopwords.append(l.replace('\n',''))
#Add a list of the ingredients, and concatenate palm oil products to be just palm oil
ingredients = [[x.lower() for x in ast.literal_eval(product['ingredients'])] for _,product in df.iterrows()]
df['ingredients_list'] = ingredients



drop_sparse_idx = []
c = []
banned_words = ['nan', 'none', 'na']
trans = str.maketrans(string.punctuation, ' '*len(string.punctuation))
for row_idx, row in tqdm(df.iterrows()):
    if row['brand'] == math.nan:
        drop_sparse_idx.append(row_idx)
    len_ing = len(row['ingredients_list'])
    if len_ing==0:
        drop_sparse_idx.append(row_idx)
    elif len_ing == 1 and row['ingredients_list'][0].lower() in banned_words:
        drop_sparse_idx.append(row_idx)
    else:        
        idx = 0
        idx_to_remove = []
        while idx<len(row['ingredients_list']):
            if idx>1000:
                print(row['ingredients_list'][idx])
            row['ingredients_list'][idx] = row['ingredients_list'][idx].translate(trans)           
            if row['ingredients_list'][idx] in replacements.keys():
                #NEED TO DO THIS. SIMPLE GET THE VALUES IN replacements. CAN'T APPEND IN LOOP, BUT YOU COULD DO A WHILE LOOP
                idx_to_remove.append(idx)
                row['ingredients_list'].extend(replacements[row['ingredients_list'][idx]])             
            idx+=1
        if REMOVE_REPLACE:
            for i in reversed(idx_to_remove):
                row['ingredients_list'].pop(i)

df = df.drop(drop_sparse_idx)
drop_sparse_idx = []
for row_idx, row in df.iterrows():
    pop_li = []
    for idx, each in enumerate(row['ingredients_list']):
        stop_row_li = np.array(row['ingredients_list'][idx].split(' '))
        for stopword in stopwords:
            stop_loc = np.where(stop_row_li ==stopword)
            if len(stop_loc[0])>0:
                stop_row_li= np.delete(stop_row_li,stop_loc)
                str_ = ''
                for stringify_ in stop_row_li:
                    str_ += ' ' + stringify_
                row['ingredients_list'][idx] = str_
        if STEM:
            sentence = row['ingredients_list'][idx]
            words = [ps.stem(word) for word in sentence.split(' ')]
            s = ''
            for word in words:
                s += word
            row['ingredients_list'][idx] = s
            row['ingredients_list'][idx] = row['ingredients_list'][idx].replace(' ', '')
        if row['ingredients_list'][idx] == '':
            pop_li.append(idx)
        else:
            each = row['ingredients_list'][idx]
            if all(item in each.lower() for item in INGREDIENT_TO_CLASSIFY.lower().split()):
                c.append(each.lower())
                row['ingredients_list'][idx] = INGREDIENT_TO_CLASSIFY.lower()
    if pop_li:
        for each in reversed(pop_li):
            row['ingredients_list'].pop(each)
        if len(row['ingredients_list']) == 0:
            drop_sparse_idx.append(row_idx)

df = df.drop(drop_sparse_idx)

df = df[['index', 'name','brand','categories','price_max','price_min','ingredients','ingredients_list']]
df = df.dropna()
df
# Out:
# 4920it [00:01, 3502.09it/s]
#       index                                               name  \
# 0      1939  Simply Scrumptous Low Fat Chocolate Chunk Cookies
# 1      5420  Campbell's Chunky Creamy Chicken & Dumplings Soup
# 2      6125  Campbell's Chunky Classic Chicken Noodle Soup ...
# 3      7572  100 Grand Candy Bar, Milk Chocolate and Carame...
# 4      3647  Jeff Nathan Creations Chef Gourmet Panko Plain...
# ...     ...                                                ...
# 4915   5191                    Lawry's Spaghetti Sauce Spatini
# 4916   3671  Extra Large Rock Candy Sticks (22g): 12 Green ...
# 4917   7986  Stone Cold India Pale ALE Home Brew Beer Recip...
# 4918   4360           Campbell'sÂ Condensed Chicken Gumbo Soup
# 4919   4804    Mount Hagen Organic Freeze Dried Instant Coffee
#
#                       brand  \
# 0         Simply Scrumptous
# 1                Campbell's
# 2                Campbell's
# 3                 100 Grand
# 4     Jeff Nathan Creations
# ...                     ...
# 4915                Lawry's
# 4916                 Espeez
# 4917        Home Brew Stuff
# 4918             Campbell's
# 4919            Mount Hagen
#
#                                              categories  price_max  price_min  \
# 0     ['Grocery & Gourmet Food', 'Cookies', 'Cookie ...      17.60      17.60
# 1     ['Soup', 'Household & Grocery', 'Food & Snacks...       3.49       3.49
# 2     ['Soup', 'Food Snacks', 'Household & Grocery',...       3.59       3.39
# 3     ['Candy', ' Gum & Mints', 'Chocolate', 'Candy ...      38.99      24.67
# 4     ['Cooking & Baking', 'Breadcrumbs & Seasoned C...      96.68      10.88
# ...                                                 ...        ...        ...
# 4915  ['Grocery & Gourmet Food', 'Seasoning Mixes', ...      61.22       9.22
# 4916  ['Grocery & Gourmet Food', 'Candy & Chocolate'...      14.97      14.97
# 4917  ['Grocery & Gourmet Food', 'Food & Beverage Gi...      46.98      42.19
# 4918  ['Soups', ' Stocks & Broths', 'Grocery & Gourm...      17.76      12.00
# 4919  ['Grocery & Gourmet Food', 'Coffee', ' Tea & C...      52.10      52.10
#
#                                             ingredients  \
# 0     ['whole wheat flour', 'chocolate chunks sugar'...
# 1     ['water', 'chicken stock', 'sodium phosphate',...
# 2     ['water', 'chicken stock', 'monosodium glutama...
# 3     ['high fructose corn syrup', 'butter', 'chocol...
# 4     ['tapioca starch', 'water', 'potato starch', '...
# ...                                                 ...
# 4915  ['salt', 'sugar', 'onion', 'potato starch', 's...
# 4916  ['pure cane sugar', 'less than of the followin...
# 4917  ['recipe kit includes highest quality fresh fo...
# 4918  ['water', 'chicken stock', 'tomato puree water...
# 4919                                  ['finest coffee']
#
#                                        ingredients_list
# 0     [wholewheatflour, chocolchunksugar, chocol, co...
# 1     [water, chickenstock, sodiumphosphat, monosodi...
# 2     [water, chickenstock, monosodiumglutam, thiami...
# 3     [fructoscornsyrup, butter, chocol, cocoabutter...
# 4     [tapiocastarch, water, potatostarch, potatoflo...
# ...                                                 ...
# 4915  [salt, sugar, onion, potatostarch, spiceinclud...
# 4916  [canesugar, flavor, red, blue, red, yellow, ye...
# 4917  [recipkitincludhighestqualitigallonbeerspecial...
# 4918  [water, chickenstock, tomatowater, tomatopast,...
# 4919                                      [finestcoffe]
#
# [4920 rows x 8 columns]

# %%
brand = {}
num_palm = 0
for idx,row in df.iterrows():
    for each in row['ingredients_list']:
        if INGREDIENT_TO_CLASSIFY in each.lower():
            #print("Name: %s ## Ingredient: %s" % (row['name'], each))            
            num_palm += 1
            br = row['brand']
            brand[br] = brand[br] + 1 if br in brand.keys() else 1
print(num_palm/len(df.index), len(df.index)/len(df.index))
# Out:
# 0.4268292682926829 1.0

# %%
#df = df[["name", "ingredients"]]
df = df.drop_duplicates(subset="name")
# if 'level_0' in df.columns:
#     df = df.drop('level_0', axis=1)
df = df.reset_index()


#unique_ingred = np.unique(sum(df["ingredients"].apply(ast.literal_eval).values.tolist(), []))
unique_names = df['name'].unique()
unique_brands = df['brand'].unique()
#unique_mans = df['manufacturer'].unique()
unique_cats = np.unique(sum(df["categories"].apply(ast.literal_eval).values.tolist(), []))
unique_names = sorted(unique_names)
#unique_ingred = sorted(unique_ingred)

unique_ingred = []
for x in df['ingredients_list']:
    for y in x:
        if y not in unique_ingred:
            unique_ingred.append(y)

for i in unique_ingred:
    print(i)

print(len(set(unique_ingred)), len(unique_ingred))
# ui = np.unique(np.ndarray(df['ingredients_list']))


# G = igraph.Graph()
# G.add_vertices(len(unique_names))
# print(len(unique_names), len(df.index))
# #print(G.nodes['Once Upon a Farm Organic'])
# Out:
# wholewheatflour
# chocolchunksugar
# chocol
# cocoa
# butter
# milk
# soylecithin
# flavor
# sugar
# egg
# oatfiber
# defatbutter
# vanilla
# bakesoda
# palmoil
# cocoabutter
# emulsifi
# water
# chickenstock
# sodiumphosphat
# monosodiumglutam
# thiaminmononitr
# betacaroten
# riboflavin
# durumwheatflourdurumwheatflour
# turmer
# greenbean
# maltbarleyflour
# buttercreammilk
# salt
# celeri
# spaetzldumplwater
# wheatflour
# chickenmeat
# onion
# pea
# chicken
# spice
# soyprotein
# creamcreammilk
# vegetoil
# chickenchickenstock
# niacin
# starch
# carrot
# wheatflourwheatflour
# spaetzldumpl
# ferrousulfat
# folicacid
# whitechickenmeat
# carrageenan
# potatostarch
# canolaoil
# fructoscornsyrup
# anflavor
# milkfat
# soyglutenmilk
# cornsyrup
# coconutoil
# barleymalt
# milkchocolsugar
# flavoronpeanut
# vanillin
# monodiglycerid
# milklactos
# crispricericeflour
# tapiocastarch
# potatoflour
# vinegar
# honey
# cocoaprocessalkali
# milkchocolsugarcornsyruphydrogenpalmkerneloil
# cocoaprocessalkalisalt
# milkchocol
# palmkerneloil
# palmkerneloilpalmoil
# flavorpeanut
# twixminimilkchocolsugar
# soylecithinflavor
# peanutmilkiwayminimilkchocolsugar
# pgpr
# peanut
# iron
# cornstarch
# soywheat
# flavormilk
# dextros
# lactos
# processalkali
# barleymaltextract
# brownsugar
# brownriceflour
# whitericeflour
# tapiocaflour
# nongmocanolaoil
# yeast
# guargum
# filterwater
# drimilk
# consistchocolsugar
# chocolprocessalkali
# wholemilk
# soylecithinanemulsifi
# vanillinanflavor
# condensmilk
# dairicream
# coconutsodiummetabisulfit
# invertsugar
# nutalmond
# walnut
# pecan
# molass
# cherricherri
# citricacid
# preservsodiumbenzoat
# potassiumsorbatsulfurdioxid
# fdcred
# peanutbutterdriroastpeanut
# cottonseedrapeseoil
# soyoil
# cocoaprocesspotassiumcarbon
# confectionglaze
# sorbitol
# whitechocolsugar
# raisin
# apricottracesulfurdioxid
# maplsugar
# invertas
# carmin
# preservsodiumbenzoatpotassiumsorbat
# fdccolorred
# yellow
# blue
# tocopherol
# promotretent
# potassiumsorbatsodiumbenzoat
# milksolid
# soylecithinvanillin
# apricotsulfurdioxid
# red
# sodiumbenzoatpotassiumsorbat
# sulfurdioxid
# chocolsugar
# almond
# anemulsifi
# anenzym
# fdccolor
# preserv
# popcorn
# buttercream
# cream
# sunflowoil
# bakesodasoybean
# othertreenut
# wheat
# palmit
# annatto
# sodiumstearoyllactyl
# bleachwheatflour
# soybeanoil
# chocolchipsugar
# chocolliquor
# glycerin
# whey
# leavenbakesoda
# sodiumacidpyrophosph
# monocalciumphosphat
# glyceryllactoestfattiacid
# preser
# color
# coconut
# caramel
# interesterifisoybeanoil
# starchmodifi
# wheatstarch
# calciumchlorid
# xanthangum
# preservpotassiumsorbat
# calciumpropion
# artifici
# monoanddiglycerid
# cornmaltodextrin
# mechanseparchickenmeatmechanseparchickenmeat
# bha
# propylgallat
# hydrolyzcornprotein
# parsleyflake
# autolyzyeast
# silicondioxid
# spiceextract
# disodiumguanyl
# disodiuminosin
# propylenglycol
# polysorb
# onionoil
# glutenwholeoatflour
# evaporcanesugar
# oleicsafflowoil
# pear
# buckwheatflour
# lemon
# vanillaextract
# bake
# creamtartar
# rosemariextractonsharelinesoylecithindediccontainnopeanut
# treenut
# dairi
# casein
# fish
# crustacean
# mollusc
# gluten
# sesam
# mustardseed
# sulphurdioxid
# sulphitlupincaresourctestpeanut
# milkglutenprotein
# candicherrisultanaraisin
# sourdoughyeast
# emulsifimonofattiaciddiglyceridvegetorigin
# qualitimilk
# cerviawholemarinsalt
# madagascarmananaravanilla
# flavourstoneslowpresidiumitali
# honeyroastpeanutpeanut
# vegetoilpeanut
# cottonse
# soybeansunflowseed
# maltodextrin
# peanutbutterchipsugar
# defatpeanutflour
# peanutbutterpeanut
# rapeseoil
# cottonseoil
# peanutbuttercandisugar
# defatpeanut
# vegetoilpalmkerneloil
# coloryellowlake
# yellowlake
# redlake
# bluelake
# resinglaze
# vanillinflavor
# carnaubawax
# peanutbuttercoatpretzelballpeanutbuttercoatsugar
# driwhey
# pretzelballwheatflourwheatflour
# vegetoilonecorn
# canola
# soybean
# malt
# minipeanutbuttercupmilkchocolsugar
# soybeansunflowseedpeanut
# soy
# wheatpackonsharetreenut
# granolawholegrainoat
# palmkernelsoybeanoil
# cocount
# soyflour
# macarooncoconut
# palmpalmkerneloil
# delirollwheatflourwheatflour
# vitalwheatgluten
# doughconditionwheatflourniaci
# dulcdelechwholemilk
# glucos
# sodium
# bicarbon
# potassium
# sorbat
# margarin
# corn
# moisten
# leavenagent
# amoniumbecarbon
# flavourvanilla
# almondorang
# vanillinmilk
# soywheattracewalnut
# cashew
# caramelicecreamcream
# flavorchocolaticoatconepiecsugar
# conepiecwheatflour
# butteroil
# vanillaextractcaramelswirlsugar
# pectin
# soycornoil
# gumarabix
# sodiumalgin
# sodiumpropion
# tortugagoldrum
# yellowyellowkeylime
# bleachflour
# folicacidpotassiumbromat
# calsiumsulfat
# absorbacidguavapastguavapulp
# glucossyrup
# citricacidbutter
# granulsugar
# sodiumbicarbon
# palmkernelpalmoil
# soyalecithinanemulsifi
# bakesodiumacidpyrophosph
# calciumsulfat
# drimilksolid
# anhydrdextros
# macadamianut
# flourwheatflour
# vegetglycerin
# wholegrainoat
# riceflour
# wholegrainwheat
# honeyroastalmondbutteralmond
# mixtocopherol
# fructos
# retain
# wholegrainwheatflour
# peanutbutter
# chicorirootextract
# flourbleachwheatflour
# vegetshorten
# rolloat
# raisinpast
# maltextract
# cinnamon
# allspic
# corndextrin
# bakexanthangum
# ricebranextract
# enzym
# ricebran
# wholegrainbrownriceflour
# glutenflourcornflour
# ricestarch
# whitebeanflour
# cane
# unsulphurmolass
# ginger
# seasalt
# soybeanlecithinwarnproducparocesshandlwheat
# peanuttreenut
# glutenfreflour
# cornflour
# canesugar
# glutenfreflourcornflour
# pancakmixbleachflourwheatflour
# leavensodiumbicarbon
# soybeancottonseoil
# buttermilk
# lecithin
# huckleberrisyruphuckleberri
# oat
# invertsyrup
# bakebakesoda
# inulin
# cinnamonbit
# leaven
# wheatflourbleach
# soywalnut
# wheatflourbleachedsugarchicorirootextractcinnamonbitsugarvegetoil
# minerwhey
# sugarcanfiber
# macadamia
# locustbeangum
# glutenflourpotato
# favabean
# garbanzobean
# teff
# chiaseed
# flaxse
# driyeast
# glutenflourtapioca
# whiterice
# sorghum
# applfillappl
# glutenflourwhitericeflour
# sodiumacidbicarbon
# sunflowlecithin
# glutenflourcorn
# tapioca
# donutsugardextros
# potassiumsorbat
# cornmeal
# calciumphosphat
# sorbicacid
# monoglycerid
# wheatflourflour
# sodiumchlorid
# flour
# veget
# starterwheatflourwater
# wheatsyrup
# monodiglyceridfattiacid
# ascorbacid
# milkprotein
# emulsifimonodiglycerid
# blueproducpeanut
# lemonpeel
# palmcanolaoil
# sodiumaluminumphosphat
# blackcarrot
# vitaminminercalciumcarbon
# vegetoilsoybean
# blueberri
# cellulosgum
# redlakevitaminminercalciumcarbon
# niacinamid
# soylecithinvitaminminercalciumcarbon
# palm
# milksoy
# sugarcornsyrupchocolchocolsugarcocoamilklecithincocoabutterpgpr
# calciumcarbon
# sodiumaluminumsulfat
# tapiocadextrin
# wheyprotein
# agar
# sorbitanmonostear
# cornsyrupsolid
# wheatprotein
# sodiumbenzoat
# wholegrainmixwholewheatflour
# quinoa
# thimixwheatdairitracesoy
# montmorcherri
# sunflowoilprocessonpackagpeanut
# soylecithinasanemulsifi
# chocolliquorprocessalkali
# soylecithinasanemulsfi
# monodiglyceridsoyalecithinemulsifi
# fondantsugar
# hazelnut
# macadamiapecan
# rawspanishpeanut
# rawcoconut
# toastcoconut
# marshmallow
# gelatin
# carrageenanwatercocoa
# sodiumlauryl
# sulfat
# chocolfudgsugarwater
# vegetoillecithin
# brownsugarsugar
# canemolass
# peanutflour
# sweetdiarimilk
# freezraspberri
# malicacid
# peppermintoil
# maiz
# vegetcolor
# vegetoilpalmkernel
# palminteresterifisoybeancottonse
# chocolliquorprocessalkalidutch
# raspberri
# leavenmilkfat
# contai
# semisweetchocolsugar
# milkchocolsugarcocoabuttermilk
# chocolsoylecithin
# anemulsifisaltflavor
# sweetchocolsugarchocolcocoabutterartificisoylecithin
# palmkernelcottonseoil
# includred
# hydrolyzsoyprotein
# sodiumhexametaphosph
# dicetomatotomato
# macaronipastasemolinawheat
# redpepper
# yeastextract
# garlic
# paprika
# hydrolyzwheatgluten
# beeftallow
# tomatowater
# tomatopast
# kidneybean
# seasonbeefporkcrumblbeefpork
# whitecornflour
# shellfish
# vegan
# browncanesugar
# breweryeast
# clove
# crusttapiocastarch
# cheddarcheesmilk
# cheescultur
# mozzarellacheesmilk
# vegetrennet
# parmesancheesmilk
# vegetrennettoptomatopast
# evapormilk
# soybeancoconutoil
# coffe
# lime
# fairtradecanesugar
# distilvinegar
# avocadooil
# avocadooilmayonnaisavocadooil
# mustardflour
# blackpepper
# limeoil
# parsley
# chickenbroth
# tomato
# rice
# potassiumchlorid
# cornprotein
# thiaminhydrochlorid
# emulsifisoy
# flavour
# goldensyrup
# colour
# rais
# emulsififlavourtracepeanut
# othernut
# proteinsoyprotein
# yogurtcoatmaltitol
# yogurtculturwheyprotein
# culturmilk
# wholemilksolid
# saltflavor
# prebiotdietarivegetfiber
# invertcanesyrup
# xylitol
# xanthangumsoy
# treenutfish
# acetacid
# coffecreamglucossyrup
# vegetfat
# roastcoffe
# milkmilkprotein
# coffeflavour
# coffepastroastgroundcoffe
# flavouritali
# anisseed
# saltanisseed
# bittersweetchocolchocol
# dessiccoconut
# currant
# ammoniumbicarbon
# lemonlemonoil
# vanillavanillinanflavor
# gumarab
# monodiglyceridcitricacidhelp
# wheatflourniacin
# thiamin
# mechanseparchicken
# nosalt
# colorfdcyellow
# vegetfatoilpalm
# palmkernel
# pizzacrustwater
# oilcanolaoil
# olivoil
# moisturmozzarellacheesmilk
# mozzarellacheesculturmilk
# extravirginolivoil
# basil
# fdccolorincludyellow
# sodiummetabisulfit
# sucros
# bleachflourwheatflour
# poppiseed
# propylenglycolesterfattiacid
# distilmonoglycerid
# citricacidbht
# hydrochlorid
# passovwheatflour
# glutenflouroat
# potato
# applcidervinegar
# nutwalnut
# orangpeel
# strawberri
# carmincolor
# dlalphatocopherol
# applflakecalciumstearat
# calciumcasein
# chickencountrigravimixstarch
# breadchickenribmeatchickenribmeat
# breadwheatflourwheatflour
# setvegetoil
# mashpotatowater
# yellowcornflour
# dipotassiumphosphat
# betacarotencornoil
# graviwater
# fullibreadchickenpattichicken
# soycottonseoil
# thiaminhcl
# lacticacid
# disodiuminosindisodiumguanyl
# paprikaextractannatoextract
# batterwater
# leavensodiumacidpyrophosph
# buttermilkbuttermilk
# seasonstarch
# sodiumcasein
# smoke
# reconstitutpotato
# margarinsoybeanoiltbhqcitricacid
# aspreserv
# monodiglyceridbht
# butterbuttercream
# potatopotato
# appldessertwater
# rehydrappl
# appl
# vanillawater
# ethanol
# saucwater
# margarinsoybeanoil
# soybeanoiltbhqcitricacidaspreservmargarinsoybeanoil
# tbhqcitricacidaspreserv
# cornoil
# seasonsaucwater
# betacarotemcornoil
# potatoflakepotato
# seasonsaucsoybeanoil
# flavorflavor
# paprikaextractannattoextractcolorbatterwater
# soybeanoilseasonsaucsoybeanoil
# isoloat
# dairiwhey
# monodiglyceridbhtcitricacid
# paprikaextractannattoextract
# ofxaseasonsaucexasoybeanoil
# ofseasonsaucesoybeanoil
# redmanufacturpeanuttreenut
# vegetoilcoconut
# saltthimixwheatdairitracesoy
# glutenozbottlvegetoil
# disodiumphosphat
# hiddenvalleyranchsaladdressamptop
# hiddenvalleyranchsaladdresstop
# culturbuttermilk
# phosphoracid
# sorbicacidcalciumdisodiumedtaaspreserv
# cocoabean
# wholecondensmilk
# dsorbitol
# raisagentammoniumhydrogencarbon
# sodiumhydrogencarbon
# disodiumdiphosph
# vegetoiluseoilbakeform
# carp
# mullet
# whitefish
# matzomeal
# pike
# pepper
# shorten
# strawberriflavour
# betacarotencolor
# betacarotencolorvitaminmineralscalciumcarbon
# mozzarellacheespartmilk
# cultur
# mozzarellachees
# pepperonipork
# beef
# lacticacidstartercultur
# oleoresinpaprika
# sodiumnitrit
# bht
# hudrogensoybeanoil
# seasonbreadcrumbbleachwheatflour
# cornmaltodestrin
# saltdoughconditioncalciumsulfat
# lcysteinhydrochlorid
# tricalciumphosphat
# seasongarlic
# methylcellulos
# datem
# mediumchaintriglyerid
# buttermaltodextrin
# mediumchaintriglycerid
# preparcheeswater
# sodiumcitrat
# sorbicacidaspreserv
# soybeancottonseoillecithin
# preparcheesmozzarellacheesmilk
# seasonspice
# doughconditioncalciumsulfat
# roastpeanut
# natursesemseed
# solubldextrinfiber
# pumpkinseed
# blackchiaseed
# monkfruitextract
# bleachwheatflourniacin
# folicacidbuttercream
# unsweetchocol
# vanillavanillabeanextractwater
# alcohol
# caramelcolor
# palmsoybeanoil
# maplsyrup
# soybeancottonsesoylecithin
# coloryellow
# bluepreservbytbhqcitricacidpeanutsoymanufacturonmanufacturcontainmilk
# treenutpackagonpackagcontaintracemilk
# treenutsoyprotein
# cornmasaflour
# soybeanpalmcanolaoil
# iodizsalt
# sodiumdiacet
# colorredlake
# chillipepper
# sodiumguanyl
# sodiuminosin
# silicondioxidmilk
# mixtocopherolvitaminmineriron
# butterfat
# cheesseasonmaltodextrin
# annattoextract
# milkalwayreferaccur
# macaronidurumwheatsemolina
# butternutsquash
# cheddarcheesculturmilk
# autolyzyeastextract
# oleicsunflowoil
# annattopaprikaextractcolor
# yellowcornmeal
# cheddarchees
# durumflour
# rosemariextract
# hydrolyzvegetproteinsoy
# powderchicken
# spicesulfit
# chocolchocol
# brownriceflourrice
# fillglucossyrup
# raspberripulp
# redcurrant
# calciumcitrat
# sweetchocolvegetcoatsugar
# vegetoilonepalm
# shea
# sal
# mango
# leavenammoniumbicarbon
# soylecithinsesamseed
# chocolcocoabutter
# glacepineapplpineappl
# potassiumsorbatsodiumbenzoatpreserv
# oleoresinturmer
# sulfurdioxidpreserv
# glaceredcherricherri
# palmshortenpalmoil
# soyproteinthimanufacturonshareusemanufacturcontaincoconut
# sulfitagent
# greenlentilspinachrotinipastawater
# greenlentilflour
# spinach
# greenlentilspinachrotinipastasauc
# lightcreamcream
# parmesancheespartmilk
# sunflowseed
# tapiocasyrup
# cocoacoatsugar
# agavsyrup
# sesamseed
# seasaltallergenalmond
# cashewproductreenut
# glutenfrealmondflour
# buttersweetcreammilk
# microbicultur
# monkfruit
# vanillaextractvanillabeanextract
# himalayanpinksalt
# turkeysausagturkey
# avocado
# multigrainwater
# steelcutoat
# farrowheat
# buckwheat
# redquinoa
# kale
# chard
# cookiflour
# whitesugar
# vanillaflavorchocolsugar
# whitechocolmaltitol
# soycrispsoyprotein
# allulossyrup
# tapiocasyrupsolid
# chicorifiber
# stevialeafextractalmond
# soymanufacturplanttreenut
# palmfruitcanolaoil
# invertcanesugar
# unbromwheatflour
# chocolpiecsugar
# palmfruitoil
# chocolchunk
# groundmustard
# potpiesaucwater
# dumplwater
# durumwheatflour
# chickenchicken
# chardonnaywine
# chickenchickenbroth
# isolsoyproteinisolsoyprotein
# brownrice
# apricotjamapricot
# gellangum
# fdcyellow
# biscuitwheatflour
# vegetoilbutter
# arrowrootflour
# root
# edtacalciumdisodium
# wasabi
# calori
# total
# tran
# sodiummg
# totalcarbohydr
# proteinwat
# chocolchipcanesyrup
# evaporcane
# nongmocornstarch
# cassavastarch
# 
# aluminumfrebakemonocalciumphosphat
# nongmowheatflour
# glutenwholegrainrolloat
# oatflouroatbran
# groundflaxseed
# cranberri
# date
# coconutflake
# blackcurrantsextravirgincoconutoil
# chicorirootfiber
# chocolglazesugar
# mustarddistilvinegar
# granulgarlic
# granulonion
# erythritol
# almondflour
# coconutflour
# oiloleicsunflowoil
# sodiumcaseinmilkderiv
# nongmosprinklsolublfiber
# corngrit
# steviaextract
# tigernutflour
# leavenmonocalciumphosphat
# wet
# invertsugarsyrup
# whole
# sweetencondensmilk
# acidregulcitricacid
# tartaracid
# gell
# calciumstearat
# mineroil
# milksoymanufacturonsharepeanut
# selfrisflourbleachwheatflourbleachwheatflour
# cornfiber
# maltbarley
# pork
# turkeyliver
# chickenliver
# sherri
# truffl
# sherrivinegar
# caramelsulphurdioxid
# sulphit
# sugarsugar
# dextrin
# colorincludbluelake
# mmbrandmilkchocolcandimilkchocolsugar
# titaniumdioxid
# gumacaciasnickerbrandbarmilkchocolsugar
# gumacaciamilkchocolsugar
# flavorsugar
# colortitaniumdioxid
# carnaubawaxmilkchocolsugar
# gumacacia
# flavorskittlbitecandisugar
# stylemeatbalpork
# vegetproteinsoyprotein
# breadcrumbbleachwheatflour
# sodiumtripolyphosph
# fractionpalmoil
# romanocheesromanocheesculturcowmilk
# enzymromanocheesromanocheesculturcowmilk
# seasonmaltodextrin
# seasonsalt
# breadcrumbflourflour
# flourwheatflourniacin
# enzymmozzarellachees
# mediumchaintrigylerid
# cherri
# plum
# groundrice
# soyaflour
# emulsifiers
# flavourmilkprotein
# acidregul
# humectstabilis
# driwholemilk
# soylecithinemulsifi
# dricream
# dributtermilk
# saltmilk
# sheanut
# peanutothertreenut
# glutenflourwhiterice
# vanillaglazeconfectionsugar
# donutglazepowdersugar
# vegetgumcarobbean
# tara
# guar
# chocolprocessalkalicocoabutter
# sodiumbenzoatpotassiumsorbatsulfurdioxiditopromotretent
# tocpherol
# pistachio
# vegetoilrapese
# consistchocolsugarchocol
# bleachwheatflourwheatflour
# animvegetshortentallow
# tallow
# cocoaprocessalkalisoybeanoil
# sorbicacidpotassiumsorbat
# shortentallow
# palmoilshorten
# sodiumstearat
# xanthumgum
# vinegarmanufacturonshareothertreenut
# wholewheatpastriflour
# oatflour
# flaxmeal
# spicewheat
# milkmanufactursoy
# cranberrisugar
# dutchcocoa
# aluminumbakesodiumacidpyrophosph
# vanillaflavor
# artificiflavorblueberribitdextros
# propylenglycolmonoestfattiacid
# palmoilsoybeanoil
# carobbeangum
# canesyrup
# bleachflourbleachwheatflour
# whitechocolchipsugar
# margarinpalmoil
# treenutwheat
# chickpeaflour
# chocolextract
# monkfruitextractsustainsourc
# wholegrainrolloat
# wheatflourbleachflour
# applesaucappl
# soybeanpalmoil
# maltitol
# polydextros
# acesulfampotassium
# sucralos
# icecreammilk
# chocolcookicrunchflourwheatflour
# vegetoilshortensoybeancottonseoil
# powdersugarsugar
# chocolcookipiecsugar
# stabillocustbeangum
# guargummochidoughsugar
# sweetriceflour
# rapeselecithin
# twocornstarch
# chocolchipchocol
# vanillaextractvanilla
# sourcream
# bourbonvanilla
# cinnamonstreusel
# wholewalnut
# zucchini
# choponion
# chopredpepper
# thyme
# milksoyglutennodiacetylbutterflavor
# wholegrainpopcorn
# annattocolor
# purposflour
# groundpecan
# chocolchip
# vanillaextractcaramel
# artichok
# sunfloweroil
# whitewine
# granapadanocheesmilk
# cheesrennet
# summertruflbreak
# lemonjuic
# saltmaizstarch
# lecithinsunflow
# aroma
# mint
# twocrackermeal
# saltsodiumhydrogencarbonwheat
# pinenut
# almondstorecoolplace
# th
# fillsultana
# demerarasugar
# currantalmond
# glacecherricherri
# glucosefructossyrup
# preservsulphurdioxidspiritvinegar
# milkchocolchipsugar
# canesugargranul
# groundcinnamonwheat
# fishshelfish
# nut
# flaxseedflour
# rennet
# rennettoptomatopast
# uncurpepperoninonitratnitritexceptnaturoccurceleripork
# mustard
# spiceextractpaprika
# corncookstarch
# polydextrosmaltodextrin
# runnicaramelfructoscornsyrup
# sweetencondensmilkmilk
# saltbutterbutter
# soyalecithin
# whipcreamcream
# almondnutpast
# stickitoffesaucsugar
# pecannutpast
# cashewnutpastcashewnut
# cornflakemillcorn
# port
# vegetfatcoconut
# sunflow
# fruitconcentrblackberri
# meringugranulsugar
# caramelissugar
# champagn
# colorbeet
# cinnamonpastglucossyrup
# cinnamonoil
# amarettibiscuitsugar
# apricot
# groundnutmeg
# clementinoil
# lemonoil
# bitterorangoil
# pimentoleafoilalmondnut
# cashewnut
# pecannut
# soya
# wheatpeanut
# grape
# sulfit
# liqueurdexpedit
# calciumlactat
# creamcheesmilk
# solublcornfiber
# vegetoilpalm
# carobbeangumbuttermilk
# sourcreamcream
# refinsyrup
# cellulosgel
# bluecitricacidtocopherolretain
# fructosexawholwheatflour
# fructosewholwheatflour
# bluecitricacid
# tocopherolretain
# carbohydrgum
# polyglycerolesterfattiacid
# colortitaniumdioxidmilk
# roasthazelnut
# roastalmond
# stabilglycerolrapese
# acaciahoney
# emulsifisoyalecithin
# candisyrup
# stabilsorbitolwheat
# whipcream
# saltbutter
# raissodiumbicarbon
# milksugarlactos
# emulsifirapeselecithin
# paprikaextract
# dextrossugarmalicacidcornsyrup
# carnubawax
# lemonextract
# banana
# glutenfreoat
# agav
# blueberriblueberri
# ricebrownriceflour
# coconutsugar
# monounsatursafflowoil
# nutmeg
# foragcornsyrupconcentrraspberripulp
# thickenxanthangum
# chocolsugarpastcocoabutter
# emulsifisoylecithin
# fatmateriplantraisammoniumhydrogencarbon
# saltwheat
# soyusemilkhazelnutorangmarmaladglucosejuicorangpulp
# gellpectin
# orang
# thickenxanthangumchocolsugarpastcocoabutter
# fatmateriplantraisammoniumhydrogencarbondiphosphaciddisodiumcarbonatesodiumsaltwheat
# soyusemilkhazelnutforagglucossyruppearpulpsugargellpcitin
# xanthangumacidregulcitricacid
# sodiumcitrataromatopchocolchocolsugar
# cocoapastbutteremulsifisoylecithin
# sodiumbicarbonsaltemulsifisoyalecithinforagcutterglucosefructossyrup
# strawberripulpacidificitricacid
# gellagentpectin
# acidregulsodiumcitrat
# thickenerxanthangum
# purplcarrot
# pastcocoabutter
# duke
# salmon
# sweetpotato
# flaxseoil
# squash
# taurin
# ironaminoacidchelat
# supplement
# zincaminoacidchelat
# cholinchlorid
# cobaltaminoacidchelat
# copperaminoacidchelat
# manganesaminoacidchelat
# riboflavinsupplement
# sodiumselenit
# potassiumiodid
# biotin
# applfiber
# datepastdate
# bakin
# bakeoilpalm
# einkornflourwheattheirmilk
# glutenflourtapiocastarch
# monocalciumposphat
# wheatcornstarch
# watersoyflour
# guarxanthangum
# waterwheatcornstarch
# folicacidwater
# emulsifipropylenglycolmonostear
# palmsoybeanoiltbhqcitricacid
# dextrossoyflour
# flavorwheat
# soybeancottonseoiltbhq
# caramelsugarsyrup
# raisammoniumbicarbon
# potassiumcarbon
# caramelallergentracemilk
# floursugarinteresterifisoybeanoilchocolchipsugarwholemilkcocoabuttercocoavanillabeansoylecithin
# soybeanlecithin
# potassiumsorbatcitricacidpreserv
# annattoturmer
# seasoncheddarblucheesmilk
# extractpaprikaannatto
# groundform
# fullihamwater
# autolyzyeastextractautolyzyeastextract
# weight
# groundformcurewater
# porkbroth
# sodiumerythorb
# sodiumpartmozzarellacheesstarchpartmozzarellacheesmilk
# seasonpalmoil
# lactoswhey
# colorannattoturmer
# seasontoastbreadcrumbwheatflour
# disodiuminosinguanyl
# bluecheesmilk
# palmoilsoylecithin
# citricacidpreserv
# pa
# cheessauccheddarcheesmilk
# extractannattopaprika
# culturwhey
# smokecurewater
# cheddarcheespartmilk
# creamercoconutoil
# sodiumcaseinmilk
# lacticacidlacticacid
# amylas
# whitedistilvinegar
# cornstarchthimanufacturusemilk
# maltodextrincalciumstearat
# sweetencranberricranberri
# chickorirootfiber
# pretzelballwheatflourironasferrousulfat
# maltsyrup
# sodiumbicarbonatecaramelmilk
# ricesyrup
# caramelsugarglycerin
# madagascarvanilla
# palminteresterifisoybean
# vanillaextractbetacarotencolor
# waterbleachwheatflourwheatflour
# palmkerneloilfructoscornsyrup
# bakesodasorbicacid
# natamycinpotassiumsorbat
# cellulosgumxanthangum
# tapiocamaltodextrin
# culturcornsyrupsolidcitricacid
# totalsaturtrangcholesterolmgsodiummgtotalcarbohydrdietarifibersugargproteingvitamincalciumironphosphorumixpreparasdirectwholemilk
# canolaoilhoneycontributanadditcalori
# mg
# mgsodium
# proteiningredientsorganwhite
# cupchocolbakechipcupbuttermargarin
# softencupsugarcupbrownsugar
# chop
# vegetoilpalmfruit
# soybeanolivoil
# potassiumsorbataspreserv
# wheatflourwheat
# oilpeppermint
# statementwater
# culturbrownriceflour
# wholegrainsorghumflour
# refer
# soylecithinasan
# sweetpotatosweetpotato
# tetrasodium
# pyrophosphretardoxid
# defatsoyflour
# glutenflourbrownrice
# sweetrice
# blanchspaghettiwater
# semolina
# sesamebreadchickentenderloinchickentenderloin
# seasonsoysaucsoybean
# modifcornstarch
# mixtriglycerid
# wheatdextrin
# sesamoil
# isolsoyprotein
# modifricestarch
# roastsesamoil
# batterbreadwater
# extractpaprika
# oleoresinpaprikaannatto
# breadsetsoybeanoil
# plumsaucsugar
# saltplum
# ricevinegar
# chilipepper
# soysaucwter
# soysaucsoybean
# vinegarricevinegar
# saucbreadchickensesambreadchickentenderloinchickentenderloin
# soysaucwheat
# leavencreamtartar
# soysaucwater
# mushroom
# spicepastavegetwater
# toastsesamseed
# creamchees
# chocolflavorchip
# nutrolloat
# whitechipsugar
# bankbowkder
# sodiumaluminum
# phosphat
# sorbitantristear
# groundcarawayseed
# wholecarawayseed
# culturriceflour
# wholeblackcarawayseed
# groundginger
# pennrigatpastawheatflour
# vegetarianwater
# lightredkidneybean
# semolinawheat
# pennrigatpasta
# extractturmer
# spinachgarbanzobean
# flavormilkchocolsugar
# chocolchipcanesugar
# sorghumflour
# flaxsemeal
# flourwholegrainspeltflour
# wholegrainoatflour
# lupin
# wholegrainbarleyflour
# fig
# anis
# leavenwheatflour
# maltwheatryeflour
# wheatgluten
# acerolaextract
# monodiglyceridusemilk
# flavornamequantityunitdailivaluetotfatgsatgtranfatgcholestmgsodiummgtotcarbgfibergsugarsgproteingvitaminavitaminccalciumiron
# flaxseed
# millet
# vanillanaturflavorfillsugar
# vegetoilshorten
# emulsifisoylecithinflavor
# emulsifisoylecithinchemicbakesodiumbicarbongluten
# milksoytracepeanut
# soyproteinsoyprotein
# peanutbuttercoatsugar
# peanutoil
# brownricecrispbrownriceflour
# peanutextract
# palmoilproducontreenut
# sausagpork
# mafaldapastasemolinawheat
# sugarmaltodextrin
# roastgarlic
# tomatoextract
# calciumchloridvaluecaloriescalorifatfatgsaturgtranfatgpolyunsaturfatgmonounsaturfatgcholesterolmgsodiummgpotassiumtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumiron
# calciumchloridfatxafatgsaturgtranfatgxapolyunsaturfatgxamonounsaturfatgxacholesterolmgsodiummgpotassiumxaxatotcarbohydrategdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxa
# whitefudgcoatsugar
# minerwheymilk
# peanutsoybeanareuse
# vanillaicecreamcream
# vanillaextractmilkchocolvegetoilcoatmilkchocolsugar
# fillmilk
# swisscheesculturpartskimmilk
# onionwater
# baconbaconcurewater
# chive
# tetrasodiumpyrophosph
# pastriwheatflourwheatflour
# blueberribitsugar
# starchdextros
# fumeracid
# maltodextrinsalt
# yellowyellow
# saltthimixwheat
# treenutpeanut
# vegetoilpalmpalmkerneloil
# sunflowoilsugar
# soywheatalmond
# peanutsoy
# totalsaturtrangcholesterolmgsodiummgtotalcarbohydrdietarifibersugargmaltitolgproteingvitamincalciumironingredientsenrichwheatflourflour
# vegetoilcanola
# palmpalmkernel
# acesulfampotassiumwheat
# vanillaflavorcoatsugar
# chocolcookiflourwheatflour
# sugarsafflowoil
# brownricesyrup
# cellulos
# produconpeanut
# confectionsugar
# treaclsyrup
# vanillapod
# distilwhitevinegar
# calciumdisodiumedta
# relake
# pfpr
# colorincludred
# soywheatpeanutmmmilkchocolcandimilkchocolsugar
# snickerbarmilkchocolsugar
# gumacaciamilksoypeanut
# bittersweetchocolprocessalkali
# sugarcocoabutter
# daiributter
# marshmallowcream
# potatostarchthenbenzoatsoda
# vanillainvertas
# woodfordreservkentuckistraightwhiskey
# invertasanenzym
# nutcashew
# realbuttersugar
# realvanillaextract
# richchocolchip
# tartcranberri
# crunchiwalnut
# deepcocoa
# sweetcoconut
# coconutextract
# applesauc
# realpiecfavoritcandisuchassnicker
# reespeanutbuttercut
# mm
# almondjoyheathtoffebartastbudareanexperiaddit
# cooki
# includgiftbox
# wheypermeat
# hazelnutswalnut
# colorred
# wheatpeanutmmmilksoypeanutmusketmilk
# cocoabutterprocessalkali
# bluesnickerpeanut
# snickermilkchocolsugar
# flavortwixmilkchocolsugar
# gumacaciamusketmilkchocolsugar
# soypeanut
# flavorstarburstcornsyrup
# flavormmmilkchocolsugar
# fruitappl
# colorincludblue
# trollisourbritecrawlercornsyrup
# fumaracid
# sodiumlactat
# acacia
# beeswax
# sodiumcitrattrolliveriberrisourbritecrawlercornsyrup
# bluetrollisourbritecrawlercornsyrup
# redtrolliextremsourbitesugar
# whitemineroil
# flavornamequantityunitdailivaluetotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumironriboflavinniacin
# flourbrownriceflour
# nonhydrogenpalmoil
# chocolchunkevaporcanesugar
# cocoapast
# nongmosoylecithinemulsifi
# glutenfrevanillachunktracemilkproteindue
# glutenfre
# glutenflourglutenoatflour
# stevia
# vegetfiber
# psylliumhusk
# heavicream
# sugarfrechocolchip
# vegetoilpalmoil
# soybeansoybeanoil
# cabbagflake
# carrotflake
# sodiumbenzoatpreserv
# onionflake
# renderchicken
# slicemushroom
# autolyztorulayeastextract
# trehalos
# tbhq
# calciumsilic
# sodiumcarbon
# enzymsoyprotein
# herb
# no
# redlakebluelake
# esterfattiacid
# proplyenglycolesterfattiacid
# pregelatinyellowcornflour
# blueberribitdextros
# oleicoil
# vanillapotassiumcitrat
# calciumascorb
# inositol
# dalphatocopherylacet
# zincsulfat
# calciumpantothen
# coppersulfat
# pyridoxinhydrochlorid
# phylloquinon
# sodiumselen
# gumtragacanth
# acetacidblackblue
# yellowbluebluegreenyellow
# blueredred
# yellowyellowyellow
# hydrolysmilkprotein
# milkchocolmilksolidminimum
# milkchocolvegetfatadditcocoabutter
# candifruitmelon
# whestglucosefructossyrup
# syrup
# unleavenbreadpotatostarch
# sugarwater
# fdyellow
# soydairi
# groundgingerstatmentthiwheat
# milkmanufacturonsharesoy
# creamcoconut
# mace
# mmminimilkchocolcandimilkchocolsugar
# flavorsalt
# crisp
# riboflvin
# powdersugar
# almondwheat
# treenutmilk
# leavenagentdisodiumdiphosph
# sodiumcarbonacid
# ammoniumcarbonacid
# takoyakiflourmixwheatflour
# maltsugar
# soysauc
# seaweextract
# bonito
# season
# polysaccharidthicken
# flourtempurasquidtenhanaintoheaven
# squid
# seasondripicklgingerginger
# sugarmaltos
# acidul
# redradishpigmentseawegreenlaver
# hazelnutpulp
# cocoaprocessalkaliammoniumbicarbon
# fdcblue
# fdcbluelake
# fdcyellowlake
# oil
# glycerid
# fdcredlake
# zincoxid
# colorfdcredmanufacturpeanut
# alphatocopherylacet
# bananachipbanana
# milkwheat
# othertreenutpresentthi
# alphatocopherylacetsoy
# colorsprinklsugar
# turmerbotanextract
# raisagentdisodiumdiphosph
# coconutpalmsugar
# potatostarchtapiocadextrin
# stevialeafextract
# potassiumsorbatmilk
# flavorleaven
# palmsoybeansoybeanoil
# newzealandanchorbutter
# importwalnutgenerpremiumfiveyearold
# oakbarreltortugagoldrumsoldpublic
# barley
# mmmilkchocolcandimilkchocolsugar
# margarinvegetoilpalmfruit
# sugarchocolchipmaltitol
# milkhandlpeanuttreenut
# onionextract
# garlicextract
# milksesam
# saturfat
# dietarifiber
# proteincornstarch
# vegetmargarinfatoilcoconutpalmfraction
# driroastpeanutpeanut
# chocolcandimaltitol
# maltitolsyrup
# monodiglyceridcitricacid
# sucralosalmond
# tbhqcitricacid
# peanutbuttercupchocolcandimaltitol
# fdccoloryellow
# sodiumbenzoatpeanutbuttercrunchmaltitolsyrup
# peanutbuttercrunchmaltitolsyrup
# polyglycitol
# saltpeanutdelightchocolcandimaltitol
# peahullfiber
# chocolchipchocolnonorgancanesugar
# nonorgancanesugar
# palmstearin
# carbohydr
# protein
# calciumsodiumcasein
# lglutamin
# dicalciumphosphat
# potassiumcitrat
# magnesiumoxid
# dlalphatocopherylacet
# ferroufumar
# dcalciumpantothen
# manganessulfat
# chromiumpicolin
# sodiummolybd
# phytonadion
# cholecalciferol
# cyanocobalamin
# beet
# acesulfamek
# mannitol
# groundhazelnut
# soymilk
# carrageenannopreserv
# hazelnutcreamsugar
# flavourhazelnutflavour
# vanillaflavour
# compoundmilkchocolsugar
# ammoniumcarbon
# preservtracesesam
# drinoaddedsugarchocolchipchocol
# allulos
# monkfruitextractpreparchocolchipfudgbrownibakemix
# ironthiaminmononitr
# turmerpaprikaannatto
# macaronisemolinawheatflourniacin
# mayonnaissoybeanoil
# sweetpicklrelishcucumb
# celeriseed
# redbellpepper
# mustardwater
# turmerpaprika
# calciumdisodiumedtaretain
# sweetpicklcucumb
# chocolflavorcoatsugar
# palmoilproduconpeanut
# batterchickenchicken
# chilipastredchilipepper
# oysterextractoyster
# vegetbroccoli
# oystersaucwater
# sesamseedoil
# gelatinfre
# sodiumcitratcarnaubawaxgluten
# gumacaciamilksoypeanutskittlbitecandisugar
# tunasaladtunalighttuna
# vegetbroth
# waterchestnut
# heatstablmayonnaissoybeanoil
# gluconodeltalacton
# onioncrackerflourwheatflour
# tunacrackermilk
# pastasemolinawheat
# chickenbrothwater
# oatflake
# granulcanesugar
# milletflour
# hullmillet
# distilcidervinegar
# calciumdisodiumedtaflavor
# wholegrainriceflour
# cellulosfibr
# sesamseedsoya
# cacao
# blueberricrumbl
# canolasafflowpalmoil
# tbhqcitricacidonothernutpeanuttreenut
# ascorbacidasdoughcondition
# buttermilkmilk
# bactericultur
# soybeancanolaoil
# culturwheatflour
# ghee
# cilantro
# cashewbutter
# almondbutter
# psylliumseedhusk
# hydroxypropylmethylcellulos
# citricacidsoyrollrollcaloricaloriproteintotalcarbdietarifibersugarsattransodiummgcalciumriboflavinthiaminniacin
# vanillachocol
# mmbrandminimilkchocolcandimilkchocolsugar
# folat
# cookiwheatflourbleachwheatflour
# annattoextractcookiwheatflourbleachwheatflour
# annattoextractcookiwheatflourwheatflour
# margarinsoybeancottonseoil
# ammoniumbicarbonmmmilkchocolminibakebitmilkchocolsugar
# colorincludyellowlake
# whitegrape
# xanthangumtopelevenwheatgluten
# sulfitproductop
# vegetoilcocoabutter
# sunflowsafflowoil
# hydrolyzmilkprotein
# greekyogurtlightcreamchees
# culturmilkcream
# cerealfiber
# chocolliqour
# glycemmonosaccharid
# bicarbonsoda
# calciumacidphosphat
# dehulsoybean
# glycemfruit
# milkiwaybrandmilkchocolsugar
# monosodiumphosphat
# twosoyprotein
# hydrolyzcorngluten
# hydrolyzwheatproteinsodiumhexametaphosph
# torulayeast
# magnesiumcarbon
# vegetproteinwheatgluten
# waterhydrat
# sodiumcasenate
# twolactos
# hydrolyzvegetproteinwheatgluten
# corngluten
# sodiumphosphattripolyphosph
# tetrapyrophosph
# hexametaphosph
# monophosph
# vitaminminerniacinamid
# ironferrousulfat
# pyridoxinhydrochloridriboflavin
# succinacid
# hydrolyzwheatprotein
# cottonsesoybeanoil
# magnesiumstearat
# bleachbeeswax
# soymilkcompon
# folicacidonevitamindietariliinsignifictran
# sugarsalt
# carob
# sodiumhydroxid
# shellac
# raisinraisin
# spicefdcred
# fdampccoloryellowamp
# raspberriappl
# raspberriappltreenutwheat
# citricacidhelp
# orangpeelorangpeel
# fdampcred
# soyproteinnamequantityunitdailivaluetotfatgsatgtranfatgcholestmgsodiummgtotcarbgfibergsugarsgproteingvitaminavitaminccalciumiron
# lowersodiumseasalt
# beefextract
# steviaextractmilk
# peanutwheat
# starterwheatflour
# fdc
# prune
# applpomac
# algin
# preservsulfitagent
# vanillasugar
# millflaxseed
# xanthangumsemisweetchocolchipsugar
# millflaxse
# xanthangummilk
# flourtapiocastarch
# gum
# arab
# dextrosanhydr
# semisweetchocolchipcanesugar
# resistcornstarch
# flaxseedmeal
# molassenzymbutter
# bakingsoda
# oilrosemari
# preservativescalciumpropion
# psyllium
# polyglycerolester
# preservcalciumpropion
# sweetpotatoflour
# beetrootbetacaroten
# canolaoilsafflowoilsunflowoil
# cassavaflour
# pumpkin
# sugarfrechocolchipnongmomaltitol
# chocolliquorprocessalkalicocoabutter
# sorbitantristearsoylecithinemulsifi
# orgainproteingrassfedmilkprotein
# orgaincarbohydrbrownricesyrup
# ricedextrin
# oleicsunsunflowoil
# natur
# orgaindialphatocopherolacet
# sodiumascorb
# zincglucon
# copperglucon
# magnesiumsulfat
# tripotassiumcitrat
# orgainfruitblueberri
# acai
# crackermeal
# twochocolchipsugar
# crabmeat
# breadcrumbriceflour
# nogrademustardseed
# seasoncelerisaltsalt
# spiceincludredpepperblackpepper
# celeriwater
# sodiummalat
# apricotjamglucosefructos
# apricotjamcrucosfructos
# dicalciumphosoh
# cunnamon
# apricotjamappl
# sodiumbenzoatsulfurdioxidaspreserv
# bakeprocessonsameascontainchocol
# fiberoatfiber
# flax
# bananaextract
# dairitreenutwalnut
# bittersweetchocolliquorprocessalkali
# maltbarleyflourwheat
# hazelnutwalnut
# sweeteninvertsyrup
# peastarch
# nonshorten
# blackstrapmolass
# peaprotein
# sodiumcarboximethylcellulos
# peafibr
# vanillaglazesugar
# watersorbitol
# breadcrumbwheatflour
# turmerextract
# meatbal
# meatbalbeef
# pastawholewheatflour
# breadcrumb
# bluemanufacturpeanuttreenut
# ricottacheeswhey
# moisturpartmilkmozzarellacheesculturmilk
# vegetbasevegetcarrot
# parmesancheesculturmilk
# powdercellulos
# sage
# thymeindic
# butternutsquashravioliwheatflour
# moisturpartmozzarellacheesculturmilk
# vegetbrothvegetcarrot
# partmilkmozzarella
# ricottachees
# roasttomato
# fireroasttomato
# parmesanchees
# evaporcanesyrup
# evaporsugarcane
# lemonwater
# sweetenerythritol
# hydrolyzcollagen
# almondnetcarbarecalculbysubtracttotalfibererythritoltotalcarbohydr
# arealmondflour
# buttercreamsalt
# yellowyellowfloridaorang
# fullcreammilk
# humect
# raisagent
# milkchocolmilksolidminimumcocoasolidminimum
# chickensaladchicken
# lightmayonnais
# dresswater
# saltcrackerflourwheatflour
# soylechin
# monocalciumphosphatcookiwheatflourniacin
# saltmixfruitcupdicepeach
# dicepear
# pineappl
# doughwheatflour
# glazemilkprotein
# margarinvegetoilpalm
# sunflowcottonse
# ethylalcohol
# canolalecithin
# calciumpropioncocoafillpalmoil
# fruit
# twosoylecithinwheat
# twosoylecithin
# twoflavor
# twobakesoda
# twovanillaextract
# twosalt
# soytreenut
# chocolchipunsweetendchocol
# whitewholewheatflour
# saltvanillaextractwheat
# milkchocolcornsyrupsugarhydrogenpalmkerneloil
# milklessmilkfat
# caramelmilk
# vegetoilsoybeanpalmoiltbhq
# palmkernelcoconutoil
# peanutbutterroastpeanut
# rapese
# twodrimilksalt
# yellowlaketran
# tertbutylhydroquinon
# abbazabacornsyrup
# monodiglyceridbighunkcornsyrup
# spirulinaextract
# packag
# colorvaluarebaseoncaloridietvaluhigherlowerdependoncalorineed
# saltprocessonsameascontainchocol
# cauliflow
# preparpizzacrustpizzacrustpreparcrustcauliflow
# debonturkey
# turkeybroth
# vitamincholinchlorid
# riboavin
# cassiagum
# flaxoil
# minerzincaminoacidcomplex
# ironaminoacidcomplex
# manganesaminoacidcomplex
# copperaminoacidcomplex
# cobaltglucohepton
# rosemari
# yuccaschidigeraextract
# soyproteinwater
# inulinchicoriroot
# barleyextract
# sodiumacet
# vegetoilcorn
# canolasunflowoil
# wheatglutencornstarch
# sauccayennpepper
# breadcrumbbleachwheatflourflour
# yolk
# pecansalt
# fullicanolaoil
# citricacidascorbacid
# sodiumcitrattriethylcitrataswhipaid
# sugarvanillabeanextract
# romanocheessheepcowmilk
# beefpork
# reconstitutbutterbutter
# aluminumphosphat
# doughconditionwheatflo
# tempurachickenchickenwhitemeat
# winevinegar
# honeyfrivegetoil
# misosoybean
# koji
# whitewinewine
# redchilipepper
# blackbeanpastblacksoybean
# honeyfrivegetoilsaucwater
# ricekojiaspergilluoryza
# spicecoatwheatflour
# sodiumbenzoatsorbicacidcalciumdisodiumedta
# propylenglycolalgin
# saltphosphoracid
# whitewinevinegar
# blacktruffl
# vegetpalmkernel
# palminteresterfisoybeancottonse
# palmcottonse
# whitechunksugar
# margarincanolaoil
# vegetmonoglycerid
# treenutmealalmond
# soda
# vanillafillsugar
# vanillacrustflourcottonseoil
# ovomaltinbarleymaltextract
# vitamin
# pantothenacid
# emulsifisunflowlecithin
# vanillintracepecan
# annattoveget
# sodiumbicarbonbakesoda
# blackpepperspicemilk
# yeastsalt
# meatbalbeefpork
# pastawheatflour
# celeriextract
# soylecithinwheat
# hazelnutpeanut
# flavormilkchocolicecreamcream
# whitechocolicecreamcream
# grainvinegar
# almondwalnut
# milkmanufacturusewheat
# soyleicthin
# datemsodiumstearoyllactyl
# creamcheesculturmilkcream
# goldenraisin
# yellownut
# sugarcanefiber
# xaenrichbleachflour
# lemonflavorpiec
# chicorurootinulin
# lemonflavorpiecsugarpalm
# canolasoybeanoil
# aluminumsulfat
# lemonflavordrizzl
# applcidervinegarcitricacid
# othertreenutalmond
# macadamianutoilmacadamiaproduconusepeanut
# saltpepperseasonseasalt
# oniongarlic
# filbertshazelnut
# brazilnut
# premiumcacao
# artificu
# cupservfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxaingredichocolsugar
# vanillaextractflourfreglutenfre
# potassiumsorbatsoylecithin
# sourdoughstarter
# bamboofiber
# bakegluconodeltalacton
# orangcitrufiberthiamin
# saltwarnwheatflour
# milkpeanutoil
# glucossolid
# cinnamonwheat
# enzymbluecheesculturmilk
# paprikaannattoextractcolor
# cheessaucwater
# durumwheatsemolina
# macaroniwater
# acetlacticacid
# tomatotomato
# stylemeatbalbeef
# vegetproteinsoyflour
# styleseasonsalt
# garliconion
# parmesancheespartskimmilk
# whitepepper
# beefsugar
# extractgarlic
# ferrousulfatiron
# crushtomato
# spicesoy
# sesampoppiseed
# calciumstearoyllactyl
# calciumpropionpotassiumsorbat
# calciumperoxid
# amylasenzym
# colorannattoextract
# chocolchipcookicakechocolchipsugar
# soylecithinanemulsifivanilla
# carmel
# sodiumbenzoataspreserv
# betacarotenas
# wheatsnickerdoodlcookicakesugar
# colorbetacaroten
# levenagent
# wheatfloursugarbittersweetchocolsugar
# soylecithinasemulsifivegetoilmilkchocolsugar
# soylecithinasemulsifi
# ferricpyrophosph
# thiaminmononitrat
# folicacidwhitechocolsugar
# ammoniumbicarboncinnamonwholemilk
# caramelcolormanufacturpeanuttreenut
# cocoabutterwholemilk
# butterdairicreamcherricherri
# fdred
# cocoacocoa
# potassiumsorbatsorbicacid
# milkcream
# prebiotfiber
# vanillabean
# carobgum
# seedlessraisin
# carrotstrip
# edamam
# greencabbag
# disodiumsuccin
# broccoli
# sodiumglucon
# chocolchipcookichocolsugar
# toffepiecsugar
# sunoweroil
# flavorwhitechocolmaccookiflourwheatflour
# flavoroatmealraisincookirolloat
# strawberrifillsugar
# pyridoxinhcl
# vegetshortenpalmkerneloil
# preservsodiumpropion
# palmfractionpalmoil
# acet
# virginiapeanut
# peanutsoybeanoil
# vinegarmaltodextrin
# flavorsoy
# milkthimanufacturonpeanut
# soytraceamountpresentoz
# satur
# totalsugar
# includsugar
# significsourc
# calcium
# potassiumtellhowmuchnutrientcontributdietcaloridayusegeneradvic
# greenchili
# tamarind
# veg
# rosewat
# cardamon
# flourwheat
# calciumacidpyrophosph
# monocalciumphosphatmonohydr
# potassiumbicarbon
# coloryellowred
# bita
# folic
# teffflour
# gumxanthangum
# amaranthflour
# consistmilkchocolsugar
# raspberrisorbitol
# orangpeelhoney
# saltmolass
# fdcoloryellow
# bittersweetchocolcocoaliquorprocessalkali
# marshmallowcreaminvertsugar
# benzoatsoda
# woodfordreservkentuckistraightbourbonwhiskey
# intertasanenzym
# coffebean
# confectionglazesoymanufacturplantpeanut
# blueberrinuggetdextros
# shortensoybeanoil
# sodiumsilicoalumin
# soylecithinmilk
# flavorvaluarebaseoncaloridietmuffinaboutvaluecaloriescalorifattotfatgsaturfatmgtranfatmgcholesterolmgsodiummgtotcarbohydratesgdietarifibergsugargproteingvitaminavitaminccalciumiron
# aboutvaluecaloriescalorifattotfatgsaturfatmgtranfatmgcholesterolmgsodiummgtotcarbohydratesgdietarifibergsugargproteingvitaminavitaminccalciumiron
# flavorvaluarebaseon
# caloridiet
# caloridietmuffin
# flavorvaluarebaseoncaloridietmuffinaboutfatxatotfatgsaturfatmgtranfatmgxacholesterolmgsodiummgtotcarbohydratesgdietarifibergsugargxaproteingxavitaminaxavitamincxacalciumxaironxa
# virgincoconutoil
# shredcoconut
# louhanguo
# produra
# soylecithinvitaminminerpalmit
# raisammoniumcarbon
# wheatflourwholewheatflour
# margarinvegetoilpalmfruitoil
# soybeanolivoilwater
# prunepast
# vegetoilpalmpalmkerneloilsorbitantristear
# soybeanpalmoiltbhq
# wheatbran
# solublwheatfiber
# almondflourvitaminminercalciumcarbon
# coatsugar
# sweetencondensmilkcondensmilk
# toastsoypiec
# magnesiumphosphat
# flourhardwheatflour
# whitevinegar
# limonen
# soylecithinfructoscornsyrup
# chocolateychipsugar
# twofructoscornsyrup
# granolawholegrainrolloat
# vanillincoconut
# wheatothertreenut
# vanillaflavornutmeg
# cinnamoncrustflourwheatflour
# vegoil
# cranberricranberri
# bakexadpowd
# seasaltpeanut
# soypackonshareothertreenut
# butterinvertsugar
# raspberriredraspberri
# purestrawberri
# berriraspberriotherflavor
# icesugar
# flourcornflour
# quinoaflour
# coffeicecreamcream
# brownsugarmolass
# flavorchocolatichipsugar
# basilflavormilk
# pecorinoromanocheespdoculturmilk
# granapadanocheespdoculturmilk
# potatoflake
# basilflavor
# cashewtraceothertreenut
# chipotl
# cumin
# fruitjam
# chocolnotethigluten
# thereforitkitchen
# whichglutenitdorecommenditglutenpersonmacaron
# cookiwrapflavor
# soylecithinusemilk
# toastalmond
# sugarsyrup
# wafer
# orangvanillaflavortracehazelnutpeanut
# palmoilmargarin
# blanchpeanut
# diglycerid
# rawhempseed
# bitteralmondfewpinenut
# slat
# seasonhydrolyzsoyprotein
# asaderocheddarcheesmilk
# potassiumlactat
# cornoilsafflowoil
# salsaranchdressvegetoilsoybeanoil
# chile
# chickenribmeatchickenribmeat
# salsatomato
# tortillachipwhitecorn
# nachochililimeseasonmiwhey
# potatostarchpowdercellulospreventcake
# jalapenopepper
# salsaranchdress
# romainlettuc
# xanthaangum
# cheesmontereyjackquesoquesadillacheesmilk
# tracelimemilk
# natamycinmoldinhibitor
# limesolid
# sodiumbenzoatpotassiumsorbataspreserv
# chees
# buttermilkculturmilk
# nonmilk
# vegetcoconut
# sorbitolsyrup
# hazelnutoil
# pomegran
# elderberri
# cocoanib
# himalayasalt
# caramelsugar
# vanillaseed
# passionfruit
# fructosesyrup
# lacresin
# anhydrbutterfat
# raisbakesoda
# gellcitrufruitpectin
# barleyflour
# humectglycerol
# thickensodiumalgin
# potassiumaluminumsilic
# emulsifimonodiglyceridfattiacid
# stabilgumarab
# carageenan
# cohin
# curcumin
# beetroot
# titaniumoxid
# pumpkinspice
# cornoilsalt
# redbeet
# yellowcornmealyellowcornmeal
# twocornsyrupsolid
# hydrolyzvegetproteincornprotein
# hydrolyztorulabreweryeast
# hydrolyzvegetproteincorngluten
# porkliver
# redwine
# porcinimushroom
# flavorlemon
# vanillaorang
# honeymilk
# perserv
# candifruit
# sugarflavor
# grassfedpasturraisbutter
# mixnut
# seed
# aluminumbake
# herbspicevari
# peanutmanufacturplantwheat
# identpreservwheatflour
# wholesombiodynamcanesugar
# fairtradechocolchipcanesugar
# fairtradecocoa
# bakesodanongmocornstarch
# coffepowderorganvanillaextractsugar
# distilvinegarfructoscornsyrup
# romanocheesmilk
# glycerolmonostear
# glycerol
# sulfurdioxidmaintaincolor
# propylenglycolmonoest
# hydroxylsoylecithin
# honeywheatstarch
# propylenglycolmonoestear
# soybeanwheatmilk
# premiumcinnamon
# soyproteinwheatstarch
# glutamacid
# twowheatstarch
# xanthamgum
# nongmofiberoatfiber
# ricefiber
# erythirtol
# groundchicken
# flavornonmeatsourc
# swissstakesoyproteinwaterhydrat
# oniontorulayeast
# hydrolyzsoycornprotein
# vitaminniacinamid
# drimilkgraviwater
# primestakevegetproteinwheatgluten
# wheatfibergraviwater
# palmsunflowvegetoil
# hazelnutpastcream
# raisagentsodiumcarbonammoniumcarbon
# flavourtracepeanutsoynofat
# greenonion
# manufacturfish
# manufacturtreenut
# manufacturpeanut
# manufacturcrustaceanshellfish
# sorbitolcontainglucos
# starchcontainflavor
# disodiumguanylatexacontaindisodiuminosin
# chocolchipwheatflour
# carameloatmealraisinoat
# allspicpeanutbutterpeanutbutterdriroastpeanut
# canesugarpeanut
# sodiummetabisulfitpotassiumsorbataspreserv
# drialmondflour
# monkfruitextractpreparpancakmix
# almondmilk
# milksugar
# iodisseasalt
# smokebaconpork
# milkiwhite
# saltsubstitut
# whitewineextract
# celerimustard
# bakeryeastextract
# dicetomato
# flourvegetoiltapiocastarchsalthydrolyzsoyproteincontaindicetomatocontainhydrolyzcornproteincontainsoyproteincontaingarlicpowdercontainsoysaucwatersoybeansaltwheatsodiumbenzoat
# greenpea
# powderbeef
# crustaceanshellfish
# sodumtripolyphosph
# flavorglutenfre
# premiumpeanutbutter
# expelpresspalmoil
# peach
# redplumjumboalmond
# cashewroast
# saltsmokialmondalmond
# canolaoilsafflowoil
# hickorismoke
# hydrolyzcornsoyprotein
# flavorcolosspistachio
# saltnut
# cornsoyproducpeanut
# candiorangpeelorangpeel
# orangoilbakegluconodeltalacton
# monopotassiumtartrat
# carragenan
# brownicontainsugar
# belgianchocol
# bakecalciumacidphosphat
# cornstarchcaramelincludcaramelsugar
# soylecithinchocolchipincludchocolchipsugar
# vanillabeancoconutincludcoconutchip
# coconutextractcoconutextract
# citricacidcreamcheesincludcreamcheesmilkcreamcheescultur
# stabilespressonibincludcocoanib
# coffeextractcoffe
# agavsyrupmintchocolincludchocolchip
# peppermintoilhanoadditpecanincludpecanhalvraspberriswirlincludraspberricompoundsugar
# redgrape
# flavorpectintoffecrunchincludtoffebarpiecsugar
# soylecithinwalnutincludwalnutpiecwhitechocolincludwhitechocolchipsugar
# emulsifivanillin
# sugarcornsyrupchocolchocolsugarcocoamilkcocoabuttersoylecithinpgpr
# sugarcornsyrupchocolchocolsugarcocoamilkcocoabutterlecithinpgpr
# walnutmeal
# nosugarchocol
# cocoaprocessalkalimaltbarley
# spaghetti
# riboflavinfolicacid
# beefbeef
# sodiumpolyphosph
# sodiumpropionpotassiumsorbat
# ironthiamin
# mononitr
# wheatfloursalt
# yeastextractsalt
# chickenribmeatwaterwheatflourseasaltsugargarlicyeastextractsaltoniongarlicwhitepepperblackpepperyeastceleriseedextract
# chickenripmeat
# chickenribmeat
# celeriseedextract
# garlicwhitepepper
# extractceleriseed
# wheatflourseasalt
# pineapplcherricornsyrup
# potassiumsorbatsodiumbenzoataspreserv
# pineapplyellowoleoresinturmer
# cherriredfdcredsulfurdioxidpreserv
# wheatflourascorbacid
# margarinvegetoilsoybean
# flavoralmondemulswaterpropylenglycol
# frenchoilbitteralmond
# sherirumcopropylenglycol
# ethylvanillincolor
# brandi
# benzoatsodaaspreservalertthinutpeanut
# sodiummetabisulphit
# alum
# preservbenzoatsoda
# saltpepper
# caolaoil
# anchovisulfitmanufacturusewheatflourdairi
# arabgum
# redpepperextract
# cookwinerice
# fdcyellowno
# calciumacet
# dutchcaramelvanillachicorirootfiber
# monkfruitextracthoneyoatwheatflour
# monkfruitextractcookicreamchicorirootfiber
# monkfruitextractsnickerdoodlchicorirootfiber
# chamomil
# wholegoatmilk
# chocolswirlsugar
# almondcottonseoil
# espressocoffebean
# guarcarobgum
# vanillasalt
# classicmayonnaissunflowoil
# fairtrade
# sweetengrape
# butterispreadoilpalmfruit
# canolaolivoilwater
# humectgrape
# leavencalciumlactat
# vanillaextractvanillabean
# seasaltsalt
# degerminyellowcornflour
# ammoniumsulfat
# microcrystallincellulos
# chocolcocoa
# spongbutter
# saucbrownsugar
# flourbasesugar
# creamcheesfillwater
# creamcheesmilkcream
# whiteicesugar
# cornsyrupagar
# redcolorwater
# propylparaben
# softgelpastwater
# onecolorred
# blueblue
# vegetgum
# twococoaprocessalkali
# cornsyrupcocoa
# thiaminmononitrateb
# riboflavinb
# cottonseoiltbhqcitricacid
# confectionericoatsugar
# wheymilk
# supergrassnutrientamaranth
# chia
# wheatgrass
# barleygrass
# oatgrasssupersproutamaranthsprout
# quinoasprout
# milletsprout
# buckwheatsprout
# garbanzobeansprout
# lentilsprout
# adzukisprout
# flaxsprout
# sunflowsprout
# pumpkinsprout
# chiasprout
# superberrisuperappl
# cabbag
# parsleyleaf
# brusselsprout
# greenbellpepper
# cucumb
# gingerroot
# asparagu
# tartcherri
# blackberri
# acaciagum
# probiot
# vegetoilonecanolaoil
# monkfruitsweetenerythritol
# grassfbutter
# sprinklarabgum
# redcabbagextract
# radishextract
# kosherfishgelatin
# alpinmilkchocolpiecsugar
# stabil
# emulsifieb
# thicken
# totalsaturtrangcholesterolmgsodiummgtotalcarbohydrdietarifibersugargproteingvitamincalciumironingredientsglutenflourbrownrice
# cinnamonusa
# chickengroundformchickenmeat
# yellowsquash
# flavorpotassiumsorbat
# chocolfrecklsugar
# vegetextractmochidoughsugar
# vegetextract
# creamtartarsalt
# milkiwaymidnightchocolsugar
# flavormusketmilkchocolsugar
# flavormilkiwaymilkchocolsugar
# flavorsnickermilkchocolsugar
# coatsalt
# honeysolid
# doughconditionlcystein
# crustflourwheatflour
# followyeast
# lcystein
# honeypotassiumsorbatpeanut
# turmercolorcaramel
# crystalfruitcrystalorang
# crystalpapayacrystalcitron
# preservcalciumpropionsorbicacidadditsynthetbetacarotenglutentracepeanut
# soyderiv
# ryebarley
# vegetfatpalm
# sunflowvariproport
# rehydr
# fiber
# pasta
# raisagentammoniumcarbon
# diphosph
# sodiumaluminiumphosphat
# twocalciumcarbon
# watervegetoilsoybean
# soybealoil
# sorbicacidcalciumdisodiumedta
# coldpressoleicsafflowoil
# applsauc
# powdertofu
# huckleberri
# treenutwheatrusselstoverassortfinechocol
# fdcredmolass
# handcraftsmallbatch
# realchocol
# watersugar
# assortfillrusselstoverfamoucream
# russelstoverassortfinechocol
# assortchocolredfoilheartarehandcraftsmallbatch
# walnutalmond
# coverdelicimilkchocol
# carmincolorbeenproduconsharepeanut
# bluepotassiumsorbatsodiumbenzoat
# chewnut
# cocoaapricotsulfurdioxid
# bakesodapeppermintoil
# maltwheatflourwheatflour
# designwheyfullspectrumpeptidrbghfreewheyprotein
# rbghfreewheyprotein
# lleucin
# lphenylalanin
# digestprebiotvegetfiber
# probiotlactobacilluacidophilu
# longum
# plantarum
# vegetarianproteasenzym
# electrolytcalciumphosphat
# creamextract
# bvitamincalciumpantothen
# milkmanufacturproducsoy
# chickenskin
# chocolchipcocoa
# molassflavorcoatsugar
# oatmeal
# bakesodaflavor
# dohtoneenzym
# wheatflower
# oreochocolcookiflourwheatflour
# oleiccanolacanolaoil
# vanillavanillaextract
# choppickl
# potassiumsorbatcalciumdisodiumedtaaspreserv
# sodiumbisulfitbha
# culturdextros
# chickenbasechickenmeatchickenbrothchickenmeat
# starchriceflour
# baconbasebaconcurewater
# sodiumnitrat
# hamcurewater
# smokemaltodextrin
# drimilkpalmit
# konjacflour
# annattocolorwheat
# marshmallowsugar
# chocolcoatsugar
# lacticacidestermonoanddiglyceridcitricacidhelp
# grahamcrackerflourwheatflour
# grahamflour
# milksoysharecontainpeanut
# dillpicklcucumb
# annattosoybeanoil
# blueberricrumblblueberri
# lemonzestlemonpeel
# crystalsugar
# calciumcaseinwheyprotein
# chocolflavorchipsugar
# dutchcocoaprocessalkali
# watercocoa
# vegetoilcanolaoil
# apricotkernel
# belgianchocolchipsugar
# stabilguargum
# sorbitolvegetglycerin
# propylenglycolmonodiesterfatfattiacid
# raisagentsodiumacidpyrophosph
# soytracecoconut
# vegetshortensoybeanoil
# cottonseoilcottonseoiltbhqcitricacid
# cocoaleavenbakesoda
# cocoasoyflour
# cosmiccandipiecchocolchipsugar
# leavensodiumaluminumphosphat
# colorcaramel
# wholemilksolidcowmilk
# ...
# cyanocobalamincrunchipeanutbutterbrownricesyrup
# crunchipeanutbutterbrownricesyrup
# vitaminminerdicalciumphosphat
# cyanocobalaminwhitechocolmacadamianutxaorganbrownricesyrup
# cinnamonvitaminminerdicalciumphosphat
# whitechocolmacadamianutbrownricesyrup
# canesyrupunsweetenchocol
# barleymaltextractvitaminminerdicalciumphosphat
# rainforestallianc
# cinnamonvitaminminerxadicalciumphosphat
# cyanocobalaminwhitechocolmacadamianutbrownricesyrup
# datecrumbl
# wholegraintritical
# colorspirulinaextract
# potassiumsorbatcalciumdisodiumedta
# walnutoil
# wheatflourmaltbarleyextract
# soybeanoilpalmoilcoconutoil
# monoglyceriddiglyceridethoxylmonoglyceriddiglycerid
# yellowcolor
# lifesavercollisgummicandibag
# godivachocoltruffloz
# vanillacocoasolidminimum
# milksolidminimumcoinsservgnutrientamountservingdailivaluecaloriescalorifattotfatgsaturfatgtranfatcholesterolgsodiummgtotcarbohydratesgdietarifibergsugargproteingvitaminavitaminccalciumiron
# milksolidminimum
# additblueraspberriflavor
# knockoutpunchbufferlacticacid
# ringpopsugar
# bufferlacticacidadditblueraspberriflavor
# bluestrawberriartifici
# redpushpopsugar
# redbabibottlpopsugar
# redjuicidroppopsugar
# invertglucossyrup
# wateradditblueraspberriwatermeloncitricacid
# yellowknockoutpunchbufferlacticacid
# additbluerebelcitricacid
# babibottlpopsugar
# additsourblueraspberrimalicacid
# juicidroppopsugar
# strawberricitricacid
# strawberriartifici
# pushpopsugar
# organicricmaltodextrin
# wholebuckwheatflourleavenmonocalciumphosphat
# culturbuttermilkpowderorganmilk
# wholebrownflaxse
# masaharina
# beetwheat
# seasalthazelnut
# almondalmondoil
# whitentoothpast
# anisseedfennelseedcoriandseed
# cinnamonclovefrctuamoni
# lowfoamnaturderivcleancoconutderivsurfact
# watersoften
# plantderivantifoamagentglycerolmonool
# oleicacid
# alkalinbuilder
# nonanimderivenzymremovproteinstarchstainfabric
# antiredepositagentsodiumcitrat
# borax
# cleanenhanc
# oreorcooki
# seasaltpeanutflour
# preservbycalciumpropion
# 
# tbhqbht
# spicepaprika
# chipotlpasillachile
# noodlsalt
# topshitakmushroom
# soupbasemisopast
# soupbaseseaweextract
# soupbasesaltsake
# soupbasesoysauc
# soupbasecanesugar
# topfreeztofu
# noodltapiocastarch
# noodllacticacid
# toppotassiumcarbon
# soupbasewater
# soupbasedextros
# soupbaseonion
# topbokchoy
# topsugar
# topchilipepperflake
# topfreezgreenonion
# soupbaseyeastextract
# rollspelt
# chocolchunkevapo
# chocolchunkevaporcane
# freezedriberrifreezedristrawberri
# passionfruitfromconcentrwater
# wholeblackpeppe
# wholegreenpepper
# wholepinkpepperwholewhitepepper
# bluesoylecithinpopservservingdailifatxatotfatsaturfattranfatxacholesterolsodiumtotcarbohydratesgdietarifibersugargxaproteinxavitaminaxavitamincxacalciumxaironxa
# bluesoylecithinpopservservingdailivaluecaloriescalorifattotfatsaturfattranfatcholesterolsodiumtotcarbohydratesgdietarifibersugargproteinvitaminavitaminccalciumiron
# bluesoylecithin
# pricklipearcactu
# gardeinwater
# expelpr
# rawcanesugarchiclbasechicl
# citruacidflavorvegetglycerinriceflour
# whitegrainsorghumextract
# mixtocopherolwhitechiaseed
# sodiumascrat
# herbalspice
# applextractacid
# mangootherflavor
# tomoatopast
# calciumchloridbeef
# extractgraepfruit
# keylime
# acaciasoylecithin
# ultrabrighttoughgrademilitaritacticflashlightordinariflashlightmightputoutlumen
# strobehighgradaluminumshockresistwaterresisthunterellidifferluxmakethiatombeam
# poweratombeamputoutupluxthattimeatombeamlightupbrighterfartherflashlightbyanentirfootbalfieldthinkcarheadlightarebrightcomparhighpow
# superbrightatombeamlightupnighttakeyourhometoday
# wholegrainnongmowhitepopcorn
# wholegrainwhitepopcornglutennongmo
# californiacherri
# ironbeannavibean
# jalapnopepper
# citricacidlacticacid
# groundcorn
# expellerpresscanolaoilsunflowoil
# sourcreammilksolid
# almondapproximpiecpound
# aqueousmoke
# gradehoney
# loquatleaf
# fritillari
# blueberrifill
# halal
# lactosintolerstudichildrenatriskmalnutritchildrenageatrisk
# whengivendaydietaricounselgramtotalvitaminselenium
# shakeareglutenfre
# delicivanillastrawberri
# pediasurgrowgainfiberkidshakevanillareadytodrinkfloz
# malicacidascorbacid
# heptylbutyrateoth
# heptylbutyr
# carminsodiumcitrat
# rubiredgrapefruit
# salttomatovarietimessapiconocolorpreservverilevellycopen
# yellowcornmealcoconutoilsugarsaltbaksodafreshpreservbybhtmaymilkmaywheatnamequantityunitdailivaluetotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifiberltgsugarsgprot
# wheatnamequantityunitdailivaluetotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifiberltgsugarsgprot
# asiagochees
# purplyam
# blackrice
# minerproduccerealcontaingluten
# potatostar
# waterflavor
# polyunsatur
# monounsatur
# folatacid
# manganessproutbuckwheatgroatssproutflaxseedraisinsorgandate
# chileanmushroom
# wholegrainwheatflourenrichflourwheatflour
# folicacidsugar
# thiaminmononitrwheat
# natura
# cacaobeansx
# evaporcanesyrupx
# cocoabutterx
# peanutbuttercupcoatcanesyrup
# sustainpalmkerneloil
# canesugarorgansproutgarbanzosorgansproutwholegrainoatsorgantapiocastarchtocopherolsunrefinsaltvitamin
# godivatruffloz
# godivachocolcarameloz
# godivachocolalmondoz
# godivachocolminipretzeloz
# godivasignaturbiscuitoz
# ironkindvitamin
# wholeflaxseed
# roastsaltwholealmond
# rollwholegrainhardredwheat
# freezdragonfruit
# alpinmilkchocolcocoabiscuitchipanalpinmilkcreamfillvanillasugar
# raisagentpotassiumbicarbon
# flavorothernut
# mainmaplsyrupmainmaplsyrupmainblueberrisyrupcanesugar
# xanthangumraspberrisyrupcanesugar
# fairfradearabicacoffe
# dualextractwildcraftchagamushroom
# dualextractlionmanemushroom
# lemonalwayreferaccur
# organpear
# milkchocolsugarmilkcocoabutterchocolsoyalecithinbarleymaltvanillin
# seasong
# textur
# wheatstarchpotatocitricacid
# bluepiecesservvaluecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgprot
# bluepiecesservfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxa
# vegetshortenoneoil
# sodiummetabislfit
# flavorsodiumacidpyrophosph
# vegetshortenoneoilsoybean
# moongwhole
# oilspearmint
# peeluextract
# milkchocoldropsugar
# marshmallowpiecsugar
# glycerinfructos
# torulayeastmonodiglyceridsoybeanoil
# pyfidoxinhydrochlorid
# yellowcolorbrinewater
# dripcandisugarsyrup
# liquoricliquoricextract
# flavoranisoil
# fenneloilproductreenutmilk
# mangopiec
# titaniumdioxidcarnaubawax
# tahinasesamseed
# whitechicken
# titamiumdioxid
# defatsoy
# orangcrystal
# celeridill
# greenredbellpepper
# summersavori
# paprikatomato
# lemonpe
# porkskin
# jalepenopepper
# flavorsoylecithin
# seasaltcalciumchloridsaltseawater
# ascorbacidlowmoisturpartskimmozzarellacheespartskimmilk
# enzympizzasauctomatowater
# garlicuncurpepperoninonitratnitritexceptasnaturoccurseasaltceleripork
# lacticacidstartercultursupportqualiti
# groundtomatotomato
# sugarbrownsugarcornsyruppopcornalmondsbuttpecanssoyoilsaltpeanutoilsoylecithinsodiumbicarbon
# maplsyrupsalt
# maplmaplsyrup
# flavorbrownsugarmolass
# titaniumdioxis
# redgummiareproducplantwhichpeanut
# fumaracidfdcincludyellow
# redbluestatementproduc
# chocolcanesyrup
# packcontainbiodegradsurfactenzym
# vegetoilcocoanutpalmkernel
# totalsaturtrangpolyunsaturgmonounsaturgcholesterolmgsodiummgtotalcarbohydrdietarifibersugargproteingvitamincalciumironingredientscoconutflake
# pineapplsyrup
# freezedristra
# freezedristrawberripiec
# sugarvegetoilshortenonesheaoil
# lactosmilkprotein
# polyglycerolpolyricinolacid
# egcgmgmlstevialeafextractmgml
# otherdeionizwater
# luohanguoestablishdropvaluegreentealeafmg
# valuegreentealeafmg
# luohanguoestablishdrop
# luohanguoestablishdropvaluegreentealeafmgmlgreenteaextractpolyphenol
# egcg
# beetsugar
# nettlteabag
# naturdecaffeinblacktea
# onesunflow
# expelpresscanolacornoil
# wheatproteinwheatgluten
# yuccaextract
# uncariatomentosaextract
# porkrind
# jerki
# cheescrisp
# proteinbar
# nutbutter
# artifflavorvanilladrumstickwhey
# conecoatcoconutoil
# saltvanillafudgdrumstickdairisolid
# vanilladrumstickdairisolid
# caramelcentersweetencondensmilkmilk
# saltvanillacarameldrumstickdairisolid
# clovericenoodlwhiterice
# phobrothkelpstockfilterwater
# waterspicepacket
# starchgumarab
# mentholcaramel
# mediumchocoldipstrawberridrizzlchocolmediumpetitmilkchocoldipstrawberridrizzlmilkchocolmediumpetitwhitechocoldipstrawberridrizzlwhitechocol
# okra
# chopdate
# yogurtchipsugar
# kerneloil
# roastalmondpiec
# coconutpiec
# roastcoffepiec
# candiorangpeel
# cocoanibtreenutemulsifisunflowlecithin
# ozberricherritrailmix
# ozcheddarasiagocheescrisp
# ozmixnut
# ozsmokehousalmond
# ozpistachioshell
# ozjunglsnackmix
# ozroastsaltcashew
# ozricecrackermix
# ozbuttertoffepeanut
# ozhoneysesamstick
# rawsugarcane
# sennaleafextract
# bitterfennelfruit
# coriandfruit
# gingerrhizom
# orangpeeloilongumarab
# maltitolmaltitolsyrupcocoabutterchocolpolydextroscreampolyglucitolmilkcalciumcarbonpalmkerneloilcocoaprocessalkalimilkproteinmaltodextrinsodiumcaseinflavorsoylecithindaiributterglycerinpgpr
# emulsifisaltdisodiumphosphatpotassiumsorbatcarrageenan
# maltitolmaltitolsyrupcocoabutterchocolpolydextroscreampolyglycitolmilkcalciumcarbonpalmkerneloilcocoaprocessalkalimilkproteinmaltodextrinsodiumcaseinflavorflavorlecithindaiributterglycerinpgprsaltdisodiumphosphatpotassiumsorbat
# maintaincarrageenannegligsugar
# waterporkbrothflavor
# collagencase
# extractgarlicblack
# roastpeanutflour
# peaproteintapiocastarch
# wheyproteinsunflowlecithin
# maplnatur
# fruitpulp
# colorpdcred
# jolliranchersugar
# sulfurdioxidmaintain
# yellowbluesweetartsugar
# yellowlifesavsugar
# sesamseedwarnconsumthiexposchemicincludlead
# colorredlakepiecesservvaluecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgprot
# colorredlakepiecesservfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxa
# trivial
# vit
# saltvitaminmineralsvit
# nongmoglucos
# foliat
# bar
# valuecaloriescalorifattotfatgsaturfatgtranfatgcholestrolmgsodiummgpotassiummgtotcarbohydratesgdietarifibergsugarsgprot
# copperbarfatxatotfatgsaturfatgtranfatgxacholestrolmgxasodiummgpotassiummgtotcarbohydratesgdietarifibergsugarsgxaproteingxa
# farinafarinairon
# kombulaminariajaponica
# sarsaparillaroot
# licoricrootflavor
# extravirginolivoilkoroneikivarietioliv
# bluesodiumbenzoat
# caseinsodium
# guarantedelightpepperlovereverywher
# piney
# impartgreatestdueitfine
# penetraromacharacteristwoodi
# consistgranul
# blackpeppersharp
# alaskaredsalmonsaltskinbone
# alaskaredsalmonsalt
# americanhoney
# foodgradessentioil
# milkchocolcanesugarmilkchocolcocoabuttermilklecithin
# milkchocolcanesugarmilkchocolcocoabuttermilklecithinflavor
# virgincoconutoilturmer
# licoricflavorcaffein
# tulsileaf
# licoricflavorxacaffein
# eucalyptuleaf
# thymeleaf
# elecampanroot
# indiablackmustardseed
# palmkernaloil
# bifidu
# casei
# anticak
# pouchunclbenreadiricewholegrainbrown
# waterbasmatiricecanolasunflowoilsoylecithinniacinironthiaminfolat
# boscpear
# farmsteadgourmetcheddarchees
# vellaromanellochees
# farmsteadgourmetgoudachees
# cherrisyrahjam
# rusticbakeriolivoilselgriflatbreadcracker
# ozroastsaltpistachio
# ozchocolseasaltcaramelcorn
# ozchocolalmond
# anetttriplnutbourbonbrittl
# honeywalnutbaklava
# ozpecancluster
# rusticbakeripecancooki
# volpidrisalsicciasalam
# honeybalsamvinegar
# ozfruit
# stonewalkitchencaramelsauc
# robertrothschildartichokcheesdip
# chocolcoverpretzel
# mlsparklapplcider
# ozchocolcherri
# eastshoredippretzel
# seabearsmokesalmon
# bamboocutboard
# granolaglutenrolloat
# rollamaranth
# rollquinoa
# fairtradechocol
# culturmilkmilk
# turkishoregano
# ipad
# valuarebaseoncaloridietvaluhigherlowerdependoncalorineedsquarfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxa
# valuarebaseoncaloridietvaluhigherlowerdependoncalorineedsquarvaluecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumiron
# pollock
# filetmignonsteak
# reedpepper
# rhizopuoligosporucultur
# pomegranmolass
# rebaudiosidea
# greencoffebeanextract
# xacarbonwater
# peanutothertreenutlist
# peanutothertreenutlistbarservvaluecaloriescalorifattotfatgsaturgtranfatgcholestrolmgsodiummgtotcarbohydrategfibergsugarsgproteingvitaminavitaminccalciumiron
# peanutothertreenutlistbarservfatxatotfatgsaturgtranfatgxacholestrolmgsodiummgtotcarbohydrategfibergsugarsgxaproteingvitaminaxavitamincxacalciumxaironxa
# wheatenzym
# ancientgrainbarleymeal
# wheatwheatflour
# organi
# saleculturwheat
# cerealflourwheat
# chilepeppercarolinareaper
# bhutjolokia
# toamatopast
# sunflowoilsalt
# nondairicheddar
# flavorlacticacid
# jellibean
# extragroundchilli
# sugarchocolmaltitol
# vanillamaltballcentercornsyrup
# maltbarleymalt
# confectionglazemilk
# soywheatmanufacturpeanut
# wheatdairicautionexcessconsumptlaxeffect
# ...
# xanthungum
# lohanfruitextract
# redbeansugarwat
# sodiumbenzoatsulfurdioxid
# flavortrivial
# rawmanukahoneynewzealand
# wholegrainoatssugarcanolaoilyellowcornflourhoneysoyflourbrownsugarsyrupsaltsoylecithinbaksodanaturflavorcontainsoypeanutmayalmondmaypecan
# mctoilcoconut
# brownlentil
# tastibiteglutenmicrowavbrown
# acrcraftseedsunflowseed
# peanutoilsoybeanoil
# totalsaturtranmgsodiummgtotalcarbohydrfibersugargproteingvitamincalciumironmaplsyrupcertifibyusacanada
# steviaaleaf
# peachmango
# cornstarchinvertsugar
# twoinvertsugar
# leavensoda
# cocoaprocessalkalisoylecithin
# earlgreyteabag
# sorbitantrister
# freshliroastcolombiangroundcoffe
# sourcroastfourgenerfamilicare
# selectarabicacoffe
# selectarabicacoffesmoothbright
# extrudrice
# vanillaextractorgan
# crackermbleachwheatflour
# enzymcheescheddarcheesmilkcultur
# waterlonggrainbrownricequinoaoleicsunflowoilseasaltgarlictapiocastarchonionsoylecithinparsleyblackpepper
# nondairicreamer
# sodiumsteroyllacryl
# sodiumcalciumalgin
# jackdanielwhiskeysilicondioxid
# sweetwhitericeflour
# chicorirootjerusalemartichok
# jalapenopepperjalapenopeppergreenjalapenopepper
# carobbeanguargum
# datedate
# elderberrithiproduconsharepeanuttreenut
# honeysoynutsoybean
# wholegrainbrownparboilrice
# wholegrainparboilbrownrice
# longgrainparboilbrownrice
# butterflavorcream
# tbhqpreserv
# sweetwoodextractbezogenaufdenlakritzanteil
# fruitplantconcentrappl
# chokeberri
# gellagaragar
# elderberriextract
# glazeagentbeeswaxwhiteyellow
# releastalcum
# fdccolorwhichincludyellow
# nondairicreamercornsyrupsolid
# shittakmushroom
# imag
# sodiumbisulfaspreserv
# potassiumsorbatsodiumbisulfitaspreserv
# duckmeat
# duckstock
# sodiumnitril
# vegenaisexpellerpresscanolaoil
# veganhoneyalternbrownricesyrup
# preparmustardvinegar
# dijonmustardapplcidervinegar
# partskimmozzarellacheesstarchpartskimmozzarellacheesmilk
# applewoodsmokebaconbaconcurewater
# smokehamwater
# vegetoilshortenpalmoil
# sugarglucossyrupgelatinacidificitricacidfruitvegetconcentrsafflow
# passionfruitaromaelderberriextractcoatbeeswaxwhiteyellow
# carnaubawaxcaramelsyrupinverttracemilk
# palmkerneloiltapiocadextrin
# skittlcandibag
# seasaltflavor
# yellowpopcorn
# palmcottonseoil
# redricewater
# guajillopepperwater
# guajillochilipepper
# seasonchickenchicken
# blackbarleywater
# poblanochilipepper
# yellowpiecesservvaluecaloriescalorifattotfatgsodiummgtotcarbohydrategsugarsgprot
# piecesservcaloritotalfatgsodiummgtotcarbohydrategsugarsgprote
# yellowpiecesservfatxaxatotfatgsodiummgtotcarbohydrategsugarsgxaproteingxa
# lemonsodiumbenzoat
# realemonlemon
# ozlemonwater
# ...
# sodiummetabisulfitsodiumsulfit
# caughtshellfishsaltwater
# turmercaramelcolor
# almondroastcocoabutter
# sodiummetabisulfitsulfurdioxid
# precooktapioca
# fairtradeassamblacktea
# bergamot
# vanillabit
# coconutpineapplflavor
# oolongtealeav
# bourbonglazebeefjerkigrassfedbeef
# bourbonbourbon
# chocolpiecchocolsugar
# candiorangpeelsugar
# ascorbacidsoy
# selectpepper
# thsodiumbenzoatcalciumchloridaspreserv
# thiaminmononitra
# soylecithintrivialsourc
# strawberriwater
# bingcherri
# titaniumdioxidpiecesservvaluecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgprot
# titaniumdioxidpiecesservfatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxa
# applring
# carrageenangumarab
# orangessenc
# cornstarchseasalt
# bananaslice
# strawberribananaslice
# sugarcornsyrupreducmilkmilk
# palmkernelpalmkerneloil
# raisinvanilla
# mannitolacacia
# ramnseed
# coffeflavortraceamountalmond
# himalayanpinksaltproducusetreenut
# onionextracttracewheat
# finestcoffe
# 9796 9796

# %%
for ing in unique_ingred:
    if 'peanut' in ing:
        print(ing)
# Out:
# flavoronpeanut
# flavorpeanut
# peanutmilkiwayminimilkchocolsugar
# peanut
# peanutbutterdriroastpeanut
# rosemariextractonsharelinesoylecithindediccontainnopeanut
# sulphitlupincaresourctestpeanut
# honeyroastpeanutpeanut
# vegetoilpeanut
# peanutbutterchipsugar
# defatpeanutflour
# peanutbutterpeanut
# peanutbuttercandisugar
# defatpeanut
# peanutbuttercoatpretzelballpeanutbuttercoatsugar
# minipeanutbuttercupmilkchocolsugar
# soybeansunflowseedpeanut
# peanutbutter
# peanuttreenut
# blueproducpeanut
# sunflowoilprocessonpackagpeanut
# rawspanishpeanut
# peanutflour
# emulsififlavourtracepeanut
# redmanufacturpeanuttreenut
# roastpeanut
# bluepreservbytbhqcitricacidpeanutsoymanufacturonmanufacturcontainmilk
# milksoymanufacturonsharepeanut
# peanutothertreenut
# wheatpeanut
# milksoytracepeanut
# peanutbuttercoatsugar
# peanutoil
# peanutextract
# peanutsoybeanareuse
# treenutpeanut
# peanutsoy
# produconpeanut
# soywheatpeanutmmmilkchocolcandimilkchocolsugar
# gumacaciamilksoypeanut
# reespeanutbuttercut
# wheatpeanutmmmilksoypeanutmusketmilk
# bluesnickerpeanut
# soypeanut
# colorfdcredmanufacturpeanut
# milkhandlpeanuttreenut
# driroastpeanutpeanut
# peanutbuttercupchocolcandimaltitol
# sodiumbenzoatpeanutbuttercrunchmaltitolsyrup
# peanutbuttercrunchmaltitolsyrup
# saltpeanutdelightchocolcandimaltitol
# palmoilproduconpeanut
# gumacaciamilksoypeanutskittlbitecandisugar
# tbhqcitricacidonothernutpeanuttreenut
# peanutwheat
# bluemanufacturpeanuttreenut
# peanutbutterroastpeanut
# hazelnutpeanut
# macadamianutoilmacadamiaproduconusepeanut
# milkpeanutoil
# caramelcolormanufacturpeanuttreenut
# virginiapeanut
# peanutsoybeanoil
# milkthimanufacturonpeanut
# confectionglazesoymanufacturplantpeanut
# seasaltpeanut
# orangvanillaflavortracehazelnutpeanut
# blanchpeanut
# peanutmanufacturplantwheat
# flavourtracepeanutsoynofat
# manufacturpeanut
# allspicpeanutbutterpeanutbutterdriroastpeanut
# canesugarpeanut
# premiumpeanutbutter
# cornsoyproducpeanut
# benzoatsodaaspreservalertthinutpeanut
# honeypotassiumsorbatpeanut
# preservcalciumpropionsorbicacidadditsynthetbetacarotenglutentracepeanut
# carmincolorbeenproduconsharepeanut
# milksoysharecontainpeanut
# soywheatpeanut
# amikitchendoeuseanipeanut
# peanutvegetoil
# milkmanufacturpeanut
# peanutcoatsugar
# peanutthimanufacturafacil
# peanutoilsesamseed
# almondproduconpeanut
# flavormmpeanutchocolcandimilkchocolsugar
# bluestorecooldriplacestatementcinnamondiscdopeanut
# wheatprocesspeanut
# flavorwheatsoypackagcontainpeanut
# peanutdropsugar
# canolaoilmilksoymanufacturplantpeanut
# peanuttreenutsoypresentareaexcessconsumptlaxeffect
# milksoypeanut
# emulsifisoylecithinchemicbakesodiumbicarbonglutensoytracepeanut
# glazepeanut
# thiaminmononitrpeanut
# flavorsoymanufacturplantpeanut
# dairipackcontainpeanut
# manufacturproducpeanut
# coconutpeanuttrenut
# cinnamonallergenmilkproduconmakecontainpeanut
# seasaltmilksoytracepeanut
# wheatmilkmanufacturpeanutothertreenut
# coconutpackonsharepeanut
# flavourtracepeanut
# seasaltpeanutpackonsharetreenut
# peanutbutterdropsugar
# xanthangumpeanutpackonsharetreenut
# pecanonpeanut
# roughlichopcuproughlichoproastpeanutcashew
# peeldicetablespoonfinegroundalmondflourtablespoonlemonpeanutvegetoil
# mixfewtablespoonwaterquartchickenstockwaterbayleavfinechopthymecupsmoothpeanutbutterscotchbonnetpeppervietnamesthaifishsaucolivoil
# peanutcornsyrup
# onsharepeanut
# flavortracepeanutnut
# peanutsugarvegetoilpalm
# roastcottonsepeanutoil
# nutareprocesscontainpeanut
# redpackagcontainpeanut
# peanutpast
# almondpeanut
# vanillaproducpackagproducpackagcontainpeanuttreenuttreenut
# vanillinanflavormanufacturonpeanuttreenut
# soymilkbakepeanut
# rawrevsuperfoodpeanut
# vegetoilpeanutoil
# mixnutbuttertoffepeanut
# xanthangumpeanut
# smokeporkwheatsoybeanpeanut
# peanutcanolacottonseoil
# peanutcottonseoil
# milkpeanut
# flavorpeanutbutterwholegrainoat
# peanutsoybeen
# peanutbutteroatflour
# peanutbuttergroundpeanut
# milkproducpeanut
# honeyroastpeanut
# spinachpeanut
# seasaltrebianapeanutothertreenut
# ricebranpeanut
# peanutfre
# milkchocolpeanutssugardextrosesalttbhqnamequantityunitdailivaluetotfatgsatfatgtranfatgcholesterolltmgsodiummgtotcarbgdietarifibergsugarsgproteingvitaminavitaminccalciumiron
# somecandiincludpeanut
# buttertoffepeanutpeanut
# vegetoilonepeanut
# shellroastpeanutnosalt
# blackwalnutmanufacturoncontainpeanut
# peanutroastpeanutoilsalt
# peanutcoconut
# reespeanutbutterpeanut
# peanutflavor
# peanutbutterdefatpeanut
# caramelcolorproducpeanut
# soybakeriusepeanuttreenut
# spanishpeanut
# tapiocasyruppeanutsdarkchocolflavorcoatgranolapretzelcrispricericemaltodextrinseasaltsoylecithinsunflowoilnatur
# cinnamonmanufacturusepeanut
# walnutpeanutothertreenut
# peanutoilsoyoil
# walnutoilproduchandltreenutpeanutoil
# almondpackonsharepeanut
# peanutsoyoil
# peanutbutterswirlpeanutbutter
# peanutbuttercupcoatsugar
# peanutpastpeanut
# sugarsaltthipeanutprotein
# peanutmilkchocolsugarcocoabutterchocolmilkmilklactossoylecithinpgpr
# douseabovrecommendratiopackagsameaspeanut
# ...
# groundroastpeanut
# xanthangumpeanuttracetreenut
# roasthioleiccanolaoilpeanutoil
# peanutpeanut
# peanutsunflowoilraisingreekstyleyogurtdropsugar
# peanutsunflowoilalmond
# rawpeanut
# flavorinfoproducplantwhichpeanut
# cornstarchmilksoypeanut
# peanutbutterchocolroastpeanut
# flavorsaltcaramelnutroastpeanut
# bakesodapeanut
# almondchocolroastpeanut
# thickenmanufacturpeanutsesam
# peanutsunflowoil
# sugarpackagsameaspeanut
# milkproducmanufacturpeanut
# sugarfructoscornsyruppecanmilkcocoabuttervegetoilchocolmilkcocoadaiributterwheymonodiglyceridsafflowoilsoylecithinsaltflavorcarrageenandisodiumphosphatcaramelmacadamianutpeanutalmondhazelnut
# sugarhighfructoscornsyruppecansnonfatmilkcocoabutterpartivegetoilchocolatemilkfatcontaincocoadaiributterwheymonodiglyceridessafflowoilsoylecithinsaltartificiflavorcarrageenandisodiumphosphatecaramelcolormacadamianutspeanutsalmondshazelnut
# peanutstrenut
# yamvegetbrothcantomatoswisschardprecookricericeniacinironthiaminfolicacidonionpeanutbuttergarlicolivoilgingercurri
# roastpeanutsugar
# driroastpeanut
# coconuttracetreenutpeanut
# annattocolorpeanut
# milkchocolsugarcocoabutterchocolmilkmilklactoslecithinpgprpeanutsugardextrossalttbhqcitricacid
# cornsyruppeanutbuttergrounddriroastpeanut
# largvirginiapeanut
# peanutifareallergproteinavenin
# peanutoilpeanut
# blanchalmondstatementpeanutfrecoconut
# packagsameaspeanut
# sugarvegetoilpalmoilsheaoilsunflowoilsoybeanoilsafflowoilmilkpeanutwheatflourflourniacinferrousulfatthiaminmononitrriboflavinfolicacidlactosmilklecithinsaltmaltyeast
# sulfurdioxidpackagsameaspeanut
# confectionglazepeanutonsharetreenut
# wheatbakeriusepeanuttreenut
# confectionglazetracepeanuttreenutalmond
# rawrevultrasuperfoodpeanut
# sesamseedsunflowseedtreenutpeanut
# peanutchocolseasalt
# valuecaloriescalorifattotfatgsaturfatgtranfatgcholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgproteingvitaminavitaminccalciumironingredipeanut
# fatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingvitaminaxavitamincxacalciumxaironxaingredipeanut
# cashewinfopackagpeanut
# mixtocopherolrosemariextractpeanut
# peanutoilcornsyrup
# fatxatotfatgsaturfatgtranfatgxacholesterolmgsodiummgtotcarbohydrategdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxaingredipeanut
# canolapeanutcottonseoil
# flavormanufacturoncontainpeanut
# 
# 
# peanutbuttter
# rawgoldenberrimanufacturpeanut
# sodaproduchandlpeanutbutter
# roastpeanutsugarcontainmolassescontainfullivegetoilmonodiglyceridescontainsalt
# reessnackpeanutbuttercupmilkchocolsugarcocoabutterchocolmilkmilklactoslecithinpgprpeanutsugardextrossalttbhqcitricacid
# brillantbluefcftracenutpeanut
# groundpeanut
# vanillapeanut
# peanutstrenutpiecesservfatxatotfatgtranfatgxasaturfatgcholestrolmgsodiummgtotcarbohydratesgdietarifibergsugarsgxaproteingxavitaminaxavitamincxacalciumxaironxa
# hullsunflowseedpackagpeanuttretreenut
# alcoholsoycautionshellfragmentmanufacturonshareplantpeanut
# milklactoslecithinpgprpeanutsugardextroscocoabuttervegetoilpalmkerneloilpalmoilpalmkerneloilcornstarchtbhqcitricacidmaintain
# mechanpressnaturcanolaoilbottlproducpeanutoil
# pressnaturcanolaoilbottlproducpeanutoil
# 
# peanutflourpeanut
# almondpeanutothertreenut
# sugarchocolvegetoilpalmoilsheaoilsunflowoilpalmkerneloilsafflowoilpeanutcocoabuttermilkmilkriceflourproteinwheycocoaprocessalkalimilklecithinsaltmaltextractmonoglyceridflavor
# watertracepeanutsesamseed
# peanutbuttergrounddriroastpeanut
# cyanocobalamincrunchipeanutbutterbrownricesyrup
# crunchipeanutbutterbrownricesyrup
# seasaltpeanutflour
# 
# peanutbuttercupcoatcanesyrup
# sugarbrownsugarcornsyruppopcornalmondsbuttpecanssoyoilsaltpeanutoilsoylecithinsodiumbicarbon
# redgummiareproducplantwhichpeanut
# ozbuttertoffepeanut
# roastpeanutflour
# peanutothertreenutlist
# peanutothertreenutlistbarservvaluecaloriescalorifattotfatgsaturgtranfatgcholestrolmgsodiummgtotcarbohydrategfibergsugarsgproteingvitaminavitaminccalciumiron
# peanutothertreenutlistbarservfatxatotfatgsaturgtranfatgxacholestrolmgsodiummgtotcarbohydrategfibergsugarsgxaproteingvitaminaxavitamincxacalciumxaironxa
# soywheatmanufacturpeanut
# wholegrainoatssugarcanolaoilyellowcornflourhoneysoyflourbrownsugarsyrupsaltsoylecithinbaksodanaturflavorcontainsoypeanutmayalmondmaypecan
# peanutoilsoybeanoil
# elderberrithiproduconsharepeanuttreenut

# %%
def get_feature_matrix():
    feature_mat = np.zeros((len(unique_names),len(unique_ingred)),dtype=int)
    for idx, row in df.iterrows():
        ingr = row['ingredients_list']
        for ing_idx,each in enumerate(unique_ingred):
            feature_mat[idx,ing_idx] = 1 if each in ingr else 0
    return feature_mat

# def get_weighted_adj_mat(feature_mat, adj_mat):
#     if feature_mat.shape[0]
def get_feature_coocurrance():    
    feature_mat = dict()
    for each in range(len(unique_ingred)):
        feature_mat[each] = np.zeros((len(unique_ingred)),dtype=int)

    for idx, row in df.iterrows():
        ingr = row['ingredients_list']#ast.literal_eval(row['ingredients'])
        for ing_idx,each in enumerate(unique_ingred):
            if each in ingr:
                for ing_idx2,each2 in enumerate(unique_ingred):
                    if each2 in ingr:
                        #Minus the value along the diagonal. Prevents inteference with the coocurrance but also allows us to retrieve magnitude later
                        feature_mat[ing_idx][ing_idx2] += 1 if ing_idx!=ing_idx2 else -1
    return feature_mat

def get_cooccurance_tf_idf(palm_oil_cooccurance_vector):
    # Adapted from TF-IDF.
    # IDF = log(n/j) where n = total number of documents and j = number of documents containing a given term. This is kept the same, but squared
    # TF is the frquency of a term in a *given* document. This doesn't really apply here, but instead we..
    # || consider the frequency of a term (i.e. ingredient) in products that also contain palm oil (i.e. co-occurance)

    n = len(unique_names)

    #IMPORTANT We initialise the array to 1 rather than 0 at present, this is to avoid 0 divides in the math.log without having to iterate over idf to check and then skip the log step due to time complexity
    idf = np.ones(len(unique_ingred))
    for idx,row in df.iterrows():
        ingr_list = row['ingredients_list']#ast.literal_eval(row['ingredients'])
        for i,ingredient in enumerate(unique_ingred):
            idf[i] += 1 if ingredient in ingr_list else 0
        
        
        idf = np.array([math.log(n/j) for j in idf])
    #assert len(palm_oil_cooccurance_vector) == len(idf)

    tf_idf_vector = palm_oil_cooccurance_vector * np.square(idf)
    return tf_idf_vector

def get_information_entropy(cooccurance_matrix, palm_oil_idx, num_palm_oil, num_total_products):
    #Intuition: use information entropy to calculate how much information each other ingredient can give us on the presence of palm oil
    # - (P(palm_oil_presence|x) log(P(palm_oil_presence|x))) + (P(¬palm_oil_presence|x) log(P(¬palm_oil_presence|x)))
    def calculate_entropy(palm_presence, n):
        if n != 0:
            p1 = palm_presence/n
        else:
            p1 = 0
        p2 = 1-p1
        sum1 = 0 if p1==0 else (p1*math.log2(p1))
        sum2 = 0 if p2==0 else (p2*math.log2(p2))
        return - sum1 + sum2
    
    def calcalate_conditional_entropy(palm_presence, n, p_n):
        if p_n < 0:
            print(p_n)
            exit()
        if n!= 0:
            p1 = (palm_presence/n)*p_n
        else:
            p1 = 0
        assert p1 >=0
        assert p_n >=0
        sum1 = 1 if (p1<=0 or p_n<=0) else (1 + (p1*math.log2(1+(p1/p_n))))
        if sum1 <= 0:
            print(p1, p_n, palm_presence, n)
        return sum1

    n = len(unique_ingred)
    entropies = np.empty(n) 
    for idx,each in enumerate(cooccurance_matrix[palm_oil_idx]):
        if idx == palm_oil_idx:
            entropies[idx] == 100
        else:
            n_occ = -cooccurance_matrix[idx][idx]
            assert n_occ >= each, (unique_ingred[idx])
            entropies[idx] = (calcalate_conditional_entropy(each, n_occ, n_occ/num_total_products) + 
                                calcalate_conditional_entropy(each, num_total_products-n_occ, (num_total_products-n_occ)/num_total_products) + 
                                calcalate_conditional_entropy(n_occ-each, n_occ, n_occ/num_total_products) + 
                                calcalate_conditional_entropy(n_occ-each, num_total_products-n_occ, (num_total_products-n_occ)/num_total_products)
                                )
    return entropies        
    # for idx, row in df.iterrows():
    #     ingr_list = ast.literal_eval(row['ingredients'])
    #     for i, ingredient in enumerate(ingr_list):

# %%
def get_adj_matrix_from_features(feature_mat):
    adj_mat = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        for i in elements:
            for j in elements:
                adj_mat[i,j] += 1 if i!=j else 0 
    return adj_mat

def get_adj_matrix_from_extra_features(feature_mat):
    adj_mat = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    shared_features = np.zeros((len(unique_names), len(unique_names)), dtype=int)
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        for i in elements:
            for j in elements:
                adj_mat[i,j] += 1 if i!=j else 0
                shared_features[i,j] = idx
    return (adj_mat, shared_features)

def get_adj_list_from_features(graph,feature_mat):
    adj_list = dict()

    # for node in range(len(list(graph.vs))):
    #     node_idx = node
    #     adj_list[node_idx] = {}
    for idx, col in enumerate(feature_mat.T):
        elements = np.where(col==1)[0]
        if len(elements) > 0:
            for i in elements:
                assert len([_ for _ in elements]) > 0
                adj_list[i] = [_ for _ in elements]
                adj_list[i].remove(i)
    for each in adj_list.keys():
        adj_list[each] = list(set(adj_list[each]))
    return adj_list

# %%
import torch_geometric.transforms as transforms
from torch_geometric.loader import DataLoader
from torch_geometric.data import InMemoryDataset

def show_frequency():
  cooccurance_matrix = get_feature_coocurrance()
  freqs = []
  total_products = len(df.index)
  for idx in range(len(cooccurance_matrix[0])):
    freqs.append((-cooccurance_matrix[idx][idx])/total_products)
  plt.bar(range(len(freqs)), sorted(freqs))
  plt.show()

def piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies, threshold_perc = 0.01):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00

  def calculate_threshold():
      freqs = []
      total_products = len(df.index)
      for idx in range(len(cooccurance_matrix[0])):
        freqs.append((-cooccurance_matrix[idx][idx])/total_products)
        
      perc_idx = int(len(freqs)*threshold_perc)
      top_n_threshold = sorted(freqs, reverse=True)[perc_idx]
      zero_thresh = sorted(freqs, reverse=True)[0]
      print(perc_idx, top_n_threshold, zero_thresh)
      return top_n_threshold

  thresh = calculate_threshold()
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          #n/f = 1/(f/n), f/n == frequency.
          fx = -cooccurance_matrix[idx][idx]
          frequency = (fx)/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency) if frequency <= thresh else np.log(total_products/(total_products-fx))
              if occurance < 0:
                  print(f'less than zero, occ: {np.log(1/(total_products-fx))} with fx as {fx}')
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies):
  frequency_weighted_conditional_entropies = []
  total_products = len(df.index)
  fs = []
  min_frequency = 0.00
  for idx in ordered_entropy:
      #Minus as you've made the diagonal minus for other reasons      
      if cooccurance_matrix[idx][idx]!=0:
          frequency = (-cooccurance_matrix[idx][idx])/total_products
          fs.append(frequency)
          if frequency >= min_frequency:
              occurance = np.log(1/frequency)
              if occurance < 0:
                  print("yes")
              
              frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
          else:
              frequency_weighted_conditional_entropies.append(1.0)
  return frequency_weighted_conditional_entropies


def apply_entropy_mask(feature_matrix,top_n=2000, frequency_weighted=True):
  cooccurance_matrix = get_feature_coocurrance()
  #Print the highest co-occuring ingredients
  for idx,each in enumerate(unique_ingred):
      if (INGREDIENT_TO_CLASSIFY in each.lower()):
          palm_idx = idx
          palm_vector = cooccurance_matrix[idx]
          sorted_indicies = sorted(range(len(palm_vector)), key=lambda x: palm_vector[x], reverse=True)
          print("MOST CO-OCCURANCES: ",[(unique_ingred[x],palm_vector[x]) for x in sorted_indicies[:10]])
          break
  entropies = get_information_entropy(cooccurance_matrix, palm_idx, num_palm,len(df.index))
  ordered_entropy = sorted(range(len(entropies)), key=lambda x: entropies[x], reverse=False)
  
  if frequency_weighted:
    fwce = piecewise_frequency_weighted_conditional_entropies(cooccurance_matrix, ordered_entropy, entropies)
    fwce_ordered_entropy = sorted(range(len(entropies)), key=lambda x: fwce[x], reverse=False)
    unique_ingred_ = [unique_ingred[i_] for i_ in fwce_ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, fwce_ordered_entropy, unique_ingred_
  else:
    unique_ingred_ = [unique_ingred[i_] for i_ in ordered_entropy[:top_n]]
    feature_matrix = get_feature_matrix() 
    return feature_matrix, ordered_entropy, unique_ingred_

  # print([unique_ingred[idx] for idx in ordered_entropy[:5]])
  # print(entropies[ordered_entropy[0]], entropies[ordered_entropy[-1]])
  # mask = np.ones_like(feature_matrix)
  # mask[:,ordered_entropy[top_n:]] = 0
  # feature_matrix = feature_matrix * mask
  


def get_feature_vector_and_label(product, decision_ingredients):
  #Build feature vector of high entropy ingredients. 
  feature_vector = np.zeros(len(decision_ingredients))
  ingredients = product['ingredients_list']#ast.literal_eval(product['ingredients'])
  for dec_idx,decision_ingr in enumerate(decision_ingredients):
    #Check if ingredients is in feature list, and also make sure to mask the palm oil ingredient
    if unique_ingred[dec_idx] in ingredients and unique_ingred[dec_idx] != INGREDIENT_TO_CLASSIFY:      
      feature_vector[dec_idx] = 1
  #1 = palmy, 0 = non_palmy
  label = 1 if INGREDIENT_TO_CLASSIFY in ingredients else 0

  return (feature_vector, label)

def get_one_feature_vector(product, feature_key,unique_features, is_list=False):
  product_data = ast.literal_eval(product[feature_key]) if is_list else product[feature_key]
  feature_vector = np.zeros(len(unique_features))
  for feat_idx,feat in enumerate(unique_features):
    if (is_list and (feat in product_data)) or (feat==product_data):
      feature_vector[feat_idx] += 1
  return feature_vector

def get_balanced_dataset(df, test_perc, val_perc):
  df = df.drop('level_0', axis=1).reset_index()
  palmy_prods = []
  for idx,row in df.iterrows():
    for each in row['ingredients_list']:    
      if (INGREDIENT_TO_CLASSIFY in each):
        palmy_prods.append(row)

  palmy_df = pd.DataFrame(palmy_prods)
  #What % of the dataset is a positive class?
  proportion = len(palmy_df.index)/len(df.index)

  #Sample the same amount of non-palmy products
  df = df.drop(list(palmy_df.index))
  palmy_df = palmy_df.drop_duplicates(subset='index')


  palmy_test_sample_num = int(len(palmy_df)*test_perc)
  nonpalmy_test_sample_num = int(len(df.index)*test_perc)
  palmy_val_sample_num = int(len(palmy_df)*val_perc)
  nonpalmy_val_sample_num = int(len(df.index)*val_perc)

  sample_len = int(len(palmy_df.index)*(1-(test_perc+val_perc)))
  non_palmy_df = df.sample(sample_len+nonpalmy_test_sample_num+nonpalmy_val_sample_num)
  #assert len(palmy_df.index) == len(non_palmy_df.index)
  #Shuffle each df
  palmy_df = palmy_df.sample(frac=1).drop('level_0', axis=1).reset_index()
  non_palmy_df = non_palmy_df.sample(frac=1).drop('level_0', axis=1).reset_index()
  df=pd.concat([palmy_df, non_palmy_df]).drop('level_0', axis=1).reset_index()
  #print(len(palmy_df.index), len(df.index),proportion, nonpalmy_test_sample_num, palmy_test_sample_num, nonpalmy_val_sample_num,palmy_val_sample_num)


  train_mask,val_mask,test_mask = np.zeros(len(df.index)),np.zeros(len(df.index)),np.zeros(len(df.index))
  dflen, pdflen, npdflen = len(df.index),len(palmy_df.index),len(non_palmy_df.index)

  train_boundaries = (int((1-(test_perc+val_perc))*pdflen), (pdflen+npdflen-(nonpalmy_test_sample_num+nonpalmy_val_sample_num)))
  val_boundaries = (train_boundaries[0]+int(pdflen*val_perc), train_boundaries[1]+nonpalmy_val_sample_num)

  train_mask[:train_boundaries[0]] = 1
  train_mask[pdflen:train_boundaries[1]] = 1

  val_mask[train_boundaries[0]:val_boundaries[0]] = 1
  val_mask[train_boundaries[1]:val_boundaries[1]] = 1

  test_mask[val_boundaries[0]:pdflen]=1
  test_mask[val_boundaries[1]:]=1

  assert dflen == (pdflen+npdflen)
  assert dflen == sum([sum(x) for x in [test_mask, train_mask, val_mask]])

  print(sum(train_mask), sum(val_mask),sum(test_mask), len(df.index), pdflen, npdflen,palmy_test_sample_num,nonpalmy_test_sample_num)
  return (df, torch.tensor(train_mask, dtype=bool), torch.tensor(val_mask, dtype=bool), torch.tensor(test_mask, dtype=bool))

def drop_sparse(adjacency_matrix, feature_matrix):
  rows_to_drop = [idx for idx,row_ in enumerate(adjacency_matrix) if sum(row_)==0]
  assert feature_matrix.shape[0]==adjacency_matrix.shape[0]
  adjacency_matrix = np.delete(adjacency_matrix, rows_to_drop, axis=0)
  adjacency_matrix = np.delete(adjacency_matrix, rows_to_drop, axis=1)
  feature_matrix = np.delete(feature_matrix, rows_to_drop, axis=0)
  return adjacency_matrix,feature_matrix





if LOAD_BALANCED_DATA:
  df = pd.read_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv', converters={'ingredients_list': pd.eval})
  #load test/val/train mask
else:
  df,train_mask,val_mask,test_mask = get_balanced_dataset(df,0.1,0.1)
  df.to_csv(f'UNBALANCED_{INGREDIENT_TO_CLASSIFY}_balanced_data.csv')
  #picke test and val and train mask 


#df.to_csv('final_saved_balanced_dataset.csv')

feature_matrix = []
for idx, product in df.iterrows():
  feature_vector, label = get_feature_vector_and_label(product, unique_ingred)#get_feature_vector_and_label_with_brands(product, unique_ingred)
  feature_matrix.append(feature_vector)



unique_ingred = []
for x in df['ingredients_list']:
    for y in x:
        if y not in unique_ingred:
            unique_ingred.append(y)

show_frequency()

if MASK:  
  feature_matrix,ordered_entropy,unique_ingred=apply_entropy_mask(feature_matrix,int(len(unique_ingred)/2), frequency_weighted=USE_FREQUENCY)

#Get Matrix of Features -- Products x Features
feature_matrix = []
label_vector = []
edge_matrix = []
brand_vector = []
cat_matrix = []
for idx, product in df.iterrows():
  feature_vector, label = get_feature_vector_and_label(product, unique_ingred)#get_feature_vector_and_label_with_brands(product, unique_ingred)
  feature_matrix.append(feature_vector)
  label_vector.append(label)
  edge_matrix.append(get_one_feature_vector(product, 'brand',unique_brands))
  brand_vector.append(np.where(edge_matrix[idx] == 1)[0])
  cat_matrix.append(get_one_feature_vector(product,'categories',unique_cats, is_list=True))

#(adj_matrix,feature_matrix) = drop_sparse(get_adj_matrix_from_features(np.array(feature_matrix)), feature_matrix)



ingred_adj_matrix = get_adj_matrix_from_features(np.array(feature_matrix))
#adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))

if USE_FULL_FEATURES:
  #Concatenate ingredients with brands and categories
  feature_matrix = np.concatenate((feature_matrix, edge_matrix, cat_matrix), axis=1)
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))
elif USE_BRANDS_AND_INGR:
  feature_matrix = np.concatenate((feature_matrix, edge_matrix), axis=1)
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))
else:
  #Get adjacency from just brands
  adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(edge_matrix))
  #adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(cat_matrix))
  #adj_matrix, shared_features = get_adj_matrix_from_extra_features(np.array(feature_matrix))


# adj_matrix = get_adj_matrix_from_extra_features(np.array(feature_matrix), len(unique_ingred))
# for col in adj_matrix:
#   print(len(np.where(col==1)[0]))


# if MASK:
#   feature_matrix, ordered_entropies = apply_entropy_mask(feature_matrix, top_n=int(len(feature_matrix[:][0])/7.5))

edge_index = []
edge_attr = []
edge_weights_ = []
for idx,_ in enumerate(adj_matrix):
  for target,val in enumerate(adj_matrix[idx]):
    if val >0:
      edge_index.append([idx,target])
      edge_weights_.append(ingred_adj_matrix[idx, target])
      edge_attr.append(shared_features[idx, target])

#To Tensor
feature_matrix = torch.tensor(feature_matrix, dtype=torch.float)
label_vector = torch.tensor(label_vector)
edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
print(edge_index.shape)
edge_weights = torch.tensor([1 for _ in range(len(edge_weights_))], dtype=torch.float)#.t().contiguous()
edge_attr = torch.tensor(edge_attr, dtype=torch.float)#.t().contiguous()
edge_attr = torch.randn(edge_index.size(1))
transform = transforms.Compose([
    #transforms.RandomNodeSplit('train_rest', num_val=int(feature_matrix.shape[0]/10), num_test=int(feature_matrix.shape[0]/10)),
    transforms.TargetIndegree()
])
# print(feature_matrix.shape, label_vector.shape)
# print(len(np.where(label_vector==1)[0]),len(np.where(label_vector==0)[0]))

# class ProductDataset(InMemoryDataset):
#   def __init__(self, data, transform=None, pre_transform=None):
#     super().__init__(None, transform, pre_transform)
#     self.data = data
#     self.transform = transform
#     self.pre_transform = pre_transform 
  
#   def len(self):
#     return 1
  
#   def get(self,idx):
#     if self.pre_transform:
#       data = self.pre_transform(self.data)
#     if self.transform:
#       data = self.transform(self.data)
#     return data

# print(Data(x=feature_matrix, y=label_vector,edge_index=edge_index, edge_weight=edge_weights, edge_attr=edge_attr))
data = transform(Data(x=feature_matrix, edge_index=edge_index))
data.y=label_vector
data.edge_weight=edge_weights
data.edge_attr=edge_attr
data.train_mask=train_mask
data.val_mask=val_mask
data.test_mask=test_mask
#dataset = ProductDataset(data, transform=transform)
#dataloader = DataLoader(dataset, 
print(data)

# if MASK:
#   masked_data = deepcopy(data)
#   masked_data.x, ordered_entropies = apply_entropy_mask(masked_data.x, top_n=int(len(masked_data.x[:][0])/10))
# Out:
# torch.Size([2, 9482902])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16812/3174981815.py in <module>
#     305 data.edge_weight=edge_weights
#     306 data.edge_attr=edge_attr
# --> 307 data.train_mask=train_mask
#     308 data.val_mask=val_mask
#     309 data.test_mask=test_mask
#
# NameError: name 'train_mask' is not defined

# %%
from torch_geometric.utils import to_networkx
import networkx as nx


print(data.y[data.test_mask])
new_graph = to_networkx(data)
k=100

sampled_nodes = random.sample(new_graph.nodes,k)

sampled_graph = new_graph.subgraph(sampled_nodes)


#pos=nx.kamada_kawai_layout(sampled_graph)
cm = []
for node in sampled_graph:
    if data.y[node] ==1:
        cm.append('orange')
    else:
        cm.append('blue')

nx.draw(sampled_graph, node_color=cm)
# Out:
# tensor([1, 1, 1,  ..., 0, 0, 0])

# %%
if MASK and USE_FREQUENCY:
    cooccurance_matrix = get_feature_coocurrance()
    #Print the highest co-occuring ingredients
    for idx,each in enumerate(unique_ingred):
        if (INGREDIENT_TO_CLASSIFY in each.lower()):
            palm_idx = idx
            palm_vector = cooccurance_matrix[idx]
            sorted_indicies = sorted(range(len(palm_vector)), key=lambda x: palm_vector[x], reverse=True)
            print("MOST CO-OCCURANCES: ",[(unique_ingred[x],palm_vector[x]) for x in sorted_indicies[:10]])
            break
    entropies = get_information_entropy(cooccurance_matrix, palm_idx, num_palm,len(df.index))
    ordered_entropy = sorted(range(len(entropies)), key=lambda x: entropies[x], reverse=False)

    print(f"Lowest Entropy Ingredients: {np.array(unique_ingred)[ordered_entropy[:11]]}")
    print(f"Highest Entropy Ingredients: {np.array(unique_ingred)[ordered_entropy[-10:]]}")

    print(sorted(entropies)[:10])

# for idx,each in enumerate(entropies):
#     if each <=0:
#         print(unique_ingred[idx])

# %%
# sns.color_palette('Set2')
# sns.set_theme()
if MASK and USE_FREQUENCY:
    print(min(entropies), entropies[ordered_entropy[0]],entropies[ordered_entropy[-1]])

    '''
    Frequency-weighted conditional entropy = log(N/f) * H(Y|X)
    Where N is total number of products and f is the number of products that contain this ingredient

    '''
    frequency_weighted_conditional_entropies = []
    total_products = len(df.index)
    fs = []
    min_frequency = 0.00 #1%
    for idx in ordered_entropy:
        #Minus as you've made the diagonal minus for other reasons
        
        if cooccurance_matrix[idx][idx]!=0:
            frequency = (-cooccurance_matrix[idx][idx])/total_products
            fs.append(frequency)
            if frequency >= min_frequency:
                occurance = np.log(1/frequency)
                if occurance < 0:
                    print("yes")
                
                frequency_weighted_conditional_entropies.append(occurance*entropies[idx])
            else:
                frequency_weighted_conditional_entropies.append(1.0)
        else:
            print('Entropy', unique_ingred[idx])
    print(sorted(frequency_weighted_conditional_entropies)[:20])
    print(min(frequency_weighted_conditional_entropies),max(frequency_weighted_conditional_entropies))
    print(min(fs), max(fs), np.median(fs), np.mean(fs))


    fig,ax = plt.subplots()
    ax.set_title('IDF-Conditional Entropy of Ingredients For Palm Oil Prediction')
    ax.set_ylabel('IDF Conditional Entropy')
    ax.set_xlabel('Ingredients')
    ax.bar(np.arange(len(frequency_weighted_conditional_entropies)), sorted(frequency_weighted_conditional_entropies))
    plt.show()

# %%
if MASK and USE_FREQUENCY:
    fig,ax = plt.subplots(1,2)
    ax[0].bar(np.arange(len(entropies)),sorted(entropies))
    #ax[0].set_xticklabels(np.array(unique_ingred)[ordered_entropy], rotation=45, ha='right')
    ax[0].set_xticks(np.arange(len(entropies)))

    ax[1].bar(np.arange(len(entropies[:20])),sorted(entropies[:20]))
    #ax[1].set_xticklabels(np.array(unique_ingred)[ordered_entropy[:20]], rotation=45, ha='right')
    ax[1].set_xticks(np.arange(len(entropies[:20])))
    ax[0].set_title('Conditional Entropy of Ingredients With Respect to Palm Oil')
    ax[1].set_title('Ingredients With Lowest Conditional Entropy With Respect to Palm Oil')

    plt.show()

# %%
from torch_geometric.nn import GCNConv, GATv2Conv, NNConv,SAGEConv
from torch_geometric.nn.models import AttentiveFP 
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.transforms import NormalizeFeatures
from sklearn.manifold import TSNE
def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(out.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
class MLP(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(MLP, self).__init__()
        #torch.manual_seed(12345)
        self.lin1 = Linear(len(data.x[0]), hidden_channels)
        self.lin2 = Linear(hidden_channels,2)

    def forward(self, x):
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x

model = MLP(hidden_channels=16)
print(model)

# criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.

# def train():
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss

# def test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(data.x)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[data.test_mask]
#       d = data.y[data.test_mask]      
#       for idx,each in enumerate(test_correct):
#           class_samples[d[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# def masked_test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(masked_data.x)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[masked_data.test_mask] == masked_data.y[masked_data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[masked_data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(masked_data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[masked_data.test_mask]
#       d = data.y[masked_data.test_mask]      
#       for idx,each in enumerate(test_correct):
#           class_samples[d[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# for epoch in range(1, 101):
#     loss = train()
#     print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# test_acc = test()
# print(f'Test Accuracy: {test_acc:.4f}')

# # if MASK:
# #     masked_test_acc = masked_test()
# #     print(f'Masked Test Accuracy: {masked_test_acc:.4f}')
# Out:
# MLP(
#   (lin1): Linear(in_features=12979, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=2, bias=True)
# )

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = GCNConv(len(data.x[0]), hidden_channels)
        self.conv2 = GCNConv(hidden_channels, 2)

    def forward(self, x, edge_index, edge_weight):
        x = self.conv1(x, edge_index, edge_weight=edge_weight)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index, edge_weight)
        return x

class GatV2ConvClass(torch.nn.Module):
    def __init__(self, hidden_channels, heads=4, edge_dim=1):
        super().__init__()
        self.edge_dim=edge_dim
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = GATv2Conv(len(data.x[0]), hidden_channels, heads=heads)
        self.conv2 = GATv2Conv(hidden_channels*heads, 2)

    def forward(self, x, edge_index, edge_attr=None, size=None):
        x = self.conv1(x, edge_index, edge_attr, size)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index,edge_attr, size)
        return x


class SAGEConvClass(torch.nn.Module):
    def __init__(self, hidden_channels,dropout=0.5,edge_dim=1):
        super().__init__()
        self.edge_dim=edge_dim
        #torch.manual_seed(12345)
        #print(len(set(data.y)))
        self.conv1 = SAGEConv(len(data.x[0]), hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, 2)
        self.dropout_prob = dropout
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=self.dropout_prob, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# %%
# model = Net()
# model.eval()
# out = model(data.x, data.edge_index, data.edge_attr)
# visualize(out, color=data.y)
# print(model)

# %%
model = GCN(hidden_channels=16)
model.eval()

print(data.edge_weight.size(), data.edge_index.size())
out = model(data.x, data.edge_index, data.edge_weight)
visualize(out, color=data.y)
print(model)
model = GCN(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# torch.Size([81062]) torch.Size([2, 81062])
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# GCN(
#   (conv1): GCNConv(12979, 16)
#   (conv2): GCNConv(16, 2)
# )

# %%
# def train():
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x, data.edge_index, data.edge_weight)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss


# def validate():
#       model.eval()
#       out = model(data.x, data.edge_index, data.edge_weight)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
#       test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
#       return test_acc


# # def test():
# #       class_correct = [0,0]
# #       class_samples = [0,0]
# #       model.eval()
# #       out = model(data.x, data.edge_index)
# #       pred = out.argmax(dim=1)  # Use the class with highest probability.
# #       test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
# #       #print(test_correct)
# #       test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
# #       p = pred[data.test_mask]
# #       assert len(p) == len(test_correct)
# #       d = data.y[data.test_mask]      
# #       for idx,each in enumerate(test_correct):
# #             try:
# #                   class_samples[p[idx]] += 1
# #             except Exception as e:
# #                   print("BROKE", p[idx])
# #                   sys.exit()
# #             if each == True:
# #                   class_correct[p[idx]] += 1

# #       print(class_correct, class_samples)
# #       print([0 if class_samples[idx] == 0 else class_correct[idx]/class_samples[idx] for idx in range(2)])
# #       return test_acc

# def test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(data.x, data.edge_index, data.edge_weight)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[data.test_mask]
#       d = data.y[data.test_mask]
      
#       for idx,each in enumerate(test_correct):          
#           class_samples[p[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# # chans = [16,48,64,128]
# # lrs = [0.005,0.01,0.02]
# # decays = [1e-4,5e-4,9e-4]
# # for chan in chans:
# #       for lr in lrs:
# #             for decay in decays:
# #                   model = GCN(hidden_channels=chan)
# #                   optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=decay)
# #                   criterion = torch.nn.CrossEntropyLoss()
# #                   for epoch in range(1, 101):
# #                         loss = train()
# #                         #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# #                         # if (epoch) % 25 == 0:
# #                         #       val_acc =validate()
# #                         #       print(f'Validate Accuracy: {val_acc:.4f}')

# #                   test_acc = test()
# #                   print(chan,lr,decay)
# #                   print(f'Test Accuracy: {test_acc:.4f}')

# model = GCN(hidden_channels=16)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# criterion = torch.nn.CrossEntropyLoss()
# for epoch in range(1, 201):
#       loss = train()
#       print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
#       if (epoch) % 25 == 0:
#             val_acc =validate()
#             print(f'Validate Accuracy: {val_acc:.4f}')
# test_acc = test()
# print(f'Test Accuracy: {test_acc:.4f}')

# model.eval()
# out = model(data.x, data.edge_index, data.edge_weight)
# visualize(out, color=data.y)

# %%
model = GatV2ConvClass(hidden_channels=16)
model.eval()
out = model(data.x, data.edge_index)#, data.edge_attr)#, len(data.edge_attr))
visualize(out, color=data.y)
print(model)
model = GatV2ConvClass(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# GatV2ConvClass(
#   (conv1): GATv2Conv(12979, 16, heads=4)
#   (conv2): GATv2Conv(64, 2, heads=1)
# )

# %%
# def train():
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x, data.edge_index)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss


# def validate():
#       model.eval()
#       out = model(data.x, data.edge_index)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
#       test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
#       return test_acc

# def test():
#       class_correct = [0,0]
#       class_samples = [0,0]
#       model.eval()
#       out = model(data.x, data.edge_index)
#       pred = out.argmax(dim=1)  # Use the class with highest probability.
#       test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#       assert len(test_correct)==len(pred[data.test_mask])
#       #print(test_correct)
#       test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#       p = pred[data.test_mask]
#       d = data.y[data.test_mask]
      
#       for idx,each in enumerate(test_correct):          
#           class_samples[d[idx]] += 1
#           if each == True:
#               class_correct[p[idx]] += 1
#       print(class_correct, class_samples)
#       print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#       return test_acc

# # model = GatV2ConvClass(hidden_channels=16)
# # optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# # criterion = torch.nn.CrossEntropyLoss()
# # for epoch in range(1, 101):
# #       loss = train()
# #       print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# #       if (epoch) % 25 == 0:
# #             val_acc =validate()
# #             print(f'Validate Accuracy: {val_acc:.4f}')
# # test_acc = test()
# # print(f'Test Accuracy: {test_acc:.4f}')

# # model.eval()
# # out = model(data.x, data.edge_index)
# # visualize(out, color=data.y)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = SAGEConvClass(hidden_channels=16)
model.eval()
out = model(data.x, data.edge_index)#, data.edge_attr)#, len(data.edge_attr))
visualize(out, color=data.y)
print(model)
data = data.to(device)
model = SAGEConvClass(hidden_channels=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# SAGEConvClass(
#   (conv1): SAGEConv(12979, 16)
#   (conv2): SAGEConv(16, 2)
# )

# %%
def train():
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data.x, data.edge_index)  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss


def validate():
      model.eval()
      out = model(data.x, data.edge_index)
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
      test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.
      return test_acc

def test():
      class_correct = [0,0]
      class_samples = [0,0]
      model.eval()
      out = model(data.x, data.edge_index)
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
      assert len(test_correct)==len(pred[data.test_mask])
      #print(test_correct)
      test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
      p = pred[data.test_mask]
      d = data.y[data.test_mask]
      
      for idx,each in enumerate(test_correct):          
          class_samples[p[idx]] += 1
          if each == True:
              class_correct[p[idx]] += 1
      print(class_correct, class_samples)
      print([class_correct[idx]/class_samples[idx] for idx in range(2)])
      return test_acc

model = SAGEConvClass(hidden_channels=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()
for epoch in range(1, 51):
      loss = train()
      print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
      if (epoch) % 25 == 0:
            val_acc =validate()
            print(f'Validate Accuracy: {val_acc:.4f}')
test_acc = test()
print(f'Test Accuracy: {test_acc:.4f}')

model.eval()
out = model(data.x, data.edge_index)
visualize(out.detach().cpu(), color=data.y.detach().cpu())
# Out:
# Epoch: 001, Loss: 0.6961
# Epoch: 002, Loss: 0.6124
# Epoch: 003, Loss: 0.5637
# Epoch: 004, Loss: 0.5214
# Epoch: 005, Loss: 0.4838
# Epoch: 006, Loss: 0.4506
# Epoch: 007, Loss: 0.4171
# Epoch: 008, Loss: 0.3895
# Epoch: 009, Loss: 0.3630
# Epoch: 010, Loss: 0.3355
# Epoch: 011, Loss: 0.3145
# Epoch: 012, Loss: 0.2896
# Epoch: 013, Loss: 0.2703
# Epoch: 014, Loss: 0.2513
# Epoch: 015, Loss: 0.2358
# Epoch: 016, Loss: 0.2209
# Epoch: 017, Loss: 0.2097
# Epoch: 018, Loss: 0.1954
# Epoch: 019, Loss: 0.1860
# Epoch: 020, Loss: 0.1729
# Epoch: 021, Loss: 0.1666
# Epoch: 022, Loss: 0.1607
# Epoch: 023, Loss: 0.1533
# Epoch: 024, Loss: 0.1444
# Epoch: 025, Loss: 0.1410
# Validate Accuracy: 0.8763
# Epoch: 026, Loss: 0.1381
# Epoch: 027, Loss: 0.1325
# Epoch: 028, Loss: 0.1292
# Epoch: 029, Loss: 0.1206
# Epoch: 030, Loss: 0.1256
# Epoch: 031, Loss: 0.1179
# Epoch: 032, Loss: 0.1115
# Epoch: 033, Loss: 0.1116
# Epoch: 034, Loss: 0.1078
# Epoch: 035, Loss: 0.1074
# Epoch: 036, Loss: 0.1057
# Epoch: 037, Loss: 0.1054
# Epoch: 038, Loss: 0.1039
# Epoch: 039, Loss: 0.1013
# Epoch: 040, Loss: 0.0983
# Epoch: 041, Loss: 0.0990
# Epoch: 042, Loss: 0.0938
# Epoch: 043, Loss: 0.0949
# Epoch: 044, Loss: 0.0943
# Epoch: 045, Loss: 0.0908
# Epoch: 046, Loss: 0.0891
# Epoch: 047, Loss: 0.0887
# Epoch: 048, Loss: 0.0878
# Epoch: 049, Loss: 0.0881
# Epoch: 050, Loss: 0.0856
# Validate Accuracy: 0.8831
# [1031, 265] [1064, 399]
# [0.9689849624060151, 0.6641604010025063]
# Test Accuracy: 0.8859
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
data = data.to(device)
# WEIGHTS = torch.tensor([1-proportion, proportion])
# WEIGHTS = WEIGHTS.to(device)
def gridsearch(hidden_channels, lrs,weight_decays, save_path, dropouts):
    def train(optimizer, criterion):
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data.x, data.edge_index)  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      # loss = (loss*WEIGHTS).mean()
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss


    def validate():
        model.eval()
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)  # Use the class with highest probability.

        sm = torch.nn.Softmax(dim=1)
        probs__ = sm(out)
        greater_class_probs = probs__[:,1]

        test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
        test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.

        d_ = data.y[data.val_mask].cpu().numpy()
        p_ = pred[data.val_mask].cpu().numpy()

        #Precision, Recall and F1 Score
        precision = precision_score(d_, p_)
        recall = recall_score(d_, p_)
        f1 = f1_score(y_true = d_, y_pred=p_)

        return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
    
    
    def test():
        class_correct = [0,0]
        class_samples = [0,0]
        model.eval()
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
        assert len(test_correct)==len(pred[data.test_mask])
        #print(test_correct)
        sm = torch.nn.Softmax(dim=1)
        probs__ = sm(out)
        greater_class_probs = probs__[:,1]
        test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
        p = pred[data.test_mask]
        d = data.y[data.test_mask]
        
        d_ = d.cpu().numpy()
        p_ = p.cpu().numpy()
        greater_class_probs_ = greater_class_probs[data.test_mask].cpu().detach().numpy()

        precision = precision_score(d_, p_)
        recall = recall_score(d_, p_)
        f1 = f1_score(y_true = d_, y_pred=p_)
        return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

        for idx,each in enumerate(test_correct):          
            class_samples[d[idx]] += 1
            if each == True:
                class_correct[p[idx]] += 1
        # print(class_correct, class_samples)
        # print([class_correct[idx]/class_samples[idx] for idx in range(2)])
        return roc_auc_score(d.cpu().numpy(),greater_class_probs_),test_acc, precision, recall, f1

    num_features = len(data.x[0])
    stop_at = 0
    data_dict = {}
    end_str = INGREDIENT_TO_CLASSIFY
    data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
       'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
    gridsearch_ = {}
    for hidden_chans in hidden_channels:
        for lr in lrs:
          for wd in weight_decays:
            for do in dropouts:
              for i in range(25):
                model = SAGEConvClass(hidden_chans, dropout=do).to(device)
                optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
                criterion = torch.nn.CrossEntropyLoss()
                max_acc = 0.0
                max_auc = 0.0
                max_val = 0.0
                max_test_auc = 0.0
                max_test_acc = 0.0
                acc_li = []
                auc_li = []
                test_acc_li = []
                test_auc_li = []
                val_prec_li = []
                val_rec_li = []
                val_f1_li = []
                test_prec_li = []
                test_rec_li = []
                test_f1_li = []
                loss_li = []
                for epoch in range(1,401):
                  loss=train(optimizer,criterion)
                  loss_li.append(loss.cpu().detach().item())
                  if (epoch%10)==0 or epoch==1:
                    val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
                    val_auc = round(val_auc, 3)
                    val_acc = round(val_acc, 3)
                    acc_li.append(val_acc)
                    auc_li.append(val_auc)
                    val_prec_li.append(val_precision)
                    val_rec_li.append(val_recall)
                    val_f1_li.append(val_f1)

                    test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                    test_auc_li.append(round(test_auc,3))
                    test_acc_li.append(round(test_acc,3))
                    test_prec_li.append(test_precision)
                    test_rec_li.append(test_recall)
                    test_f1_li.append(test_f1)
                    if val_acc >= max_val :
                      stop_at = epoch
                      max_auc = val_auc 
                      max_val = val_acc 
                      max_test_auc = test_auc
                      max_test_acc = test_acc
                print(f'HC: {hidden_channels} | LR: {lr} | WD: {wd} | DrpOut: {do} | Run: {i} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')
                    #print(f'Epoch: {epoch} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')

                      # torch.save(model.state_dict(), save_path+f'mlp_state_dict')
                # if max_test_auc > 0.9:
                #   print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'dropout: {do}',f'Max Test Accuracy: {max_test_acc:.4f} Max Test AUC: {max_test_auc:.4f}')
                # string_ = f'Hids: {hidden_chans} lr: {lr} wd: {wd} dropout: {do}'
                # gridsearch_[string_] = {}
                # gridsearch_[string_]['ACC'] = max_test_acc
                # gridsearch_[string_]['AUC'] = max_test_auc
                # with open(f'{INGREDIENT_TO_CLASSIFY}_gridsearch', 'wb') as f:
                #   pickle.dump(gridsearch_, f)

                data_dict[end_str]['train_loss'][i] = loss_li
                data_dict[end_str]['Validation Accuracy'][i] = acc_li
                data_dict[end_str]['Validation AUC'][i] = auc_li
                data_dict[end_str]['Validation Precision'][i] = val_prec_li
                data_dict[end_str]['Validation Recall'][i] = val_rec_li
                data_dict[end_str]['Validation F1'][i] = val_f1_li
                data_dict[end_str]['Test Accuracy'][i]= test_acc_li
                data_dict[end_str]['Test AUC'][i] = test_auc_li
                data_dict[end_str]['Test Precision'][i] = test_prec_li
                data_dict[end_str]['Test Recall'][i] = test_rec_li
                data_dict[end_str]['Test F1'][i] = test_f1_li
          with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_graphsage_data_dict_{stop_at}', 'wb') as f:
            pickle.dump(data_dict, f)

            
# 'Hids: 128 lr: 0.01 wd: 0.005 dropout: 0.5'
hidden_chans = [128]#64 lr: 0.01 wd: 0.005
lrs = [0.01]
wds = [0.005]
dropouts = [0.5]
save_path = 'gridsearch/node/'
gridsearch(hidden_chans,lrs,wds, save_path,dropouts)
#model.eval()
#out = model(data.x, data.edge_index)
#visualize(out, color=data.y)
# Out:
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 0 | Accuracy: 0.901 | AUC: 0.95 | Precision: 0.7095890410958904 | Recall: 0.8691275167785235 | F1: 0.7812971342383107
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 1 | Accuracy: 0.9 | AUC: 0.949 | Precision: 0.7035040431266847 | Recall: 0.8758389261744967 | F1: 0.7802690582959642
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 2 | Accuracy: 0.905 | AUC: 0.947 | Precision: 0.7226890756302521 | Recall: 0.8657718120805369 | F1: 0.7877862595419848
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 3 | Accuracy: 0.903 | AUC: 0.95 | Precision: 0.7166666666666667 | Recall: 0.8657718120805369 | F1: 0.78419452887538
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 4 | Accuracy: 0.907 | AUC: 0.947 | Precision: 0.7314285714285714 | Recall: 0.8590604026845637 | F1: 0.7901234567901234
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 5 | Accuracy: 0.867 | AUC: 0.949 | Precision: 0.6181818181818182 | Recall: 0.912751677852349 | F1: 0.7371273712737126
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 6 | Accuracy: 0.887 | AUC: 0.948 | Precision: 0.665 | Recall: 0.8926174496644296 | F1: 0.7621776504297995
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 7 | Accuracy: 0.893 | AUC: 0.948 | Precision: 0.6858638743455497 | Recall: 0.8791946308724832 | F1: 0.7705882352941177
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 8 | Accuracy: 0.875 | AUC: 0.948 | Precision: 0.6378896882494005 | Recall: 0.8926174496644296 | F1: 0.744055944055944
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 9 | Accuracy: 0.864 | AUC: 0.947 | Precision: 0.6132723112128147 | Recall: 0.8993288590604027 | F1: 0.7292517006802721
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 10 | Accuracy: 0.895 | AUC: 0.949 | Precision: 0.6875 | Recall: 0.8859060402684564 | F1: 0.7741935483870969
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 11 | Accuracy: 0.901 | AUC: 0.947 | Precision: 0.7073170731707317 | Recall: 0.8758389261744967 | F1: 0.7826086956521738
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 12 | Accuracy: 0.9 | AUC: 0.947 | Precision: 0.7134831460674157 | Recall: 0.8523489932885906 | F1: 0.7767584097859327
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 13 | Accuracy: 0.892 | AUC: 0.948 | Precision: 0.6813471502590673 | Recall: 0.8825503355704698 | F1: 0.7690058479532164
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 14 | Accuracy: 0.892 | AUC: 0.948 | Precision: 0.6804123711340206 | Recall: 0.8859060402684564 | F1: 0.7696793002915453
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 15 | Accuracy: 0.891 | AUC: 0.947 | Precision: 0.6759493670886076 | Recall: 0.8959731543624161 | F1: 0.7705627705627706
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 16 | Accuracy: 0.891 | AUC: 0.949 | Precision: 0.6751269035532995 | Recall: 0.8926174496644296 | F1: 0.7687861271676301
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 17 | Accuracy: 0.901 | AUC: 0.949 | Precision: 0.7029177718832891 | Recall: 0.889261744966443 | F1: 0.7851851851851851
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 18 | Accuracy: 0.902 | AUC: 0.948 | Precision: 0.7170868347338936 | Recall: 0.8590604026845637 | F1: 0.7816793893129771
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 19 | Accuracy: 0.866 | AUC: 0.947 | Precision: 0.6153846153846154 | Recall: 0.912751677852349 | F1: 0.7351351351351351
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 20 | Accuracy: 0.866 | AUC: 0.948 | Precision: 0.6153846153846154 | Recall: 0.912751677852349 | F1: 0.7351351351351351
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 21 | Accuracy: 0.888 | AUC: 0.947 | Precision: 0.6691919191919192 | Recall: 0.889261744966443 | F1: 0.7636887608069165
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 22 | Accuracy: 0.9 | AUC: 0.948 | Precision: 0.7087912087912088 | Recall: 0.8657718120805369 | F1: 0.7794561933534744
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 23 | Accuracy: 0.88 | AUC: 0.948 | Precision: 0.6466346153846154 | Recall: 0.9026845637583892 | F1: 0.7535014005602241
# HC: [128] | LR: 0.01 | WD: 0.005 | DrpOut: 0.5 | Run: 24 | Accuracy: 0.896 | AUC: 0.948 | Precision: 0.6941489361702128 | Recall: 0.8758389261744967 | F1: 0.7744807121661721

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
data = data.to(device)
def gridsearch(hidden_channels, lrs,weight_decays, save_path):
    def train(optimizer, criterion):
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data.x)  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss


    def validate():
        model.eval()
        out = model(data.x)
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
        test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.]
        
        sm = torch.nn.Softmax(dim=1)
        probs__ = sm(out)
        greater_class_probs = probs__[:,1]

        d_ = data.y[data.val_mask].cpu().numpy()
        p_ = pred[data.val_mask].cpu().numpy()

        precision = precision_score(d_, p_)
        recall = recall_score(d_, p_)
        f1 = f1_score(d_, p_)

        return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
    
    def test():
        class_correct = [0,0]
        class_samples = [0,0]
        model.eval()
        out = model(data.x)
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
        assert len(test_correct)==len(pred[data.test_mask])
        #print(test_correct)
        test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
        p = pred[data.test_mask]
        d = data.y[data.test_mask]
        sm = torch.nn.Softmax(dim=1)
        probs__ = sm(out)
        greater_class_probs = probs__[:,1]
        
        for idx,each in enumerate(test_correct):          
            class_samples[d[idx]] += 1
            if each == True:
                class_correct[p[idx]] += 1
        # print(class_correct, class_samples)
        # print([class_correct[idx]/class_samples[idx] for idx in range(2)])

        d_ = data.y[data.test_mask].cpu().numpy()
        p_ = pred[data.test_mask].cpu().numpy()

        precision = precision_score(d_, p_)
        recall = recall_score(d_, p_)
        f1 = f1_score(d_, p_)

        return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

    num_features = len(data.x[0])
    data_dict = {}
    end_str = INGREDIENT_TO_CLASSIFY
    stop_at = 0
    data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
       'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
    for hidden_chans in hidden_channels:
        for lr in lrs:
          for wd in weight_decays:
            for i in range(25):
              model = MLP(hidden_chans).to(device)
              optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
              criterion = torch.nn.CrossEntropyLoss()
              max_acc = 0.0
              max_auc = 0.0
              max_val = 0.0
              acc_li = []
              auc_li = []
              test_acc_li = []
              test_auc_li = []
              val_prec_li = []
              val_rec_li = []
              val_f1_li = []
              test_prec_li = []
              test_rec_li = []
              test_f1_li = []
              loss_li = []
              for epoch in range(1,401):
                loss=train(optimizer,criterion)
                loss_li.append(loss.cpu().detach().item())
                if (epoch%10)==0 or epoch==1:
                  val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
                  val_auc = round(val_auc, 3)
                  val_acc = round(val_acc, 3)
                  acc_li.append(val_acc)
                  auc_li.append(val_auc)
                  val_prec_li.append(val_precision)
                  val_rec_li.append(val_recall)
                  val_f1_li.append(val_f1)

                  test_auc,test_acc, test_precision, test_recall, test_f1 = test()
                  test_auc_li.append(round(test_auc,3))
                  test_acc_li.append(round(test_acc,3))
                  test_prec_li.append(test_precision)
                  test_rec_li.append(test_recall)
                  test_f1_li.append(test_f1)

                  if val_auc >= max_auc :
                    stop_at = epoch
                    max_auc = val_auc 
                    max_val = val_acc 
                    # torch.save(model.state_dict(), save_path+f'mlp_state_dict')
                    print(f'Epoch: {epoch} | Accuracy: {val_acc} | AUC: {val_auc} | Precision: {val_precision} | Recall: {val_recall} | F1: {val_f1}')

              print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'Max Validate Accuracy: {max_val:.4f} Max Validate AUC: {max_auc:.4f}')
              
              
              data_dict[end_str]['train_loss'][i] = loss_li
              data_dict[end_str]['Validation Accuracy'][i] = acc_li
              data_dict[end_str]['Validation AUC'][i] = auc_li
              data_dict[end_str]['Validation Precision'][i] = val_prec_li
              data_dict[end_str]['Validation Recall'][i] = val_rec_li
              data_dict[end_str]['Validation F1'][i] = val_f1_li
              data_dict[end_str]['Test Accuracy'][i]= test_acc_li
              data_dict[end_str]['Test AUC'][i] = test_auc_li
              data_dict[end_str]['Test Precision'][i] = test_prec_li
              data_dict[end_str]['Test Recall'][i] = test_rec_li
              data_dict[end_str]['Test F1'][i] = test_f1_li
          with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_mlp_data_dict_stop_epoch_{stop_at}', 'wb') as f:
            pickle.dump(data_dict, f)
hidden_chans = [128]#64 lr: 0.01 wd: 0.005
lrs = [0.01]
wds = [0.005]
dropouts = [0.5]
save_path = 'gridsearch/node/'
gridsearch(hidden_chans,lrs,wds, save_path)
# Out:
# Epoch: 1 | Accuracy: 0.351 | AUC: 0.883 | Precision: 0.28955532574974147 | Recall: 0.99644128113879 | F1: 0.4487179487179487
# Epoch: 10 | Accuracy: 0.845 | AUC: 0.902 | Precision: 0.6756756756756757 | Recall: 0.800711743772242 | F1: 0.7328990228013029
# Epoch: 20 | Accuracy: 0.856 | AUC: 0.923 | Precision: 0.7038216560509554 | Recall: 0.7864768683274022 | F1: 0.7428571428571428
# Epoch: 30 | Accuracy: 0.858 | AUC: 0.926 | Precision: 0.7003058103975535 | Recall: 0.8149466192170819 | F1: 0.7532894736842106
# Epoch: 40 | Accuracy: 0.87 | AUC: 0.929 | Precision: 0.729903536977492 | Recall: 0.8078291814946619 | F1: 0.7668918918918919
# Epoch: 60 | Accuracy: 0.866 | AUC: 0.929 | Precision: 0.7324414715719063 | Recall: 0.7793594306049823 | F1: 0.7551724137931034
# Epoch: 70 | Accuracy: 0.872 | AUC: 0.93 | Precision: 0.7408637873754153 | Recall: 0.7935943060498221 | F1: 0.7663230240549829
# Epoch: 80 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 120 | Accuracy: 0.873 | AUC: 0.932 | Precision: 0.7417218543046358 | Recall: 0.797153024911032 | F1: 0.7684391080617496
# Epoch: 130 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.7317880794701986 | Recall: 0.7864768683274022 | F1: 0.758147512864494
# Epoch: 140 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 160 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7082066869300911 | Recall: 0.8291814946619217 | F1: 0.763934426229508
# Epoch: 190 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.717391304347826 | Recall: 0.8220640569395018 | F1: 0.7661691542288557
# Epoch: 260 | Accuracy: 0.86 | AUC: 0.933 | Precision: 0.7009063444108762 | Recall: 0.8256227758007118 | F1: 0.758169934640523
# Epoch: 290 | Accuracy: 0.866 | AUC: 0.933 | Precision: 0.7234726688102894 | Recall: 0.800711743772242 | F1: 0.7601351351351352
# Epoch: 400 | Accuracy: 0.857 | AUC: 0.933 | Precision: 0.6948640483383686 | Recall: 0.8185053380782918 | F1: 0.7516339869281047
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8570 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.274 | AUC: 0.882 | Precision: 0.26736441484300666 | Recall: 1.0 | F1: 0.4219219219219219
# Epoch: 10 | Accuracy: 0.843 | AUC: 0.9 | Precision: 0.6747720364741642 | Recall: 0.7900355871886121 | F1: 0.7278688524590164
# Epoch: 20 | Accuracy: 0.854 | AUC: 0.923 | Precision: 0.6920731707317073 | Recall: 0.8078291814946619 | F1: 0.7454844006568145
# Epoch: 30 | Accuracy: 0.858 | AUC: 0.926 | Precision: 0.6955223880597015 | Recall: 0.8291814946619217 | F1: 0.7564935064935066
# Epoch: 40 | Accuracy: 0.863 | AUC: 0.929 | Precision: 0.7048192771084337 | Recall: 0.8327402135231317 | F1: 0.7634584013050569
# Epoch: 60 | Accuracy: 0.863 | AUC: 0.929 | Precision: 0.7165605095541401 | Recall: 0.800711743772242 | F1: 0.7563025210084033
# Epoch: 70 | Accuracy: 0.856 | AUC: 0.929 | Precision: 0.6904761904761905 | Recall: 0.8256227758007118 | F1: 0.7520259319286872
# Epoch: 80 | Accuracy: 0.865 | AUC: 0.93 | Precision: 0.7211538461538461 | Recall: 0.800711743772242 | F1: 0.7588532883642496
# Epoch: 100 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7211538461538461 | Recall: 0.800711743772242 | F1: 0.7588532883642496
# Epoch: 150 | Accuracy: 0.871 | AUC: 0.932 | Precision: 0.7292993630573248 | Recall: 0.8149466192170819 | F1: 0.7697478991596638
# Epoch: 190 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Epoch: 220 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.7085889570552147 | Recall: 0.8220640569395018 | F1: 0.7611202635914334
# Epoch: 240 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.706060606060606 | Recall: 0.8291814946619217 | F1: 0.762684124386252
# Epoch: 250 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.706060606060606 | Recall: 0.8291814946619217 | F1: 0.762684124386252
# Epoch: 290 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7102803738317757 | Recall: 0.8113879003558719 | F1: 0.7574750830564783
# Epoch: 310 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7192429022082019 | Recall: 0.8113879003558719 | F1: 0.7625418060200669
# Epoch: 350 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7183544303797469 | Recall: 0.8078291814946619 | F1: 0.7604690117252931
# Epoch: 360 | Accuracy: 0.857 | AUC: 0.933 | Precision: 0.6936936936936937 | Recall: 0.8220640569395018 | F1: 0.752442996742671
# Epoch: 370 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.6920821114369502 | Recall: 0.8398576512455516 | F1: 0.7588424437299036
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8580 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.604 | AUC: 0.877 | Precision: 0.3988355167394469 | Recall: 0.9750889679715302 | F1: 0.5661157024793388
# Epoch: 10 | Accuracy: 0.835 | AUC: 0.901 | Precision: 0.6514285714285715 | Recall: 0.8113879003558719 | F1: 0.722662440570523
# Epoch: 20 | Accuracy: 0.858 | AUC: 0.924 | Precision: 0.7138157894736842 | Recall: 0.7722419928825622 | F1: 0.7418803418803418
# Epoch: 30 | Accuracy: 0.856 | AUC: 0.925 | Precision: 0.6951219512195121 | Recall: 0.8113879003558719 | F1: 0.748768472906404
# Epoch: 40 | Accuracy: 0.856 | AUC: 0.928 | Precision: 0.7012578616352201 | Recall: 0.7935943060498221 | F1: 0.7445742904841403
# Epoch: 50 | Accuracy: 0.865 | AUC: 0.928 | Precision: 0.7284768211920529 | Recall: 0.7829181494661922 | F1: 0.7547169811320755
# Epoch: 60 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7220447284345048 | Recall: 0.8042704626334519 | F1: 0.7609427609427608
# Epoch: 80 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7111801242236024 | Recall: 0.8149466192170819 | F1: 0.7595356550580432
# Epoch: 90 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 140 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7197452229299363 | Recall: 0.8042704626334519 | F1: 0.7596638655462183
# Epoch: 150 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.706060606060606 | Recall: 0.8291814946619217 | F1: 0.762684124386252
# Epoch: 160 | Accuracy: 0.871 | AUC: 0.932 | Precision: 0.7322580645161291 | Recall: 0.8078291814946619 | F1: 0.7681895093062605
# Epoch: 180 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7107692307692308 | Recall: 0.8220640569395018 | F1: 0.7623762376237624
# Epoch: 290 | Accuracy: 0.862 | AUC: 0.934 | Precision: 0.7184466019417476 | Recall: 0.7900355871886121 | F1: 0.7525423728813558
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8620 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.352 | AUC: 0.88 | Precision: 0.2902892561983471 | Recall: 1.0 | F1: 0.44995996797437954
# Epoch: 10 | Accuracy: 0.851 | AUC: 0.9 | Precision: 0.6915887850467289 | Recall: 0.7900355871886121 | F1: 0.7375415282392027
# Epoch: 20 | Accuracy: 0.85 | AUC: 0.923 | Precision: 0.6859756097560976 | Recall: 0.800711743772242 | F1: 0.7389162561576355
# Epoch: 30 | Accuracy: 0.856 | AUC: 0.926 | Precision: 0.6916167664670658 | Recall: 0.8220640569395018 | F1: 0.7512195121951218
# Epoch: 40 | Accuracy: 0.863 | AUC: 0.93 | Precision: 0.7098765432098766 | Recall: 0.8185053380782918 | F1: 0.7603305785123968
# Epoch: 70 | Accuracy: 0.861 | AUC: 0.93 | Precision: 0.6994047619047619 | Recall: 0.8362989323843416 | F1: 0.7617504051863857
# Epoch: 110 | Accuracy: 0.869 | AUC: 0.93 | Precision: 0.7305194805194806 | Recall: 0.800711743772242 | F1: 0.7640067911714772
# Epoch: 120 | Accuracy: 0.868 | AUC: 0.93 | Precision: 0.7238095238095238 | Recall: 0.8113879003558719 | F1: 0.7651006711409395
# Epoch: 150 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7263843648208469 | Recall: 0.7935943060498221 | F1: 0.7585034013605442
# Epoch: 170 | Accuracy: 0.865 | AUC: 0.93 | Precision: 0.7197452229299363 | Recall: 0.8042704626334519 | F1: 0.7596638655462183
# Epoch: 190 | Accuracy: 0.867 | AUC: 0.931 | Precision: 0.7317880794701986 | Recall: 0.7864768683274022 | F1: 0.758147512864494
# Epoch: 210 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7156549520766773 | Recall: 0.797153024911032 | F1: 0.7542087542087542
# Epoch: 220 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7120743034055728 | Recall: 0.8185053380782918 | F1: 0.7615894039735099
# Epoch: 260 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7142857142857143 | Recall: 0.8185053380782918 | F1: 0.7628524046434495
# Epoch: 320 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.7067901234567902 | Recall: 0.8149466192170819 | F1: 0.7570247933884298
# Epoch: 330 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.6994047619047619 | Recall: 0.8362989323843416 | F1: 0.7617504051863857
# Epoch: 340 | Accuracy: 0.866 | AUC: 0.933 | Precision: 0.7165109034267912 | Recall: 0.8185053380782918 | F1: 0.7641196013289037
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8660 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.501 | AUC: 0.879 | Precision: 0.34538653366583544 | Recall: 0.9857651245551602 | F1: 0.5115420129270545
# Epoch: 10 | Accuracy: 0.831 | AUC: 0.902 | Precision: 0.6440677966101694 | Recall: 0.8113879003558719 | F1: 0.7181102362204723
# Epoch: 20 | Accuracy: 0.853 | AUC: 0.924 | Precision: 0.7022653721682848 | Recall: 0.7722419928825622 | F1: 0.735593220338983
# Epoch: 30 | Accuracy: 0.854 | AUC: 0.926 | Precision: 0.6863905325443787 | Recall: 0.8256227758007118 | F1: 0.7495961227786753
# Epoch: 40 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7064220183486238 | Recall: 0.8220640569395018 | F1: 0.7598684210526316
# Epoch: 70 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7133956386292835 | Recall: 0.8149466192170819 | F1: 0.760797342192691
# Epoch: 100 | Accuracy: 0.868 | AUC: 0.932 | Precision: 0.7210031347962382 | Recall: 0.8185053380782918 | F1: 0.7666666666666667
# Epoch: 140 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7178683385579937 | Recall: 0.8149466192170819 | F1: 0.7633333333333334
# Epoch: 180 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7202572347266881 | Recall: 0.797153024911032 | F1: 0.7567567567567568
# Epoch: 230 | Accuracy: 0.858 | AUC: 0.934 | Precision: 0.6966966966966966 | Recall: 0.8256227758007118 | F1: 0.755700325732899
# Epoch: 290 | Accuracy: 0.861 | AUC: 0.934 | Precision: 0.6982248520710059 | Recall: 0.8398576512455516 | F1: 0.7625201938610663
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8610 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.569 | AUC: 0.877 | Precision: 0.3787878787878788 | Recall: 0.9786476868327402 | F1: 0.5461767626613704
# Epoch: 10 | Accuracy: 0.844 | AUC: 0.902 | Precision: 0.6726190476190477 | Recall: 0.8042704626334519 | F1: 0.7325769854132901
# Epoch: 20 | Accuracy: 0.856 | AUC: 0.924 | Precision: 0.7051282051282052 | Recall: 0.7829181494661922 | F1: 0.7419898819561551
# Epoch: 30 | Accuracy: 0.855 | AUC: 0.926 | Precision: 0.6884272997032641 | Recall: 0.8256227758007118 | F1: 0.7508090614886732
# Epoch: 40 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7293729372937293 | Recall: 0.7864768683274022 | F1: 0.7568493150684932
# Epoch: 60 | Accuracy: 0.868 | AUC: 0.931 | Precision: 0.7142857142857143 | Recall: 0.8362989323843416 | F1: 0.7704918032786885
# Epoch: 100 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7192429022082019 | Recall: 0.8113879003558719 | F1: 0.7625418060200669
# Epoch: 110 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7178683385579937 | Recall: 0.8149466192170819 | F1: 0.7633333333333334
# Epoch: 120 | Accuracy: 0.859 | AUC: 0.931 | Precision: 0.6976047904191617 | Recall: 0.8291814946619217 | F1: 0.7577235772357723
# Epoch: 130 | Accuracy: 0.868 | AUC: 0.932 | Precision: 0.718266253869969 | Recall: 0.8256227758007118 | F1: 0.7682119205298014
# Epoch: 150 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7234726688102894 | Recall: 0.800711743772242 | F1: 0.7601351351351352
# Epoch: 240 | Accuracy: 0.865 | AUC: 0.934 | Precision: 0.7129629629629629 | Recall: 0.8220640569395018 | F1: 0.7636363636363636
# Epoch: 280 | Accuracy: 0.864 | AUC: 0.934 | Precision: 0.7082066869300911 | Recall: 0.8291814946619217 | F1: 0.763934426229508
# Epoch: 340 | Accuracy: 0.874 | AUC: 0.934 | Precision: 0.7378640776699029 | Recall: 0.8113879003558719 | F1: 0.7728813559322034
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8740 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.387 | AUC: 0.88 | Precision: 0.30182599355531686 | Recall: 1.0 | F1: 0.4636963696369637
# Epoch: 10 | Accuracy: 0.84 | AUC: 0.902 | Precision: 0.6627565982404692 | Recall: 0.8042704626334519 | F1: 0.7266881028938906
# Epoch: 20 | Accuracy: 0.858 | AUC: 0.924 | Precision: 0.711038961038961 | Recall: 0.7793594306049823 | F1: 0.7436332767402376
# Epoch: 30 | Accuracy: 0.857 | AUC: 0.927 | Precision: 0.6936936936936937 | Recall: 0.8220640569395018 | F1: 0.752442996742671
# Epoch: 40 | Accuracy: 0.868 | AUC: 0.93 | Precision: 0.7373737373737373 | Recall: 0.7793594306049823 | F1: 0.7577854671280275
# Epoch: 80 | Accuracy: 0.862 | AUC: 0.93 | Precision: 0.7002967359050445 | Recall: 0.8398576512455516 | F1: 0.7637540453074434
# Epoch: 100 | Accuracy: 0.859 | AUC: 0.93 | Precision: 0.7156862745098039 | Recall: 0.7793594306049823 | F1: 0.746166950596252
# Epoch: 110 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7220447284345048 | Recall: 0.8042704626334519 | F1: 0.7609427609427608
# Epoch: 120 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 130 | Accuracy: 0.867 | AUC: 0.931 | Precision: 0.7243589743589743 | Recall: 0.8042704626334519 | F1: 0.7622259696458684
# Epoch: 140 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 150 | Accuracy: 0.87 | AUC: 0.932 | Precision: 0.729903536977492 | Recall: 0.8078291814946619 | F1: 0.7668918918918919
# Epoch: 170 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7009063444108762 | Recall: 0.8256227758007118 | F1: 0.758169934640523
# Epoch: 180 | Accuracy: 0.857 | AUC: 0.932 | Precision: 0.6925373134328359 | Recall: 0.8256227758007118 | F1: 0.7532467532467533
# Epoch: 190 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7067901234567902 | Recall: 0.8149466192170819 | F1: 0.7570247933884298
# Epoch: 240 | Accuracy: 0.857 | AUC: 0.932 | Precision: 0.6925373134328359 | Recall: 0.8256227758007118 | F1: 0.7532467532467533
# Epoch: 250 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7263843648208469 | Recall: 0.7935943060498221 | F1: 0.7585034013605442
# Epoch: 260 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7120743034055728 | Recall: 0.8185053380782918 | F1: 0.7615894039735099
# Epoch: 300 | Accuracy: 0.859 | AUC: 0.933 | Precision: 0.7 | Recall: 0.8220640569395018 | F1: 0.7561374795417348
# Epoch: 350 | Accuracy: 0.861 | AUC: 0.934 | Precision: 0.709375 | Recall: 0.8078291814946619 | F1: 0.7554076539101496
# Epoch: 380 | Accuracy: 0.861 | AUC: 0.934 | Precision: 0.703030303030303 | Recall: 0.8256227758007118 | F1: 0.7594108019639934
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8610 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.32 | AUC: 0.881 | Precision: 0.28043912175648705 | Recall: 1.0 | F1: 0.43803585346843343
# Epoch: 10 | Accuracy: 0.846 | AUC: 0.901 | Precision: 0.677710843373494 | Recall: 0.800711743772242 | F1: 0.7340946166394781
# Epoch: 20 | Accuracy: 0.857 | AUC: 0.923 | Precision: 0.707395498392283 | Recall: 0.7829181494661922 | F1: 0.7432432432432433
# Epoch: 30 | Accuracy: 0.861 | AUC: 0.927 | Precision: 0.7042682926829268 | Recall: 0.8220640569395018 | F1: 0.7586206896551724
# Epoch: 40 | Accuracy: 0.864 | AUC: 0.93 | Precision: 0.7133956386292835 | Recall: 0.8149466192170819 | F1: 0.760797342192691
# Epoch: 50 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7220447284345048 | Recall: 0.8042704626334519 | F1: 0.7609427609427608
# Epoch: 60 | Accuracy: 0.862 | AUC: 0.93 | Precision: 0.7014925373134329 | Recall: 0.8362989323843416 | F1: 0.7629870129870131
# Epoch: 70 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.7133757961783439 | Recall: 0.797153024911032 | F1: 0.7529411764705882
# Epoch: 100 | Accuracy: 0.873 | AUC: 0.931 | Precision: 0.7295597484276729 | Recall: 0.8256227758007118 | F1: 0.7746243739565944
# Epoch: 130 | Accuracy: 0.86 | AUC: 0.931 | Precision: 0.7046153846153846 | Recall: 0.8149466192170819 | F1: 0.7557755775577559
# Epoch: 140 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7165109034267912 | Recall: 0.8185053380782918 | F1: 0.7641196013289037
# Epoch: 150 | Accuracy: 0.87 | AUC: 0.931 | Precision: 0.7328990228013029 | Recall: 0.800711743772242 | F1: 0.7653061224489796
# Epoch: 160 | Accuracy: 0.872 | AUC: 0.931 | Precision: 0.7457627118644068 | Recall: 0.7829181494661922 | F1: 0.763888888888889
# Epoch: 170 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7046153846153846 | Recall: 0.8149466192170819 | F1: 0.7557755775577559
# Epoch: 200 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7058823529411765 | Recall: 0.8113879003558719 | F1: 0.7549668874172185
# Epoch: 220 | Accuracy: 0.87 | AUC: 0.932 | Precision: 0.735973597359736 | Recall: 0.7935943060498221 | F1: 0.7636986301369865
# Epoch: 230 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 240 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7102803738317757 | Recall: 0.8113879003558719 | F1: 0.7574750830564783
# Epoch: 250 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7111801242236024 | Recall: 0.8149466192170819 | F1: 0.7595356550580432
# Epoch: 280 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 310 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.709375 | Recall: 0.8078291814946619 | F1: 0.7554076539101496
# Epoch: 340 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7129337539432177 | Recall: 0.8042704626334519 | F1: 0.7558528428093646
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8620 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.5 | AUC: 0.88 | Precision: 0.3449564134495641 | Recall: 0.9857651245551602 | F1: 0.511070110701107
# Epoch: 10 | Accuracy: 0.831 | AUC: 0.901 | Precision: 0.6448863636363636 | Recall: 0.8078291814946619 | F1: 0.717219589257504
# Epoch: 20 | Accuracy: 0.858 | AUC: 0.924 | Precision: 0.711038961038961 | Recall: 0.7793594306049823 | F1: 0.7436332767402376
# Epoch: 30 | Accuracy: 0.857 | AUC: 0.926 | Precision: 0.6984615384615385 | Recall: 0.8078291814946619 | F1: 0.7491749174917491
# Epoch: 40 | Accuracy: 0.856 | AUC: 0.931 | Precision: 0.6893491124260355 | Recall: 0.8291814946619217 | F1: 0.752827140549273
# Epoch: 80 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7160883280757098 | Recall: 0.8078291814946619 | F1: 0.7591973244147157
# Epoch: 100 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.7067901234567902 | Recall: 0.8149466192170819 | F1: 0.7570247933884298
# Epoch: 120 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7183544303797469 | Recall: 0.8078291814946619 | F1: 0.7604690117252931
# Epoch: 150 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7192429022082019 | Recall: 0.8113879003558719 | F1: 0.7625418060200669
# Epoch: 160 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7192429022082019 | Recall: 0.8113879003558719 | F1: 0.7625418060200669
# Epoch: 170 | Accuracy: 0.868 | AUC: 0.931 | Precision: 0.7252396166134185 | Recall: 0.8078291814946619 | F1: 0.7643097643097643
# Epoch: 180 | Accuracy: 0.867 | AUC: 0.931 | Precision: 0.7287581699346405 | Recall: 0.7935943060498221 | F1: 0.7597955706984667
# Epoch: 190 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7111801242236024 | Recall: 0.8149466192170819 | F1: 0.7595356550580432
# Epoch: 200 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7116564417177914 | Recall: 0.8256227758007118 | F1: 0.7644151565074137
# Epoch: 210 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7065868263473054 | Recall: 0.8398576512455516 | F1: 0.767479674796748
# Epoch: 220 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7058823529411765 | Recall: 0.8113879003558719 | F1: 0.7549668874172185
# Epoch: 240 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7021276595744681 | Recall: 0.8220640569395018 | F1: 0.7573770491803278
# Epoch: 250 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.7134146341463414 | Recall: 0.8327402135231317 | F1: 0.7684729064039408
# Epoch: 260 | Accuracy: 0.873 | AUC: 0.932 | Precision: 0.737012987012987 | Recall: 0.8078291814946619 | F1: 0.7707979626485569
# Epoch: 270 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 310 | Accuracy: 0.857 | AUC: 0.932 | Precision: 0.6858789625360231 | Recall: 0.8469750889679716 | F1: 0.7579617834394904
# Epoch: 350 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7064220183486238 | Recall: 0.8220640569395018 | F1: 0.7598684210526316
# Epoch: 360 | Accuracy: 0.858 | AUC: 0.932 | Precision: 0.6923076923076923 | Recall: 0.8327402135231317 | F1: 0.7560581583198707
# Epoch: 370 | Accuracy: 0.864 | AUC: 0.932 | Precision: 0.7174603174603175 | Recall: 0.8042704626334519 | F1: 0.7583892617449665
# Epoch: 390 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7039274924471299 | Recall: 0.8291814946619217 | F1: 0.761437908496732
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8620 Max Validate AUC: 0.9320
# Epoch: 1 | Accuracy: 0.446 | AUC: 0.881 | Precision: 0.32209302325581396 | Recall: 0.9857651245551602 | F1: 0.48553900087642426
# Epoch: 10 | Accuracy: 0.839 | AUC: 0.903 | Precision: 0.6608187134502924 | Recall: 0.8042704626334519 | F1: 0.7255216693418941
# Epoch: 20 | Accuracy: 0.856 | AUC: 0.923 | Precision: 0.7038216560509554 | Recall: 0.7864768683274022 | F1: 0.7428571428571428
# Epoch: 30 | Accuracy: 0.857 | AUC: 0.926 | Precision: 0.6891495601173021 | Recall: 0.8362989323843416 | F1: 0.7556270096463023
# Epoch: 40 | Accuracy: 0.87 | AUC: 0.93 | Precision: 0.7391304347826086 | Recall: 0.7864768683274022 | F1: 0.7620689655172415
# Epoch: 80 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7213114754098361 | Recall: 0.7829181494661922 | F1: 0.7508532423208192
# Epoch: 130 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7222222222222222 | Recall: 0.7864768683274022 | F1: 0.7529812606473596
# Epoch: 150 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.7080745341614907 | Recall: 0.8113879003558719 | F1: 0.7562189054726369
# Epoch: 160 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.703030303030303 | Recall: 0.8256227758007118 | F1: 0.7594108019639934
# Epoch: 170 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7174603174603175 | Recall: 0.8042704626334519 | F1: 0.7583892617449665
# Epoch: 180 | Accuracy: 0.868 | AUC: 0.931 | Precision: 0.7238095238095238 | Recall: 0.8113879003558719 | F1: 0.7651006711409395
# Epoch: 190 | Accuracy: 0.869 | AUC: 0.932 | Precision: 0.7232704402515723 | Recall: 0.8185053380782918 | F1: 0.7679465776293823
# Epoch: 270 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 290 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.7317880794701986 | Recall: 0.7864768683274022 | F1: 0.758147512864494
# Epoch: 310 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7133757961783439 | Recall: 0.797153024911032 | F1: 0.7529411764705882
# Epoch: 330 | Accuracy: 0.857 | AUC: 0.933 | Precision: 0.6902654867256637 | Recall: 0.8327402135231317 | F1: 0.7548387096774194
# Epoch: 350 | Accuracy: 0.868 | AUC: 0.933 | Precision: 0.722397476340694 | Recall: 0.8149466192170819 | F1: 0.765886287625418
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8680 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.283 | AUC: 0.882 | Precision: 0.26993275696445723 | Recall: 1.0 | F1: 0.42511346444780634
# Epoch: 10 | Accuracy: 0.842 | AUC: 0.902 | Precision: 0.6759259259259259 | Recall: 0.7793594306049823 | F1: 0.7239669421487603
# Epoch: 20 | Accuracy: 0.852 | AUC: 0.923 | Precision: 0.6856287425149701 | Recall: 0.8149466192170819 | F1: 0.7447154471544717
# Epoch: 30 | Accuracy: 0.851 | AUC: 0.926 | Precision: 0.6772334293948127 | Recall: 0.8362989323843416 | F1: 0.7484076433121019
# Epoch: 40 | Accuracy: 0.858 | AUC: 0.93 | Precision: 0.6966966966966966 | Recall: 0.8256227758007118 | F1: 0.755700325732899
# Epoch: 80 | Accuracy: 0.864 | AUC: 0.93 | Precision: 0.7133956386292835 | Recall: 0.8149466192170819 | F1: 0.760797342192691
# Epoch: 90 | Accuracy: 0.861 | AUC: 0.93 | Precision: 0.709375 | Recall: 0.8078291814946619 | F1: 0.7554076539101496
# Epoch: 110 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7090909090909091 | Recall: 0.8327402135231317 | F1: 0.7659574468085105
# Epoch: 130 | Accuracy: 0.859 | AUC: 0.931 | Precision: 0.6964285714285714 | Recall: 0.8327402135231317 | F1: 0.7585089141004862
# Epoch: 150 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.717948717948718 | Recall: 0.797153024911032 | F1: 0.7554806070826308
# Epoch: 200 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 210 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7211538461538461 | Recall: 0.800711743772242 | F1: 0.7588532883642496
# Epoch: 220 | Accuracy: 0.872 | AUC: 0.933 | Precision: 0.7331189710610932 | Recall: 0.8113879003558719 | F1: 0.7702702702702704
# Epoch: 240 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.6943620178041543 | Recall: 0.8327402135231317 | F1: 0.7572815533980582
# Epoch: 270 | Accuracy: 0.869 | AUC: 0.933 | Precision: 0.7261146496815286 | Recall: 0.8113879003558719 | F1: 0.7663865546218488
# Epoch: 340 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7125 | Recall: 0.8113879003558719 | F1: 0.7587354409317805
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8630 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.459 | AUC: 0.88 | Precision: 0.32742316784869974 | Recall: 0.9857651245551602 | F1: 0.4915705412599822
# Epoch: 10 | Accuracy: 0.842 | AUC: 0.903 | Precision: 0.6676557863501483 | Recall: 0.800711743772242 | F1: 0.7281553398058253
# Epoch: 20 | Accuracy: 0.852 | AUC: 0.923 | Precision: 0.6962025316455697 | Recall: 0.7829181494661922 | F1: 0.7370184254606366
# Epoch: 30 | Accuracy: 0.86 | AUC: 0.927 | Precision: 0.7058823529411765 | Recall: 0.8113879003558719 | F1: 0.7549668874172185
# Epoch: 40 | Accuracy: 0.859 | AUC: 0.93 | Precision: 0.6929824561403509 | Recall: 0.8434163701067615 | F1: 0.7608346709470304
# Epoch: 60 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.7206349206349206 | Recall: 0.8078291814946619 | F1: 0.761744966442953
# Epoch: 80 | Accuracy: 0.854 | AUC: 0.93 | Precision: 0.6831395348837209 | Recall: 0.8362989323843416 | F1: 0.752
# Epoch: 90 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7102803738317757 | Recall: 0.8113879003558719 | F1: 0.7574750830564783
# Epoch: 140 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7151702786377709 | Recall: 0.8220640569395018 | F1: 0.7649006622516555
# Epoch: 180 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.703030303030303 | Recall: 0.8256227758007118 | F1: 0.7594108019639934
# Epoch: 210 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7018072289156626 | Recall: 0.8291814946619217 | F1: 0.7601957585644371
# Epoch: 240 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Epoch: 270 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.7272727272727273 | Recall: 0.797153024911032 | F1: 0.7606112054329373
# Epoch: 280 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.710691823899371 | Recall: 0.8042704626334519 | F1: 0.7545909849749582
# Epoch: 290 | Accuracy: 0.869 | AUC: 0.933 | Precision: 0.7320261437908496 | Recall: 0.797153024911032 | F1: 0.7632027257240204
# Epoch: 300 | Accuracy: 0.868 | AUC: 0.933 | Precision: 0.7326732673267327 | Recall: 0.7900355871886121 | F1: 0.7602739726027397
# Epoch: 340 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7098765432098766 | Recall: 0.8185053380782918 | F1: 0.7603305785123968
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8630 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.266 | AUC: 0.885 | Precision: 0.26534466477809254 | Recall: 1.0 | F1: 0.41940298507462687
# Epoch: 10 | Accuracy: 0.85 | AUC: 0.902 | Precision: 0.690625 | Recall: 0.7864768683274022 | F1: 0.7354409317803661
# Epoch: 20 | Accuracy: 0.85 | AUC: 0.923 | Precision: 0.6837349397590361 | Recall: 0.8078291814946619 | F1: 0.7406199021207176
# Epoch: 30 | Accuracy: 0.856 | AUC: 0.927 | Precision: 0.6975308641975309 | Recall: 0.8042704626334519 | F1: 0.7471074380165289
# Epoch: 40 | Accuracy: 0.859 | AUC: 0.93 | Precision: 0.6941176470588235 | Recall: 0.8398576512455516 | F1: 0.7600644122383252
# Epoch: 90 | Accuracy: 0.859 | AUC: 0.93 | Precision: 0.7 | Recall: 0.8220640569395018 | F1: 0.7561374795417348
# Epoch: 100 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7120743034055728 | Recall: 0.8185053380782918 | F1: 0.7615894039735099
# Epoch: 140 | Accuracy: 0.858 | AUC: 0.931 | Precision: 0.6946107784431138 | Recall: 0.8256227758007118 | F1: 0.7544715447154472
# Epoch: 150 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7099697885196374 | Recall: 0.8362989323843416 | F1: 0.7679738562091502
# Epoch: 170 | Accuracy: 0.87 | AUC: 0.932 | Precision: 0.7284345047923323 | Recall: 0.8113879003558719 | F1: 0.7676767676767676
# Epoch: 200 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Epoch: 220 | Accuracy: 0.869 | AUC: 0.932 | Precision: 0.721875 | Recall: 0.8220640569395018 | F1: 0.7687188019966722
# Epoch: 250 | Accuracy: 0.859 | AUC: 0.932 | Precision: 0.6964285714285714 | Recall: 0.8327402135231317 | F1: 0.7585089141004862
# Epoch: 300 | Accuracy: 0.857 | AUC: 0.932 | Precision: 0.6925373134328359 | Recall: 0.8256227758007118 | F1: 0.7532467532467533
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8570 Max Validate AUC: 0.9320
# Epoch: 1 | Accuracy: 0.271 | AUC: 0.883 | Precision: 0.2666034155597723 | Recall: 1.0 | F1: 0.4209737827715356
# Epoch: 10 | Accuracy: 0.846 | AUC: 0.902 | Precision: 0.6787878787878788 | Recall: 0.797153024911032 | F1: 0.7332242225859248
# Epoch: 20 | Accuracy: 0.851 | AUC: 0.923 | Precision: 0.6892307692307692 | Recall: 0.797153024911032 | F1: 0.7392739273927392
# Epoch: 30 | Accuracy: 0.86 | AUC: 0.927 | Precision: 0.7046153846153846 | Recall: 0.8149466192170819 | F1: 0.7557755775577559
# Epoch: 40 | Accuracy: 0.867 | AUC: 0.93 | Precision: 0.7258064516129032 | Recall: 0.800711743772242 | F1: 0.7614213197969543
# Epoch: 60 | Accuracy: 0.867 | AUC: 0.93 | Precision: 0.7380952380952381 | Recall: 0.7722419928825622 | F1: 0.7547826086956523
# Epoch: 80 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7234726688102894 | Recall: 0.800711743772242 | F1: 0.7601351351351352
# Epoch: 100 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.709480122324159 | Recall: 0.8256227758007118 | F1: 0.7631578947368421
# Epoch: 110 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7051671732522796 | Recall: 0.8256227758007118 | F1: 0.760655737704918
# Epoch: 120 | Accuracy: 0.858 | AUC: 0.931 | Precision: 0.7006172839506173 | Recall: 0.8078291814946619 | F1: 0.7504132231404959
# Epoch: 130 | Accuracy: 0.87 | AUC: 0.932 | Precision: 0.72 | Recall: 0.8327402135231317 | F1: 0.7722772277227722
# Epoch: 140 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.7018072289156626 | Recall: 0.8291814946619217 | F1: 0.7601957585644371
# Epoch: 280 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.6955223880597015 | Recall: 0.8291814946619217 | F1: 0.7564935064935066
# Epoch: 330 | Accuracy: 0.866 | AUC: 0.933 | Precision: 0.7293729372937293 | Recall: 0.7864768683274022 | F1: 0.7568493150684932
# Epoch: 350 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.6955223880597015 | Recall: 0.8291814946619217 | F1: 0.7564935064935066
# Epoch: 360 | Accuracy: 0.854 | AUC: 0.933 | Precision: 0.68 | Recall: 0.8469750889679716 | F1: 0.7543581616481776
# Epoch: 380 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.7161290322580646 | Recall: 0.7900355871886121 | F1: 0.751269035532995
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8610 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.334 | AUC: 0.882 | Precision: 0.2847011144883485 | Recall: 1.0 | F1: 0.4432176656151419
# Epoch: 10 | Accuracy: 0.842 | AUC: 0.903 | Precision: 0.6696428571428571 | Recall: 0.800711743772242 | F1: 0.7293354943273906
# Epoch: 20 | Accuracy: 0.847 | AUC: 0.923 | Precision: 0.683076923076923 | Recall: 0.7900355871886121 | F1: 0.7326732673267327
# Epoch: 30 | Accuracy: 0.858 | AUC: 0.927 | Precision: 0.6946107784431138 | Recall: 0.8256227758007118 | F1: 0.7544715447154472
# Epoch: 40 | Accuracy: 0.871 | AUC: 0.928 | Precision: 0.7482758620689656 | Recall: 0.7722419928825622 | F1: 0.7600700525394046
# Epoch: 50 | Accuracy: 0.864 | AUC: 0.928 | Precision: 0.7160883280757098 | Recall: 0.8078291814946619 | F1: 0.7591973244147157
# Epoch: 60 | Accuracy: 0.868 | AUC: 0.928 | Precision: 0.7296416938110749 | Recall: 0.797153024911032 | F1: 0.761904761904762
# Epoch: 70 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.706060606060606 | Recall: 0.8291814946619217 | F1: 0.762684124386252
# Epoch: 90 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7129629629629629 | Recall: 0.8220640569395018 | F1: 0.7636363636363636
# Epoch: 210 | Accuracy: 0.862 | AUC: 0.932 | Precision: 0.7089783281733746 | Recall: 0.8149466192170819 | F1: 0.7582781456953643
# Epoch: 220 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 230 | Accuracy: 0.87 | AUC: 0.932 | Precision: 0.7313915857605178 | Recall: 0.8042704626334519 | F1: 0.7661016949152543
# Epoch: 240 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7178683385579937 | Recall: 0.8149466192170819 | F1: 0.7633333333333334
# Epoch: 250 | Accuracy: 0.857 | AUC: 0.932 | Precision: 0.6913946587537092 | Recall: 0.8291814946619217 | F1: 0.7540453074433656
# Epoch: 270 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7129337539432177 | Recall: 0.8042704626334519 | F1: 0.7558528428093646
# Epoch: 300 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Epoch: 320 | Accuracy: 0.873 | AUC: 0.933 | Precision: 0.7433333333333333 | Recall: 0.7935943060498221 | F1: 0.7676419965576593
# Epoch: 330 | Accuracy: 0.868 | AUC: 0.933 | Precision: 0.7210031347962382 | Recall: 0.8185053380782918 | F1: 0.7666666666666667
# Epoch: 340 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.6920821114369502 | Recall: 0.8398576512455516 | F1: 0.7588424437299036
# Epoch: 350 | Accuracy: 0.86 | AUC: 0.935 | Precision: 0.7058823529411765 | Recall: 0.8113879003558719 | F1: 0.7549668874172185
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8600 Max Validate AUC: 0.9350
# Epoch: 1 | Accuracy: 0.276 | AUC: 0.882 | Precision: 0.2681297709923664 | Recall: 1.0 | F1: 0.42287434161023324
# Epoch: 10 | Accuracy: 0.843 | AUC: 0.903 | Precision: 0.6737160120845922 | Recall: 0.7935943060498221 | F1: 0.7287581699346406
# Epoch: 20 | Accuracy: 0.852 | AUC: 0.924 | Precision: 0.69375 | Recall: 0.7900355871886121 | F1: 0.7387687188019966
# Epoch: 30 | Accuracy: 0.857 | AUC: 0.926 | Precision: 0.6891495601173021 | Recall: 0.8362989323843416 | F1: 0.7556270096463023
# Epoch: 40 | Accuracy: 0.859 | AUC: 0.929 | Precision: 0.7037037037037037 | Recall: 0.8113879003558719 | F1: 0.7537190082644629
# Epoch: 60 | Accuracy: 0.869 | AUC: 0.929 | Precision: 0.721875 | Recall: 0.8220640569395018 | F1: 0.7687188019966722
# Epoch: 70 | Accuracy: 0.866 | AUC: 0.929 | Precision: 0.7234726688102894 | Recall: 0.800711743772242 | F1: 0.7601351351351352
# Epoch: 80 | Accuracy: 0.863 | AUC: 0.929 | Precision: 0.717948717948718 | Recall: 0.797153024911032 | F1: 0.7554806070826308
# Epoch: 90 | Accuracy: 0.859 | AUC: 0.93 | Precision: 0.7012195121951219 | Recall: 0.8185053380782918 | F1: 0.7553366174055829
# Epoch: 110 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7178683385579937 | Recall: 0.8149466192170819 | F1: 0.7633333333333334
# Epoch: 170 | Accuracy: 0.858 | AUC: 0.931 | Precision: 0.7003058103975535 | Recall: 0.8149466192170819 | F1: 0.7532894736842106
# Epoch: 180 | Accuracy: 0.869 | AUC: 0.932 | Precision: 0.7246835443037974 | Recall: 0.8149466192170819 | F1: 0.7671691792294807
# Epoch: 190 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7090909090909091 | Recall: 0.8327402135231317 | F1: 0.7659574468085105
# Epoch: 200 | Accuracy: 0.855 | AUC: 0.933 | Precision: 0.6862170087976539 | Recall: 0.8327402135231317 | F1: 0.7524115755627009
# Epoch: 340 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8630 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.647 | AUC: 0.875 | Precision: 0.4260731319554849 | Recall: 0.9537366548042705 | F1: 0.589010989010989
# Epoch: 10 | Accuracy: 0.833 | AUC: 0.902 | Precision: 0.6477272727272727 | Recall: 0.8113879003558719 | F1: 0.7203791469194313
# Epoch: 20 | Accuracy: 0.859 | AUC: 0.924 | Precision: 0.7185430463576159 | Recall: 0.7722419928825622 | F1: 0.74442538593482
# Epoch: 30 | Accuracy: 0.854 | AUC: 0.926 | Precision: 0.6920731707317073 | Recall: 0.8078291814946619 | F1: 0.7454844006568145
# Epoch: 40 | Accuracy: 0.862 | AUC: 0.929 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 50 | Accuracy: 0.863 | AUC: 0.929 | Precision: 0.7207792207792207 | Recall: 0.7900355871886121 | F1: 0.7538200339558574
# Epoch: 70 | Accuracy: 0.862 | AUC: 0.93 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 80 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.7243589743589743 | Recall: 0.8042704626334519 | F1: 0.7622259696458684
# Epoch: 130 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7080745341614907 | Recall: 0.8113879003558719 | F1: 0.7562189054726369
# Epoch: 140 | Accuracy: 0.856 | AUC: 0.932 | Precision: 0.6828571428571428 | Recall: 0.8505338078291815 | F1: 0.757527733755943
# Epoch: 160 | Accuracy: 0.858 | AUC: 0.932 | Precision: 0.696969696969697 | Recall: 0.8185053380782918 | F1: 0.7528641571194763
# Epoch: 200 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7133757961783439 | Recall: 0.797153024911032 | F1: 0.7529411764705882
# Epoch: 210 | Accuracy: 0.864 | AUC: 0.932 | Precision: 0.7231270358306189 | Recall: 0.7900355871886121 | F1: 0.7551020408163265
# Epoch: 230 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.7108433734939759 | Recall: 0.8398576512455516 | F1: 0.7699836867862968
# Epoch: 240 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7147335423197492 | Recall: 0.8113879003558719 | F1: 0.76
# Epoch: 270 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.709375 | Recall: 0.8078291814946619 | F1: 0.7554076539101496
# Epoch: 340 | Accuracy: 0.856 | AUC: 0.933 | Precision: 0.686046511627907 | Recall: 0.8398576512455516 | F1: 0.7552
# Epoch: 350 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7156549520766773 | Recall: 0.797153024911032 | F1: 0.7542087542087542
# Epoch: 360 | Accuracy: 0.868 | AUC: 0.933 | Precision: 0.7281553398058253 | Recall: 0.800711743772242 | F1: 0.7627118644067796
# Epoch: 380 | Accuracy: 0.867 | AUC: 0.934 | Precision: 0.717391304347826 | Recall: 0.8220640569395018 | F1: 0.7661691542288557
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8670 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.506 | AUC: 0.881 | Precision: 0.3475533249686324 | Recall: 0.9857651245551602 | F1: 0.5139146567717996
# Epoch: 10 | Accuracy: 0.836 | AUC: 0.903 | Precision: 0.6550724637681159 | Recall: 0.8042704626334519 | F1: 0.7220447284345047
# Epoch: 20 | Accuracy: 0.862 | AUC: 0.924 | Precision: 0.7303754266211604 | Recall: 0.7615658362989324 | F1: 0.7456445993031359
# Epoch: 30 | Accuracy: 0.858 | AUC: 0.926 | Precision: 0.707936507936508 | Recall: 0.7935943060498221 | F1: 0.7483221476510067
# Epoch: 40 | Accuracy: 0.869 | AUC: 0.929 | Precision: 0.7350993377483444 | Recall: 0.7900355871886121 | F1: 0.7615780445969125
# Epoch: 60 | Accuracy: 0.869 | AUC: 0.929 | Precision: 0.7414965986394558 | Recall: 0.7758007117437722 | F1: 0.7582608695652174
# Epoch: 70 | Accuracy: 0.864 | AUC: 0.929 | Precision: 0.7069486404833837 | Recall: 0.8327402135231317 | F1: 0.7647058823529412
# Epoch: 80 | Accuracy: 0.865 | AUC: 0.93 | Precision: 0.7197452229299363 | Recall: 0.8042704626334519 | F1: 0.7596638655462183
# Epoch: 90 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7090909090909091 | Recall: 0.8327402135231317 | F1: 0.7659574468085105
# Epoch: 100 | Accuracy: 0.867 | AUC: 0.931 | Precision: 0.7134146341463414 | Recall: 0.8327402135231317 | F1: 0.7684729064039408
# Epoch: 110 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7165605095541401 | Recall: 0.800711743772242 | F1: 0.7563025210084033
# Epoch: 120 | Accuracy: 0.858 | AUC: 0.931 | Precision: 0.6966966966966966 | Recall: 0.8256227758007118 | F1: 0.755700325732899
# Epoch: 130 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7197452229299363 | Recall: 0.8042704626334519 | F1: 0.7596638655462183
# Epoch: 140 | Accuracy: 0.867 | AUC: 0.931 | Precision: 0.7147239263803681 | Recall: 0.8291814946619217 | F1: 0.7677100494233937
# Epoch: 150 | Accuracy: 0.872 | AUC: 0.931 | Precision: 0.7361563517915309 | Recall: 0.8042704626334519 | F1: 0.7687074829931972
# Epoch: 160 | Accuracy: 0.868 | AUC: 0.932 | Precision: 0.7238095238095238 | Recall: 0.8113879003558719 | F1: 0.7651006711409395
# Epoch: 180 | Accuracy: 0.87 | AUC: 0.933 | Precision: 0.729903536977492 | Recall: 0.8078291814946619 | F1: 0.7668918918918919
# Epoch: 250 | Accuracy: 0.87 | AUC: 0.933 | Precision: 0.7423728813559322 | Recall: 0.7793594306049823 | F1: 0.7604166666666665
# Epoch: 310 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.7015384615384616 | Recall: 0.8113879003558719 | F1: 0.7524752475247526
# Epoch: 340 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.7080745341614907 | Recall: 0.8113879003558719 | F1: 0.7562189054726369
# Epoch: 350 | Accuracy: 0.855 | AUC: 0.933 | Precision: 0.6829971181556196 | Recall: 0.8434163701067615 | F1: 0.7547770700636942
# Epoch: 370 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.7272727272727273 | Recall: 0.797153024911032 | F1: 0.7606112054329373
# Epoch: 390 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7129337539432177 | Recall: 0.8042704626334519 | F1: 0.7558528428093646
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8620 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.391 | AUC: 0.88 | Precision: 0.30312837108953616 | Recall: 1.0 | F1: 0.46523178807947024
# Epoch: 10 | Accuracy: 0.84 | AUC: 0.902 | Precision: 0.6627565982404692 | Recall: 0.8042704626334519 | F1: 0.7266881028938906
# Epoch: 20 | Accuracy: 0.857 | AUC: 0.923 | Precision: 0.7128712871287128 | Recall: 0.7686832740213523 | F1: 0.7397260273972603
# Epoch: 30 | Accuracy: 0.854 | AUC: 0.927 | Precision: 0.688622754491018 | Recall: 0.8185053380782918 | F1: 0.7479674796747967
# Epoch: 40 | Accuracy: 0.858 | AUC: 0.93 | Precision: 0.7027863777089783 | Recall: 0.8078291814946619 | F1: 0.7516556291390728
# Epoch: 60 | Accuracy: 0.87 | AUC: 0.93 | Precision: 0.7391304347826086 | Recall: 0.7864768683274022 | F1: 0.7620689655172415
# Epoch: 70 | Accuracy: 0.87 | AUC: 0.93 | Precision: 0.726984126984127 | Recall: 0.8149466192170819 | F1: 0.7684563758389261
# Epoch: 80 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7064220183486238 | Recall: 0.8220640569395018 | F1: 0.7598684210526316
# Epoch: 90 | Accuracy: 0.862 | AUC: 0.931 | Precision: 0.7064220183486238 | Recall: 0.8220640569395018 | F1: 0.7598684210526316
# Epoch: 100 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.7067901234567902 | Recall: 0.8149466192170819 | F1: 0.7570247933884298
# Epoch: 120 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.7018072289156626 | Recall: 0.8291814946619217 | F1: 0.7601957585644371
# Epoch: 130 | Accuracy: 0.865 | AUC: 0.931 | Precision: 0.7225806451612903 | Recall: 0.797153024911032 | F1: 0.7580372250423011
# Epoch: 140 | Accuracy: 0.86 | AUC: 0.931 | Precision: 0.6985074626865672 | Recall: 0.8327402135231317 | F1: 0.7597402597402597
# Epoch: 150 | Accuracy: 0.872 | AUC: 0.932 | Precision: 0.7361563517915309 | Recall: 0.8042704626334519 | F1: 0.7687074829931972
# Epoch: 200 | Accuracy: 0.864 | AUC: 0.932 | Precision: 0.7160883280757098 | Recall: 0.8078291814946619 | F1: 0.7591973244147157
# Epoch: 220 | Accuracy: 0.869 | AUC: 0.932 | Precision: 0.7191358024691358 | Recall: 0.8291814946619217 | F1: 0.7702479338842975
# Epoch: 230 | Accuracy: 0.864 | AUC: 0.932 | Precision: 0.7160883280757098 | Recall: 0.8078291814946619 | F1: 0.7591973244147157
# Epoch: 250 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7225806451612903 | Recall: 0.797153024911032 | F1: 0.7580372250423011
# Epoch: 290 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7116564417177914 | Recall: 0.8256227758007118 | F1: 0.7644151565074137
# Epoch: 300 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.7098765432098766 | Recall: 0.8185053380782918 | F1: 0.7603305785123968
# Epoch: 310 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7102803738317757 | Recall: 0.8113879003558719 | F1: 0.7574750830564783
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8620 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.483 | AUC: 0.879 | Precision: 0.3377885783718105 | Recall: 0.9893238434163701 | F1: 0.5036231884057971
# Epoch: 10 | Accuracy: 0.845 | AUC: 0.898 | Precision: 0.68 | Recall: 0.7864768683274022 | F1: 0.7293729372937294
# Epoch: 20 | Accuracy: 0.851 | AUC: 0.922 | Precision: 0.6927899686520376 | Recall: 0.7864768683274022 | F1: 0.7366666666666667
# Epoch: 30 | Accuracy: 0.861 | AUC: 0.927 | Precision: 0.7080745341614907 | Recall: 0.8113879003558719 | F1: 0.7562189054726369
# Epoch: 40 | Accuracy: 0.86 | AUC: 0.93 | Precision: 0.7058823529411765 | Recall: 0.8113879003558719 | F1: 0.7549668874172185
# Epoch: 60 | Accuracy: 0.865 | AUC: 0.93 | Precision: 0.7269736842105263 | Recall: 0.7864768683274022 | F1: 0.7555555555555556
# Epoch: 80 | Accuracy: 0.87 | AUC: 0.931 | Precision: 0.7375415282392026 | Recall: 0.7900355871886121 | F1: 0.7628865979381442
# Epoch: 90 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7324414715719063 | Recall: 0.7793594306049823 | F1: 0.7551724137931034
# Epoch: 110 | Accuracy: 0.872 | AUC: 0.932 | Precision: 0.7424749163879598 | Recall: 0.7900355871886121 | F1: 0.7655172413793103
# Epoch: 140 | Accuracy: 0.86 | AUC: 0.932 | Precision: 0.7033639143730887 | Recall: 0.8185053380782918 | F1: 0.7565789473684211
# Epoch: 150 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7197452229299363 | Recall: 0.8042704626334519 | F1: 0.7596638655462183
# Epoch: 170 | Accuracy: 0.861 | AUC: 0.932 | Precision: 0.7067901234567902 | Recall: 0.8149466192170819 | F1: 0.7570247933884298
# Epoch: 180 | Accuracy: 0.858 | AUC: 0.932 | Precision: 0.6887608069164265 | Recall: 0.8505338078291815 | F1: 0.7611464968152866
# Epoch: 190 | Accuracy: 0.869 | AUC: 0.932 | Precision: 0.7335526315789473 | Recall: 0.7935943060498221 | F1: 0.7623931623931623
# Epoch: 200 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7192429022082019 | Recall: 0.8113879003558719 | F1: 0.7625418060200669
# Epoch: 210 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7129629629629629 | Recall: 0.8220640569395018 | F1: 0.7636363636363636
# Epoch: 260 | Accuracy: 0.861 | AUC: 0.933 | Precision: 0.7042682926829268 | Recall: 0.8220640569395018 | F1: 0.7586206896551724
# Epoch: 270 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7035928143712575 | Recall: 0.8362989323843416 | F1: 0.7642276422764229
# Epoch: 320 | Accuracy: 0.869 | AUC: 0.933 | Precision: 0.7204968944099379 | Recall: 0.8256227758007118 | F1: 0.769485903814262
# Epoch: 340 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7254901960784313 | Recall: 0.7900355871886121 | F1: 0.7563884156729132
# Epoch: 380 | Accuracy: 0.856 | AUC: 0.933 | Precision: 0.6893491124260355 | Recall: 0.8291814946619217 | F1: 0.752827140549273
# Epoch: 390 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7103658536585366 | Recall: 0.8291814946619217 | F1: 0.7651888341543513
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8650 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.608 | AUC: 0.878 | Precision: 0.40145985401459855 | Recall: 0.9786476868327402 | F1: 0.5693581780538303
# Epoch: 10 | Accuracy: 0.839 | AUC: 0.902 | Precision: 0.6598837209302325 | Recall: 0.8078291814946619 | F1: 0.7263999999999998
# Epoch: 20 | Accuracy: 0.858 | AUC: 0.923 | Precision: 0.7133550488599348 | Recall: 0.7793594306049823 | F1: 0.7448979591836736
# Epoch: 30 | Accuracy: 0.855 | AUC: 0.926 | Precision: 0.6978193146417445 | Recall: 0.797153024911032 | F1: 0.7441860465116279
# Epoch: 40 | Accuracy: 0.866 | AUC: 0.93 | Precision: 0.734006734006734 | Recall: 0.7758007117437722 | F1: 0.754325259515571
# Epoch: 60 | Accuracy: 0.86 | AUC: 0.93 | Precision: 0.6996996996996997 | Recall: 0.8291814946619217 | F1: 0.758957654723127
# Epoch: 70 | Accuracy: 0.855 | AUC: 0.931 | Precision: 0.6819484240687679 | Recall: 0.8469750889679716 | F1: 0.7555555555555555
# Epoch: 110 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7174603174603175 | Recall: 0.8042704626334519 | F1: 0.7583892617449665
# Epoch: 120 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.717948717948718 | Recall: 0.797153024911032 | F1: 0.7554806070826308
# Epoch: 140 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7147335423197492 | Recall: 0.8113879003558719 | F1: 0.76
# Epoch: 180 | Accuracy: 0.871 | AUC: 0.932 | Precision: 0.7384105960264901 | Recall: 0.7935943060498221 | F1: 0.7650085763293311
# Epoch: 210 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7269736842105263 | Recall: 0.7864768683274022 | F1: 0.7555555555555556
# Epoch: 220 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7206349206349206 | Recall: 0.8078291814946619 | F1: 0.761744966442953
# Epoch: 230 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7147335423197492 | Recall: 0.8113879003558719 | F1: 0.76
# Epoch: 350 | Accuracy: 0.866 | AUC: 0.933 | Precision: 0.7220447284345048 | Recall: 0.8042704626334519 | F1: 0.7609427609427608
# Epoch: 380 | Accuracy: 0.866 | AUC: 0.933 | Precision: 0.7125382262996942 | Recall: 0.8291814946619217 | F1: 0.7664473684210527
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8660 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.406 | AUC: 0.878 | Precision: 0.30760749724366043 | Recall: 0.9928825622775801 | F1: 0.46969696969696967
# Epoch: 10 | Accuracy: 0.839 | AUC: 0.902 | Precision: 0.6598837209302325 | Recall: 0.8078291814946619 | F1: 0.7263999999999998
# Epoch: 20 | Accuracy: 0.851 | AUC: 0.925 | Precision: 0.6927899686520376 | Recall: 0.7864768683274022 | F1: 0.7366666666666667
# Epoch: 30 | Accuracy: 0.858 | AUC: 0.926 | Precision: 0.6978851963746223 | Recall: 0.8220640569395018 | F1: 0.7549019607843137
# Epoch: 40 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7234726688102894 | Recall: 0.800711743772242 | F1: 0.7601351351351352
# Epoch: 60 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7138461538461538 | Recall: 0.8256227758007118 | F1: 0.7656765676567656
# Epoch: 140 | Accuracy: 0.868 | AUC: 0.932 | Precision: 0.7342192691029901 | Recall: 0.7864768683274022 | F1: 0.7594501718213059
# Epoch: 160 | Accuracy: 0.864 | AUC: 0.932 | Precision: 0.7202572347266881 | Recall: 0.797153024911032 | F1: 0.7567567567567568
# Epoch: 170 | Accuracy: 0.867 | AUC: 0.932 | Precision: 0.720125786163522 | Recall: 0.8149466192170819 | F1: 0.7646076794657763
# Epoch: 180 | Accuracy: 0.863 | AUC: 0.932 | Precision: 0.706060606060606 | Recall: 0.8291814946619217 | F1: 0.762684124386252
# Epoch: 190 | Accuracy: 0.866 | AUC: 0.932 | Precision: 0.7165109034267912 | Recall: 0.8185053380782918 | F1: 0.7641196013289037
# Epoch: 220 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.7229299363057324 | Recall: 0.8078291814946619 | F1: 0.7630252100840336
# Epoch: 230 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.7229299363057324 | Recall: 0.8078291814946619 | F1: 0.7630252100840336
# Epoch: 240 | Accuracy: 0.87 | AUC: 0.933 | Precision: 0.7241379310344828 | Recall: 0.8220640569395018 | F1: 0.77
# Epoch: 250 | Accuracy: 0.86 | AUC: 0.933 | Precision: 0.7009063444108762 | Recall: 0.8256227758007118 | F1: 0.758169934640523
# Epoch: 300 | Accuracy: 0.867 | AUC: 0.933 | Precision: 0.7348993288590604 | Recall: 0.7793594306049823 | F1: 0.7564766839378239
# Epoch: 350 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7169811320754716 | Recall: 0.8113879003558719 | F1: 0.7612687813021702
# Epoch: 390 | Accuracy: 0.864 | AUC: 0.934 | Precision: 0.7069486404833837 | Recall: 0.8327402135231317 | F1: 0.7647058823529412
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8640 Max Validate AUC: 0.9340
# Epoch: 1 | Accuracy: 0.266 | AUC: 0.884 | Precision: 0.26534466477809254 | Recall: 1.0 | F1: 0.41940298507462687
# Epoch: 10 | Accuracy: 0.847 | AUC: 0.904 | Precision: 0.6842105263157895 | Recall: 0.7864768683274022 | F1: 0.7317880794701986
# Epoch: 20 | Accuracy: 0.853 | AUC: 0.922 | Precision: 0.691131498470948 | Recall: 0.8042704626334519 | F1: 0.743421052631579
# Epoch: 30 | Accuracy: 0.862 | AUC: 0.928 | Precision: 0.7170418006430869 | Recall: 0.7935943060498221 | F1: 0.7533783783783784
# Epoch: 40 | Accuracy: 0.866 | AUC: 0.929 | Precision: 0.7206349206349206 | Recall: 0.8078291814946619 | F1: 0.761744966442953
# Epoch: 50 | Accuracy: 0.862 | AUC: 0.929 | Precision: 0.7064220183486238 | Recall: 0.8220640569395018 | F1: 0.7598684210526316
# Epoch: 60 | Accuracy: 0.859 | AUC: 0.929 | Precision: 0.7 | Recall: 0.8220640569395018 | F1: 0.7561374795417348
# Epoch: 70 | Accuracy: 0.866 | AUC: 0.929 | Precision: 0.7249190938511327 | Recall: 0.797153024911032 | F1: 0.7593220338983052
# Epoch: 80 | Accuracy: 0.87 | AUC: 0.929 | Precision: 0.7313915857605178 | Recall: 0.8042704626334519 | F1: 0.7661016949152543
# Epoch: 90 | Accuracy: 0.868 | AUC: 0.929 | Precision: 0.7296416938110749 | Recall: 0.797153024911032 | F1: 0.761904761904762
# Epoch: 100 | Accuracy: 0.867 | AUC: 0.93 | Precision: 0.7272727272727273 | Recall: 0.797153024911032 | F1: 0.7606112054329373
# Epoch: 110 | Accuracy: 0.871 | AUC: 0.931 | Precision: 0.7337662337662337 | Recall: 0.8042704626334519 | F1: 0.767402376910017
# Epoch: 120 | Accuracy: 0.859 | AUC: 0.931 | Precision: 0.6976047904191617 | Recall: 0.8291814946619217 | F1: 0.7577235772357723
# Epoch: 130 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7082066869300911 | Recall: 0.8291814946619217 | F1: 0.763934426229508
# Epoch: 140 | Accuracy: 0.871 | AUC: 0.931 | Precision: 0.7368421052631579 | Recall: 0.797153024911032 | F1: 0.7658119658119659
# Epoch: 160 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7151702786377709 | Recall: 0.8220640569395018 | F1: 0.7649006622516555
# Epoch: 170 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7202572347266881 | Recall: 0.797153024911032 | F1: 0.7567567567567568
# Epoch: 180 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7151898734177216 | Recall: 0.8042704626334519 | F1: 0.7571189279731992
# Epoch: 190 | Accuracy: 0.858 | AUC: 0.932 | Precision: 0.6900584795321637 | Recall: 0.8398576512455516 | F1: 0.7576243980738362
# Epoch: 200 | Accuracy: 0.868 | AUC: 0.932 | Precision: 0.7169230769230769 | Recall: 0.8291814946619217 | F1: 0.7689768976897691
# Epoch: 210 | Accuracy: 0.863 | AUC: 0.933 | Precision: 0.7073170731707317 | Recall: 0.8256227758007118 | F1: 0.7619047619047619
# Epoch: 240 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7053571428571429 | Recall: 0.8434163701067615 | F1: 0.7682333873581847
# Epoch: 340 | Accuracy: 0.857 | AUC: 0.933 | Precision: 0.6837606837606838 | Recall: 0.8540925266903915 | F1: 0.759493670886076
# Epoch: 360 | Accuracy: 0.858 | AUC: 0.933 | Precision: 0.7027863777089783 | Recall: 0.8078291814946619 | F1: 0.7516556291390728
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8580 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.51 | AUC: 0.877 | Precision: 0.3493670886075949 | Recall: 0.9822064056939501 | F1: 0.5154061624649858
# Epoch: 10 | Accuracy: 0.834 | AUC: 0.9 | Precision: 0.6487252124645893 | Recall: 0.8149466192170819 | F1: 0.722397476340694
# Epoch: 20 | Accuracy: 0.861 | AUC: 0.925 | Precision: 0.7203947368421053 | Recall: 0.7793594306049823 | F1: 0.7487179487179487
# Epoch: 30 | Accuracy: 0.857 | AUC: 0.925 | Precision: 0.7060702875399361 | Recall: 0.7864768683274022 | F1: 0.744107744107744
# Epoch: 40 | Accuracy: 0.866 | AUC: 0.927 | Precision: 0.734006734006734 | Recall: 0.7758007117437722 | F1: 0.754325259515571
# Epoch: 50 | Accuracy: 0.86 | AUC: 0.929 | Precision: 0.7033639143730887 | Recall: 0.8185053380782918 | F1: 0.7565789473684211
# Epoch: 60 | Accuracy: 0.862 | AUC: 0.93 | Precision: 0.7076923076923077 | Recall: 0.8185053380782918 | F1: 0.7590759075907592
# Epoch: 70 | Accuracy: 0.87 | AUC: 0.93 | Precision: 0.7313915857605178 | Recall: 0.8042704626334519 | F1: 0.7661016949152543
# Epoch: 80 | Accuracy: 0.875 | AUC: 0.931 | Precision: 0.7442622950819672 | Recall: 0.8078291814946619 | F1: 0.7747440273037541
# Epoch: 100 | Accuracy: 0.863 | AUC: 0.931 | Precision: 0.7222222222222222 | Recall: 0.7864768683274022 | F1: 0.7529812606473596
# Epoch: 110 | Accuracy: 0.871 | AUC: 0.933 | Precision: 0.7278481012658228 | Recall: 0.8185053380782918 | F1: 0.7705192629815746
# Epoch: 210 | Accuracy: 0.856 | AUC: 0.933 | Precision: 0.6828571428571428 | Recall: 0.8505338078291815 | F1: 0.757527733755943
# Epoch: 290 | Accuracy: 0.862 | AUC: 0.933 | Precision: 0.7102803738317757 | Recall: 0.8113879003558719 | F1: 0.7574750830564783
# Epoch: 310 | Accuracy: 0.86 | AUC: 0.933 | Precision: 0.7033639143730887 | Recall: 0.8185053380782918 | F1: 0.7565789473684211
# Epoch: 350 | Accuracy: 0.871 | AUC: 0.933 | Precision: 0.7322580645161291 | Recall: 0.8078291814946619 | F1: 0.7681895093062605
# Epoch: 390 | Accuracy: 0.868 | AUC: 0.933 | Precision: 0.722397476340694 | Recall: 0.8149466192170819 | F1: 0.765886287625418
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8680 Max Validate AUC: 0.9330
# Epoch: 1 | Accuracy: 0.443 | AUC: 0.882 | Precision: 0.320973348783314 | Recall: 0.9857651245551602 | F1: 0.48426573426573427
# Epoch: 10 | Accuracy: 0.84 | AUC: 0.903 | Precision: 0.6627565982404692 | Recall: 0.8042704626334519 | F1: 0.7266881028938906
# Epoch: 20 | Accuracy: 0.858 | AUC: 0.923 | Precision: 0.7106109324758842 | Recall: 0.7864768683274022 | F1: 0.7466216216216216
# Epoch: 30 | Accuracy: 0.853 | AUC: 0.926 | Precision: 0.6843657817109144 | Recall: 0.8256227758007118 | F1: 0.7483870967741936
# Epoch: 40 | Accuracy: 0.855 | AUC: 0.93 | Precision: 0.6829971181556196 | Recall: 0.8434163701067615 | F1: 0.7547770700636942
# Epoch: 60 | Accuracy: 0.861 | AUC: 0.931 | Precision: 0.6970588235294117 | Recall: 0.8434163701067615 | F1: 0.7632850241545893
# Epoch: 100 | Accuracy: 0.864 | AUC: 0.931 | Precision: 0.7082066869300911 | Recall: 0.8291814946619217 | F1: 0.763934426229508
# Epoch: 110 | Accuracy: 0.866 | AUC: 0.931 | Precision: 0.7178683385579937 | Recall: 0.8149466192170819 | F1: 0.7633333333333334
# Epoch: 130 | Accuracy: 0.871 | AUC: 0.931 | Precision: 0.7292993630573248 | Recall: 0.8149466192170819 | F1: 0.7697478991596638
# Epoch: 180 | Accuracy: 0.865 | AUC: 0.932 | Precision: 0.7090909090909091 | Recall: 0.8327402135231317 | F1: 0.7659574468085105
# Epoch: 220 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7133956386292835 | Recall: 0.8149466192170819 | F1: 0.760797342192691
# Epoch: 310 | Accuracy: 0.865 | AUC: 0.933 | Precision: 0.7183544303797469 | Recall: 0.8078291814946619 | F1: 0.7604690117252931
# Epoch: 340 | Accuracy: 0.869 | AUC: 0.933 | Precision: 0.7232704402515723 | Recall: 0.8185053380782918 | F1: 0.7679465776293823
# Epoch: 360 | Accuracy: 0.86 | AUC: 0.933 | Precision: 0.69164265129683 | Recall: 0.8540925266903915 | F1: 0.7643312101910829
# Epoch: 400 | Accuracy: 0.864 | AUC: 0.933 | Precision: 0.7044776119402985 | Recall: 0.8398576512455516 | F1: 0.7662337662337663
# Hids: 128 lr: 0.01 wd: 0.005 Max Validate Accuracy: 0.8640 Max Validate AUC: 0.9330

# %%
# from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# data = data.to(device)
# def gridsearch(hidden_channels, lrs,weight_decays, save_path):
#     def train(optimizer, criterion):
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x, data.edge_index,data.edge_weight)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss


#     def validate():
#         model.eval()
#         out = model(data.x, data.edge_index,data.edge_weight)
#         pred = out.argmax(dim=1)  # Use the class with highest probability.

#         sm = torch.nn.Softmax(dim=1)
#         probs__ = sm(out)
#         greater_class_probs = probs__[:,1]

#         test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
#         test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.

#         d_ = data.y[data.val_mask].cpu().numpy()
#         p_ = pred[data.val_mask].cpu().numpy()

#         #Precision, Recall and F1 Score
#         precision = precision_score(d_, p_)
#         recall = recall_score(d_, p_)
#         f1 = f1_score(d_, p_)

#         return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
    
    
#     def test():
#         class_correct = [0,0]
#         class_samples = [0,0]
#         model.eval()
#         out = model(data.x, data.edge_index, data.edge_weight)
#         pred = out.argmax(dim=1)  # Use the class with highest probability.
#         test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#         assert len(test_correct)==len(pred[data.test_mask])
#         #print(test_correct)
#         sm = torch.nn.Softmax(dim=1)
#         probs__ = sm(out)
#         greater_class_probs = probs__[:,1]
#         test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#         p = pred[data.test_mask]
#         d = data.y[data.test_mask]
        
#         d_ = d.cpu().numpy()
#         p_ = p.cpu().numpy()
#         greater_class_probs_ = greater_class_probs[data.test_mask].cpu().detach().numpy()

#         precision = precision_score(d_, p_)
#         recall = recall_score(d_, p_)
#         f1 = f1_score(d_, p_)

#         return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

#         for idx,each in enumerate(test_correct):          
#             class_samples[d[idx]] += 1
#             if each == True:
#                 class_correct[p[idx]] += 1
#         # print(class_correct, class_samples)
#         # print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#         return roc_auc_score(d.cpu().numpy(),greater_class_probs_),test_acc, precision, recall, f1

#     num_features = len(data.x[0])
#     stop_at = 0
#     data_dict = {}
#     end_str = INGREDIENT_TO_CLASSIFY
#     data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
#        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
#     for hidden_chans in hidden_channels:
#         for lr in lrs:
#           for wd in weight_decays:
#             for i in range(25):
#               model = GCN(hidden_chans).to(device)
#               optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
#               criterion = torch.nn.CrossEntropyLoss()
#               max_acc = 0.0
#               max_auc = 0.0
#               max_val = 0.0
#               acc_li = []
#               auc_li = []
#               test_acc_li = []
#               test_auc_li = []
#               val_prec_li = []
#               val_rec_li = []
#               val_f1_li = []
#               test_prec_li = []
#               test_rec_li = []
#               test_f1_li = []
#               loss_li = []
#               for epoch in range(1,201):
#                 loss=train(optimizer,criterion)
#                 loss_li.append(loss.cpu().detach().item())
#                 if (epoch%10)==0 or epoch==1:
#                   val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
#                   val_auc = round(val_auc, 3)
#                   val_acc = round(val_acc, 3)
#                   acc_li.append(val_acc)
#                   auc_li.append(val_auc)
#                   val_prec_li.append(val_precision)
#                   val_rec_li.append(val_recall)
#                   val_f1_li.append(val_f1)

#                   test_auc,test_acc, test_precision, test_recall, test_f1 = test()
#                   test_auc_li.append(round(test_auc,3))
#                   test_acc_li.append(round(test_acc,3))
#                   test_prec_li.append(test_precision)
#                   test_rec_li.append(test_recall)
#                   test_f1_li.append(test_f1)
#                   if val_acc >= max_val :
#                     stop_at = epoch
#                     max_auc = val_auc 
#                     max_val = val_acc 
#                     # torch.save(model.state_dict(), save_path+f'mlp_state_dict')

#               print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'Max Validate Accuracy: {max_val:.4f} Max Validate AUC: {max_auc:.4f}')
              
#               data_dict[end_str]['train_loss'][i] = loss_li
#               data_dict[end_str]['Validation Accuracy'][i] = acc_li
#               data_dict[end_str]['Validation AUC'][i] = auc_li
#               data_dict[end_str]['Validation Precision'][i] = val_prec_li
#               data_dict[end_str]['Validation Recall'][i] = val_rec_li
#               data_dict[end_str]['Validation F1'][i] = val_f1_li
#               data_dict[end_str]['Test Accuracy'][i]= test_acc_li
#               data_dict[end_str]['Test AUC'][i] = test_auc_li
#               data_dict[end_str]['Test Precision'][i] = test_prec_li
#               data_dict[end_str]['Test Recall'][i] = test_rec_li
#               data_dict[end_str]['Test F1'][i] = test_f1_li
#           with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_gcn_data_dict_stop_epoch_{stop_at}', 'wb') as f:
#             pickle.dump(data_dict, f)
            
# hidden_chans = [64]#64 lr: 0.01 wd: 0.005
# lrs = [0.01]
# wds = [5e-3]
# save_path = 'run_saves/node_class/'
# gridsearch(hidden_chans,lrs,wds, save_path)
# #model.eval()
# #out = model(data.x, data.edge_index)
# #visualize(out, color=data.y)

# %%
# from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score

# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# data = data.to(device)
# def gridsearch(hidden_channels, lrs,weight_decays, save_path):
#     def train(optimizer, criterion):
#       model.train()
#       optimizer.zero_grad()  # Clear gradients.
#       out = model(data.x, data.edge_index)  # Perform a single forward pass.
#       loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
#       loss.backward()  # Derive gradients.
#       optimizer.step()  # Update parameters based on gradients.
#       return loss


#     def validate():
#         model.eval()
#         out = model(data.x, data.edge_index)
#         pred = out.argmax(dim=1)  # Use the class with highest probability.

#         sm = torch.nn.Softmax(dim=1)
#         probs__ = sm(out)
#         greater_class_probs = probs__[:,1]

#         test_correct = pred[data.val_mask] == data.y[data.val_mask]  # Check against ground-truth labels.
#         test_acc = int(test_correct.sum()) / int(data.val_mask.sum())  # Derive ratio of correct predictions.

#         d_ = data.y[data.val_mask].cpu().numpy()
#         p_ = pred[data.val_mask].cpu().numpy()

#         #Precision, Recall and F1 Score
#         precision = precision_score(d_, p_)
#         recall = recall_score(d_, p_)
#         f1 = f1_score(d_, p_)

#         return roc_auc_score(d_,greater_class_probs[data.val_mask].cpu().detach().numpy()),test_acc, precision,recall,f1
    
    
#     def test():
#         class_correct = [0,0]
#         class_samples = [0,0]
#         model.eval()
#         out = model(data.x, data.edge_index)
#         pred = out.argmax(dim=1)  # Use the class with highest probability.
#         test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
#         assert len(test_correct)==len(pred[data.test_mask])
#         #print(test_correct)
#         sm = torch.nn.Softmax(dim=1)
#         probs__ = sm(out)
#         greater_class_probs = probs__[:,1]
#         test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
#         p = pred[data.test_mask]
#         d = data.y[data.test_mask]
        
#         d_ = d.cpu().numpy()
#         p_ = p.cpu().numpy()
#         greater_class_probs_ = greater_class_probs[data.test_mask].cpu().detach().numpy()

#         precision = precision_score(d_, p_)
#         recall = recall_score(d_, p_)
#         f1 = f1_score(d_, p_)

#         return roc_auc_score(d_,greater_class_probs[data.test_mask].cpu().detach().numpy()),test_acc, precision,recall,f1

#         for idx,each in enumerate(test_correct):          
#             class_samples[d[idx]] += 1
#             if each == True:
#                 class_correct[p[idx]] += 1
#         # print(class_correct, class_samples)
#         # print([class_correct[idx]/class_samples[idx] for idx in range(2)])
#         return roc_auc_score(d.cpu().numpy(),greater_class_probs_),test_acc, precision, recall, f1

#     num_features = len(data.x[0])
#     stop_at = 0
#     data_dict = {}
#     end_str = INGREDIENT_TO_CLASSIFY
#     data_dict[end_str] = {'train_loss':{}, 'Test Accuracy':{},'Test AUC':{}, 'Validation Accuracy':{},'Validation AUC':{},\
#        'Validation Precision':{},'Validation Recall': {}, 'Validation F1':{}, 'Test Precision':{},'Test Recall': {}, 'Test F1':{}}
#     for hidden_chans in hidden_channels:
#         for lr in lrs:
#           for wd in weight_decays:
#             for i in range(25):
#               model = GatV2ConvClass(hidden_chans).to(device)
#               optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
#               criterion = torch.nn.CrossEntropyLoss()
#               max_acc = 0.0
#               max_auc = 0.0
#               max_val = 0.0
#               acc_li = []
#               auc_li = []
#               test_acc_li = []
#               test_auc_li = []
#               val_prec_li = []
#               val_rec_li = []
#               val_f1_li = []
#               test_prec_li = []
#               test_rec_li = []
#               test_f1_li = []
#               loss_li = []
#               for epoch in range(1,201):
#                 loss=train(optimizer,criterion)
#                 loss_li.append(loss.cpu().detach().item())
#                 if (epoch%10)==0 or epoch==1:
#                   val_auc,val_acc, val_precision, val_recall, val_f1 =validate()
#                   val_auc = round(val_auc, 3)
#                   val_acc = round(val_acc, 3)
#                   acc_li.append(val_acc)
#                   auc_li.append(val_auc)
#                   val_prec_li.append(val_precision)
#                   val_rec_li.append(val_recall)
#                   val_f1_li.append(val_f1)

#                   test_auc,test_acc, test_precision, test_recall, test_f1 = test()
#                   test_auc_li.append(round(test_auc,3))
#                   test_acc_li.append(round(test_acc,3))
#                   test_prec_li.append(test_precision)
#                   test_rec_li.append(test_recall)
#                   test_f1_li.append(test_f1)
#                   if val_acc >= max_val :
#                     stop_at = epoch
#                     max_auc = val_auc 
#                     max_val = val_acc 
#                     # torch.save(model.state_dict(), save_path+f'mlp_state_dict')

#               print(f'Hids: {hidden_chans}',f'lr: {lr}',f'wd: {wd}',f'Max Validate Accuracy: {max_val:.4f} Max Validate AUC: {max_auc:.4f}')
              
#               data_dict[end_str]['train_loss'][i] = loss_li
#               data_dict[end_str]['Validation Accuracy'][i] = acc_li
#               data_dict[end_str]['Validation AUC'][i] = auc_li
#               data_dict[end_str]['Validation Precision'][i] = val_prec_li
#               data_dict[end_str]['Validation Recall'][i] = val_rec_li
#               data_dict[end_str]['Validation F1'][i] = val_f1_li
#               data_dict[end_str]['Test Accuracy'][i]= test_acc_li
#               data_dict[end_str]['Test AUC'][i] = test_auc_li
#               data_dict[end_str]['Test Precision'][i] = test_prec_li
#               data_dict[end_str]['Test Recall'][i] = test_rec_li
#               data_dict[end_str]['Test F1'][i] = test_f1_li
#           with open(save_path+f'{INGREDIENT_TO_CLASSIFY}_gatv2_data_dict_stop_epoch_{stop_at}', 'wb') as f:
#             pickle.dump(data_dict, f)
            
# hidden_chans = [64]#64 lr: 0.01 wd: 0.005
# lrs = [0.01]
# wds = [5e-3]
# save_path = 'run_saves/node_class/'
# gridsearch(hidden_chans,lrs,wds, save_path)
# #model.eval()
# #out = model(data.x, data.edge_index)
# #visualize(out, color=data.y)

# %%
from sklearn import tree,ensemble
if not MASK:
    assert len(data.y) == len(data.test_mask)==len(data.x)

    clf = tree.DecisionTreeClassifier()
    grad_boost = ensemble.GradientBoostingClassifier()
    data.detach().cpu()
    print(data.x.shape)

    clf.fit(data.x[data.train_mask], data.y[data.train_mask])
    grad_boost.fit(data.x[data.train_mask], data.y[data.train_mask])

    print("FIT")
    clf_preds = torch.Tensor(clf.predict(data.x[data.val_mask]))

    clf_val_acc = int((clf_preds==data.y[data.val_mask]).sum()) / int(data.val_mask.sum())
    grad_val_acc = grad_boost.score(data.x[data.val_mask], data.y[data.val_mask])




    clf_val_probas = clf.predict_proba(data.x[data.val_mask])
    grad_val_probas = grad_boost.predict_proba(data.x[data.val_mask])


    clf_val_auc = roc_auc_score(data.y[data.val_mask],clf_val_probas[:,1])
    grad_val_auc = roc_auc_score(data.y[data.val_mask],grad_val_probas[:,1])

    print(f'Decision Tree Validation Acc {clf_val_acc} and Validation AUC {clf_val_auc}')
    print(f'Grad Boost Validation Acc {grad_val_acc} and Validation AUC {grad_val_auc}')


    clf_preds = torch.Tensor(clf.predict(data.x[data.test_mask]))

    clf_test_acc = int((clf_preds==data.y[data.test_mask]).sum()) / int(data.test_mask.sum())
    grad_test_acc = grad_boost.score(data.x[data.test_mask], data.y[data.test_mask])


    clf_test_probas = clf.predict_proba(data.x[data.test_mask])
    grad_test_probas = grad_boost.predict_proba(data.x[data.test_mask])


    clf_test_auc = roc_auc_score(data.y[data.test_mask],clf_test_probas[:,1])
    grad_test_auc = roc_auc_score(data.y[data.test_mask],grad_test_probas[:,1])


    grad_preds = grad_boost.predict(data.x[data.test_mask])

    grad_f1 = f1_score(data.y[data.test_mask], grad_preds)
    clf_f1 = f1_score(data.y[data.test_mask], clf_preds)


    print(f'Decision Tree test Acc {clf_val_acc} and test AUC {clf_val_auc} and Test F1: {clf_f1}')
    print(f'Grad Boost test Acc {grad_test_acc} and test AUC {grad_test_auc} and Test F1: {grad_f1}')


    with open(f'run_saves/node_class/{INGREDIENT_TO_CLASSIFY}_clf_grad_boost_dict', 'wb') as f:
        pickle.dump({'clf': {'test_acc': clf_test_acc, 'test_auc':clf_test_auc, 'test_f1':clf_f1}, 'grad': {'test_acc': grad_test_acc, 'test_auc':grad_test_auc, 'test_f1':grad_f1}}, f)
# Out:
# torch.Size([6625, 11468])
# FIT
# Decision Tree Validation Acc 0.6688679245283019 and Validation AUC 0.7111750167885645
# Grad Boost Validation Acc 0.8283018867924529 and Validation AUC 0.900940616448682
# Decision Tree test Acc 0.6688679245283019 and test AUC 0.7111750167885645 and Test F1: 0.5954773869346733
# Grad Boost test Acc 0.825636192271442 and test AUC 0.8892993381221607 and Test F1: 0.7086614173228346
